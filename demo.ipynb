# %%
# Editor: ThreeLiu
# Time: 2023/3/31
# Course: NLP
# Description: 分词实验，使用最大匹配算法分词，构建trie树

import transfer_code
import pandas as pd

# %%
train_path = 'train.csv/train.csv'
test_path = 'test.csv'

# %%
class TrieNode:
    def __init__(self, word: str):
        self.children = {}
        self.word = word

    def judge(self):
        if 'end' in self.children.keys():
            return True
        else:
            return False


def add_node(node: TrieNode, word: str):
    for char in word:
        new_node = TrieNode(word=char)
        node.children[char] = new_node
        node = new_node
    node.children['end'] = TrieNode(word='end')


class Trie:
    print_num = 0

    def __init__(self):
        self.root = TrieNode(word='root')

    def build_tree(self, word: str):
        if len(self.root.children) == 0:  # 如果根节点为空，直接添加
            add_node(word=word, node=self.root)
            return 'add'
        else:
            node = self.root
            for charnum in range(len(word)):
                if word[charnum] in node.children.keys():  # 如果当前字在节点中，继续往下找
                    node = node.children.get(word[charnum])
                    if charnum == len(word) - 1 and node.judge:  # 如果当前字是最后一个字，返回exist
                        return 'exist'
                    elif charnum == len(word) - 1 and not node.judge:  # 如果当前字是最后一个字，但是节点中没有end，添加end
                        node.children['end'] = TrieNode(word='end')
                        return 'add'
                    else:  # 如果当前字不在节点中，添加节点
                        continue
                else:
                    add_node(word=word[charnum:], node=node)
                    return 'add'

    def print(self, node=None):  # 打印trie树
        if node is None:
            node = self.root
        print(node.word, end='')
        if node.children:
            flag = False
            for child in node.children.values():
                if flag:
                    print((self.print_num + 1) * '\t', end='')
                flag = True
                self.print_num += 1
                print('->', end='')
                self.print(child)
        else:
            print(' len:', self.print_num - 1)

            # print(self.print_num * '----', end='')

            self.print_num -= 1
            return
        self.print_num -= 1

    def search(self, word):  # 查找单词是否在trie树中
        node = self.root
        for char in word:
            if char in node.children.keys():
                node = node.children.get(char)
            else:
                return False
        return True

# trie = Trie()
# text1=['我们','我们要','我们要去','我们要去吃','我们要去吃饭','我们要去玩','我们要去吃火锅']
# for word in text1:
#     trie.build_tree(word)
# trie.print()

# %%
# 分块读取训练集并分词构建trie树
import re
import sys

text_total = []
trie = Trie()
count = 0


def remove_chinese_punctuation(lst):
    pattern = re.compile(r'[\u4e00-\u9fa5%％\d]')
    # pattern = re.compile(r'[\u4e00-\u9fa5]')
    return [x for x in lst if pattern.search(x)]


for chunk in pd.read_csv(train_path, chunksize=1000):

    text = []
    for i in range(len(chunk)):
        text.extend(chunk['sentence'].tolist()[i].split())
        count += 1

    # text = remove_chinese_punctuation(text)
    for word in text:
        trie.build_tree(word)
    text_total.extend(text)

# trie.print()
print('counter:', count)
print('list_size:', sys.getsizeof(set(text_total)))
print('trie_size:', sys.getsizeof(trie))
print('len:', len(text_total))
print('unique_len:', len(set(text_total)))
# counter: 86918
# list_size: 4194520
# trie_size: 48
# len: 1998791
# unique_len: 87739
# print(text_total)
text_total = set(text_total)
# Out:
# counter: 86918
# list_size: 4194520
# trie_size: 48
# len: 2368391
# unique_len: 88119

# %%
# 使用text_total采用最大匹配算法分词
test_data = pd.read_csv(test_path)
data_list = test_data['sentence'].tolist()

# 正向最大匹配算法
def max_match(sen):
    sen = sen.strip()
    # sen = add_spaces_to_numbers(sen)
    sen = sen.split()
    result = []
    for word in sen:
        if word in text_total:
            result.append(word)
        else:
            left = 0
            right = len(word)
            while left < right:
                if trie.search(word[left:right]):
                    result.append(word[left:right])
                    right = left
                    left = 0
                else:
                    left += 1

    # return result  # 返回分词结果
    return result[::-1]  # 返回分词结果

res_dict = {}
for i in range(len(data_list)):
    sen = data_list[i]
    # sen = remove_chinese_punctuation(sen)
    print(''.join(sen))
    sen = max_match(''.join(sen))
    # 将列表转换为字符串，每个元素之间用空格隔开
    sen = ' '.join(sen)
    print(sen)
    result = transfer_code.transfer(sen)
    # print(result)
    res_dict[i] = result

import csv

with open('result.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['id', 'expected'])
    for key, value in res_dict.items():
        writer.writerow([key + 1, value])
# Out:
# 扬帆远东做与中国合作的先行
# 扬帆 远东 做 与 中国 合作 的 先行
# 希腊的经济结构较特殊。
# 希腊 的 经济 结构 较 特殊 。
# 海运业雄踞全球之首，按吨位计占世界总数的１７％。
# 海运 业 雄踞 全球 之 首 ， 按 吨位 计 占 世界 总数 的 １７％ 。
# 另外旅游、侨汇也是经济收入的重要组成部分，制造业规模相对较小。
# 另外 旅游 、 侨汇 也是 经济 收入 的 重要 组成部分 ， 制造业 规模 相对 较小 。
# 多年来，中希贸易始终处于较低的水平，希腊几乎没有在中国投资。
# 多年来 ， 中 希 贸易 始终 处于 较低 的 水平 ， 希腊 几乎 没有 在 中国 投资 。
# 十几年来，改革开放的中国经济高速发展，远东在崛起。
# 十 几年来 ， 改革开放 的 中国经济 高速 发展 ， 远东 在 崛起 。
# 瓦西里斯的船只中有４０％驶向远东，每个月几乎都有两三条船停靠中国港口。
# 瓦西 里斯 的 船只 中 有 ４０％ 驶 向 远东 ， 每个 月 几乎 都 有 两 三条 船 停靠 中国 港口 。
# 他感受到了中国经济发展的大潮。
# 他 感 受到 了 中国经济 发展 的 大潮 。
# 他要与中国人合作。
# 他 要 与 中国人 合作 。
# 他来到中国，成为第一个访华的大船主。
# 他 来到 中国 ， 成为 第一个 访 华 的 大船 主 。
# 访问归来，他对中国发展充满信心，他向希腊海运部长介绍了情况，提出了两国在海运、造船业方面合作的建议。
# 访问 归来 ， 他 对 中国 发展 充满 信心 ， 他 向 希腊 海运 部长 介绍 了 情况 ， 提出 了 两国 在 海运 、 造船 业 方面 合作 的 建议 。
# １９９５年１０月，希腊海运部长访华时，他根据“船长”的建议与中方探讨了在海运、造船方面合作的可能与途径。
# １９９５年１０月 ， 希腊 海运 部长 访 华 时 ， 他 根据 “ 船长 ” 的 建议 与 中方 探讨 了 在 海运 、 造船 方面 合作 的 可能 与 途径 。
# “船长”本人还与几个船主联合起来准备与我远洋公司建立合资企业。
# “ 船长 ” 本人 还 与 几个 船 主 联合 起来 准备 与 我 远洋 公司 建立 合资 企业 。
# “船长”常说，要么不干，干就要争第一。
# “ 船长 ” 常 说 ， 要么 不干 ， 干 就要 争 第一 。
# 他拥有世界最大的私人集装箱船队，也要做与中国合作的先行。
# 他 拥有 世界 最大 的 私人 集装箱 船队 ， 也 要 做 与 中国 合作 的 先行 。
# 找准人生价值的坐标
# 找 准 人生 价值 的 坐标
# 王思斌，男，１９４９年１０月生。
# ， 男 ， １９４９年１０月 生 。
# 北京大学社会学系教授、博士生导师、系主任，中国社会学会副会长、中国社会工作教育协会副会长兼秘书长。
# 北京大学 社会学系 教授 、 博士生 导师 、 系 主任 ， 中国社会 学会 副 会长 、 中国 社会工作 教育 协会 副 会长 兼 秘书长 。
# 多年来，一直从事农村社会学、组织社会学方面的研究，主要著述有《社会学概论》（合编）、《经济体制改革对农村社会关系的影响》等。
# 多年来 ， 一直 从事 农村 社会学 、 组织 社会学 方 面的 研究 ， 主要 著述 有 《 社会学 概论 》 （ 合编 ） 、 《经济 体制改革 对 农村 社会关系 的 影响 》 等 。
# 译著有《社会管理》、《人的前景》。
# 译著 有 《 社会 管理 》 、 《人 的 前景 》 。
# 近几年来，兼从事社会工作及社会保障问题研究。
# 近几年来 ， 兼 从事 社会工作 及 社会保障 问题 研究 。
# 辛志强朋友：
# 辛 志 强 朋友 ：
# 年轻人谋求自我发展，期望实现自我价值是一件好事情，但怎样才叫实现自我价值呢？
# 年轻人 谋求 自我 发展 ， 期望 实现 自我 价值 是 一件 好 事情 ， 但 怎样 才 叫 实现 自我 价值 呢 ？
# 我认为人生价值的实现应该有两方面的内容：一是个人对社会的贡献，二是社会对个人的尊重和满足。
# 我 认为 人生 价值 的 实现 应该 有 两方 面的 内容 ： 一是 个人 对 社会 的 贡献 ， 二是 社会 对 个人 的 尊重 和 满足 。
# 这两点是相辅相成的。
# 这 两点 是 相辅相成 的 。
# 青年人在确定自己的人生坐标时，一定要找到人生价值和社会价值的切合点。
# 青年人 在 确定 自己 的 人生 坐标 时 ， 一定 要 找到 人生 价值 和 社会 价值 的 切合 点 。
# 又到了毕业生找工作的时候，很多本科生、研究生都希望进国家大机关和各种大公司，这本无可厚非。
# 又 到 了 毕业生 找 工作 的 时候 ， 很多 本科生 、 研究生 都 希望 进 国家大 机关 和 各种 大 公司 ， 这 本 无可厚非 。
# 这些单位起点高，待遇好，一旦有机会可以干出一番大事业。
# 这些 单位 起点 高 ， 待遇 好 ， 一旦 有 机会 可以 干 出 一番 大 事业 。
# 但我们也必须看到，这些单位的位置基本已满，很多学生即使分配进去，也未必能发挥自己的才干，无形中形成了一种人力资源的浪费。
# 但 我们 也 必须 看到 ， 这些 单位 的 位置 基本 已 满 ， 很多 学生 即使 分配 进去 ， 也 未必 能 发挥 自己 的 才干 ， 无形中 形成 了 一种 人力资源 的 浪费 。
# 几年下来，将所学的知识忘光了，将原有的锋芒磨没了。
# 几年 下来 ， 将 所 学 的 知识 忘 光 了 ， 将 原 有的 锋芒 磨 没 了 。
# 社会对一个人自身价值的评价，并不在于他所处的职位的高低，而是看他到底为社会做了什么有价值的事情，是不是充分发挥了他的潜能，做了自己力所能及的事情。
# 社会 对 一 个人 自身 价值 的 评价 ， 并不 在于 他 所 处 的 职位 的 高低 ， 而是 看 他 到底 为 社会 做 了 什么 有 价值 的 事情 ， 是不是 充分 发挥 了 他 的 潜能 ， 做 了 自己 力所能及 的 事情 。
# 而作为个人，自己当然更清楚自我价值是否得到了实现。
# 而 作为 个人 ， 自己 当然 更 清楚 自我 价值 是否 得到 了 实现 。
# 我的一位学生毕业后没有留在北京，而是回苏州一个乡去工作，负责开发区工业园的策划规划，一年做下来，收获颇大，甚至感到所学知识已不够用，需要重回学校补充知识。
# 我 的 一 位 学生 毕业 后 没有 留 在 北京 ， 而是 回 苏州 一个 乡 去 工作 ， 负责 开发区 工业 园 的 策划 规划 ， 一年 做 下来 ， 收获 颇 大 ， 甚至 感到 所 学 知识 已 不 够用 ， 需要 重 回 学校 补充 知识 。
# 和那些分在大机关无法施展才华的同学相比，这位同学活得更充实、更有价值。
# 和 那些 分 在 大 机关 无法 施展 才华 的 同学 相比 ， 这 位 同学 活 得 更 充实 、 更有 价值 。
# 有的同学也许会将自我价值的实现和当今的社会评价体系联系起来看。
# 有的 同学 也 许会 将 自我 价值 的 实现 和 当今 的 社会 评价 体系 联系 起 来看 。
# 譬如电视上频频露面的党政要员、社会名流、企业家、总经理，极容易刺激一个人的政治抱负、财富占有欲，但这种评价体系和现实是有差距的。
# 譬如 电视 上 频频 露 面的 党政 要员 、 社会名流 、 企业家 、 总经理 ， 极 容易 刺激 一 个人 的 政治 抱负 、 财富 占有 欲 ， 但 这种 评价 体系 和 现实 是 有 差距 的 。
# 尤其是通向成功的路不是平坦的，如同一条大船为了航行，必要时要多走一些曲线，但从长远的观点看，这条线还是直的。
# 尤其是 通向 成功 的 路 不是 平坦 的 ， 如同 一条 大船 为了 航行 ， 必要 时 要 多 走 一些 曲线 ， 但 从 长远 的 观点 看 ， 这 条 线 还是 直 的 。
# 两点之间直线最短，但更多的人是走曲线的。
# 两点 之间 直线 最 短 ， 但 更 多 的 人 是 走 曲线 的 。
# 所以我经常鼓励我的学生们去艰苦的地方、去祖国最需要的地方工作。
# 所以 我 经常 鼓励 我 的 学生 们 去 艰苦 的 地方 、 去 祖国 最 需要 的 地方 工作 。
# 很多成功的人都是从最基层做起的。
# 很多 成功 的 人 都是 从 最 基层 做 起 的 。
# 从社会学的角度讲，一个人总是从自己能胜任的工作做起，一直做到自己终不能胜任的工作。
# 从 社会学 的 角度 讲 ， 一 个人 总是 从 自己 能 胜任 的 工作 做 起 ， 一直 做到 自己 终 不能 胜任 的 工作 。
# 社会所提供的机会，尤其是做大事的机会是有限的，但做一些力所能及的小事的机会却很多。
# 社会 所 提供 的 机会 ， 尤其是 做 大事 的 机会 是 有限 的 ， 但 做 一些 力所能及 的 小事 的 机会 却 很多 。
# 有些大学生眼高手低，不屑于做小事情。
# 有些 大学生 眼高手低 ， 不屑于 做 小 事情 。
# 其实小事情带给人的价值会更被人看重。
# 其实 小 事情 带 给 人 的 价值 会 更 被 人 看重 。
# 社会对个人的尊重总是体现在你所创造的价值中，而自我价值的实现本身就是社会对你的贡献的回报，同时也应该是你的满足所在。
# 社会 对 个人 的 尊重 总是 体 现在 你 所 创造 的 价值 中 ， 而 自我 价值 的 实现 本身 就是 社会 对 你 的 贡献 的 回报 ， 同时 也 应该 是 你 的 满足 所在 。
# 辛志强朋友，到边疆工作虽然苦一些，并有违父母的意愿，但如果施展才能的空间很大，而且能充分发挥所学专长，不妨一试。
# 辛 志 强 朋友 ， 到 边疆 工作 虽然 苦 一些 ， 并 有 违 父母 的 意愿 ， 但 如果 施展 才能 的 空间 很 大 ， 而且 能 充分 发挥 所 学 专长 ， 不妨 一 试 。
# （王思斌）
# ）
# 振奋精神有所作为
# 振奋 精神 有所作为
# 陈耀朋友：
# 陈耀 朋友 ：
# 看了你的信，我被你信中流露出的凄苦、迷惘以及热切求助的情绪触动了。
# 看 了 你 的 信 ， 我 被 你 信 中流 露出 的 凄 苦 、 迷惘 以及 热切 求助 的 情绪 触动 了 。
# 我在日常编辑工作中，还收到不少类似你这样的青年人的来信。
# 我 在 日常 编辑 工作 中 ， 还 收到 不少 类似 你 这样 的 青年人 的 来信 。
# 青年人自尊好胜，勇于进取，但往往受家庭、社会环境的羁绊，人生道路上遇到的挫折也多。
# 青年人 自尊 好 胜 ， 勇于 进取 ， 但 往往 受 家庭 、 社会 环境 的 羁绊 ， 人生 道 路上 遇到 的 挫折 也 多 。
# 挫折多了，不能正确对待，久而久之，便容易心灰意懒，一蹶不振。
# 不振 。
# 其实，外在的艰难困苦并不可怕，可怕的是在这一年龄段，不少青年人经受不起失败与挫折，最后自己击败了自己。
# 其实 ， 外在 的 艰难 困苦 并不 可怕 ， 可怕 的 是 在 这一 年龄 段 ， 不少 青年人 经受 不起 失败 与 挫折 ， 最后 自己 击败 了 自己 。
# 我这封信无法给你指出一条轻松顺利的人生之路，只是想对你目前的困惑心理作些分析，并与你探讨一些摆脱困境的方法。
# 我 这 封 信 无法 给 你 指出 一条 轻松 顺利 的 人生 之 路 ， 只是 想 对 你 目前 的 困惑 心理 作 些 分析 ， 并 与 你 探讨 一些 摆脱 困境 的 方法 。
# 你信中认为是家庭的厄运、周围的环境控制着你，使你不能真正地生活，难以有所作为。
# 你 信 中 认为 是 家庭 的 厄运 、 周围 的 环境 控制 着 你 ， 使 你 不能 真正 地 生活 ， 难以 有所作为 。
# 你家庭的遭遇确实令人同情，但你也要看到，这种境遇并不是你家独有的。
# 你 家庭 的 遭遇 确实 令人 同情 ， 但 你 也 要 看到 ， 这种 境遇 并不是 你 家 独 有的 。
# 我们每个人都要面临生存斗争，任何人只要活在世上，只要同其他人进行社会交往，就会遇到相似的问题。
# 我们 每个人 都 要 面临 生存 斗争 ， 任 何人 只要 活 在 世上 ， 只要 同 其 他人 进行 社会 交往 ， 就 会 遇到 相 似的 问题 。
# 天灾人祸、生老病死、贫穷富贵都是现实客观生活中存在的，意见分歧、矛盾冲突更是时常伴随在人们左右。
# 天灾人祸 、 生老病死 、 贫穷 富贵 都是 现实 客观 生活 中 存在 的 ， 意见 分歧 、 矛盾 冲突 更 是 时常 伴随 在 人们 左右 。
# 父母的年迈多病，夫妻间的龃龉，失去亲人的哀伤，每个人或多或少都有体会。
# 父母 的 年迈 多 病 ， 夫妻 间 的 龃龉 ， 失去 亲人 的 哀 伤 ， 每个人 或多或少 都 有 体会 。
# 一个人没有遇到这种不幸，也会遇到另一种变故。
# 一 个人 没有 遇到 这种 不幸 ， 也 会 遇到 另 一种 变 故 。
# 一个人在某件事上顺利一些，在另一件事上可能会碰壁。
# 一 个人 在 某 件 事 上 顺利 一些 ， 在 另 一件 事 上 可能 会 碰壁 。
# 不少人遇到打击和挫折时，怨恨生活不公平。
# 不少 人 遇到 打击 和 挫折 时 ， 怨恨 生活 不 公平 。
# 我们常常很难说清楚生活中到底是苦多还是乐多，只是可以肯定苦对人的精神打击最大。
# 我们 常常 很难说 清楚 生活 中 到底 是 苦 多 还是 乐 多 ， 只是 可以 肯定 苦 对 人 的 精神 打击 最大 。
# 意志薄弱的人最愿意诉苦，这可以赢得别人的关注与同情，从而自我怜悯，找到无所事事的借口。
# 意志 薄弱 的 人 最 愿意 诉苦 ， 这 可以 赢得 别人 的 关注 与 同情 ， 从而 自我 怜悯 ， 找到 无所事事 的 借口 。
# 你说，你的家庭的各种问题毕竟还没彻底解决，心情始终轻松不起来。
# 你 说 ， 你 的 家庭 的 各种 问题 毕竟 还 没 彻底 解决 ， 心情 始终 轻松 不 起来 。
# 等待谁来解决呢？
# 等待 谁 来 解决 呢 ？
# 如果只是把问题归咎于别人、家庭，不做努力，不冒风险，只是着急、苦恼，你家的问题可能会越搞越糟，你自己的境况也就难以改变。
# 如果 只是 把 问题 归咎 于 别人 、 家庭 ， 不 做 努力 ， 不 冒 风险 ， 只是 着急 、 苦恼 ， 你 家 的 问题 可能 会 越 搞 越 糟 ， 你 自己 的 境况 也就 难以 改变 。
# 与其怨天尤人，不如接受这种现实，正视这种现实，不使自己陷于其中，并用自己的智慧与之进行积极斗争。
# 与其 怨天尤人 ， 不如 接受 这种 现实 ， 正视 这种 现实 ， 不 使 自己 陷于 其中 ， 并用 自己 的 智慧 与 之 进行 积极 斗争 。
# 你是个有抱负的青年，好学上进，期待着为社会多做贡献，实现自己的价值。
# 你 是 个 有 抱负 的 青年 ， 好学 上进 ， 期待 着 为 社会 多 做 贡献 ， 实现 自己 的 价值 。
# 迫于家庭各种矛盾的压力，你的内心失去平衡，生活乱了章法，不但原有的才干得不到施展，潜力不能充分挖掘，而且产生了自我挫败的自卑心理，失去了各种追求的勇气。
# 迫于 家庭 各种 矛盾 的 压力 ， 你 的 内心 失去 平衡 ， 生活 乱 了 章法 ， 不但 原 有的 才干 得不 到 施展 ， 潜力 不能 充分 挖掘 ， 而且 产生 了 自我 挫败 的 自卑 心理 ， 失去 了 各种 追求 的 勇气 。
# 要改变这种局面，首先要振奋精神，不能老像心里长了草似的，焦虑，急躁，要使自己冷静下来，镇定下来，学会主宰自己，变外部控制为内部控制。
# 要 改变 这种 局面 ， 首先 要 振奋 精神 ， 不能 老 像 心里 长 了 草 似的 ， 焦虑 ， 急躁 ， 要 使 自己 冷静 下来 ， 镇定 下来 ， 学会 主宰 自己 ， 变 外部 控制 为 内部 控制 。
# 也许你一时想不出办法解决某一具体困难，但你要努力摆脱消极情绪，做好对付生活的准备。
# 也许 你 一时 想 不出 办法 解决 某 一 具体 困难 ， 但 你 要 努力 摆脱 消极 情绪 ， 做好 对付 生活 的 准备 。
# 你的当务之急，是改变家庭的经济状况。
# 你 的 当务之急 ， 是 改变 家庭 的 经济 状况 。
# 除了年迈的父亲，你似乎再没有兄弟，你就是家中的男子汉、顶梁柱，你应该意识到这一点，不要害怕，不要逃避，勇敢地承担起你的责任。
# 除了 年迈 的 父亲 ， 你 似乎 再 没有 兄弟 ， 你 就是 家 中 的 男子汉 、 顶梁柱 ， 你 应该 意识到 这 一点 ， 不要 害怕 ， 不要 逃避 ， 勇敢 地 承担 起 你 的 责任 。
# 紧紧围绕家中的严峻现实想办法，首先注意不给自己定下不现实的目标。
# 紧紧 围绕 家 中 的 严峻 现实 想 办法 ， 首先 注意 不 给 自己 定 下不 现实 的 目标 。
# 应该正确地认识自己的能力，理智地分析各种主客观因素，扎扎实实地制订循序渐进、切实可行的计划，决不好高骛远、眼高手低。
# 应该 正确 地 认识 自己 的 能力 ， 理智 地 分析 各种 主客观 因素 ， 扎扎实 实地 制订 循序渐进 、 切实可行 的 计划 ， 决 不好 高 骛 远 、 眼高手低 。
# 同时要认识到，要干成一件事，为了将来的甜，一定要吃眼前的苦，要有这个思想准备，有坚定的意志。
# 同时 要 认识 到 ， 要 干 成 一件 事 ， 为了 将来 的 甜 ， 一定 要 吃 眼前 的 苦 ， 要 有 这个 思想准备 ， 有 坚定 的 意志 。
# 无论碰到什么困难和挫折，都应提醒自己：我不能胡思乱想，事情是有希望的，出现失误是允许的，暂时心绪不宁也是正常的，一切都会过去。
# 无论 碰到 什么 困难 和 挫折 ， 都 应 提醒 自己 ： 我 不能 胡 思 乱 想 ， 事情 是 有 希望 的 ， 出现 失误 是 允许 的 ， 暂时 心绪不宁 也是 正常 的 ， 一切 都会 过去 。
# 要看到美好的前景，消极的意念只能用积极的、现实的行动来解除。
# 要 看到 美好 的 前景 ， 消极 的 意念 只能 用 积极 的 、 现实 的 行动 来 解除 。
# 你考上了乡里的临时通讯员，就应该利用这个机会好好干，多写些文章，多投些稿子，一来可以求得进一步发展，二来也可挣些稿费补贴家用。
# 你 考上 了 乡里 的 临时 通讯员 ， 就 应该 利用 这个 机会 好好 干 ， 多 写 些 文章 ， 多 投 些 稿子 ， 一来 可以 求得 进一步 发展 ， 二来 也 可 挣 些 稿费 补贴 家用 。
# 你也可以有意识地学些农业科技知识，帮助父亲种好田，这也是改善家庭状况的一条路子。
# 你 也 可以 有意识 地学 些 农业 科技 知识 ， 帮助 父亲 种 好 田 ， 这 也是 改善 家庭 状况 的 一条 路子 。
# 总之，要鼓起勇气，不怕失败，大胆尝试，相信你脚下的路会越走越宽广。
# 总之 ， 要 鼓起 勇气 ， 不怕 失败 ， 大胆 尝试 ， 相信 你 脚下 的 路 会 越 走 越 宽广 。
# 有位学者说过：“伟人之所以伟大，关键在于：当他与别人共处逆境时，别人失去理智，他则下决心实现自己的目标。”
# 有 位 学者 说 过 ： “ 伟人 之所以 伟大 ， 关键 在于 ： 当 他 与 别人 共处 逆境 时 ， 别人 失去 理智 ， 他 则 下决心 实现 自己 的 目标 。 ”
# 我们通过反复磨练自己，不断培养抵御挫折的能力，也可以成为生活中的强者。
# 我们 通过 反复 磨练 自己 ， 不断 培养 抵御 挫折 的 能力 ， 也 可以 成为 生活 中 的 强者 。
# 陈耀朋友，愿你及早征服茫然、苦恼、绝望的情绪，勇敢地接受生活的考验，做一个精神愉快、有所作为的青年。
# 陈耀 朋友 ， 愿 你 及早 征服 茫然 、 苦恼 、 绝望 的 情绪 ， 勇敢 地 接受 生活 的 考验 ， 做 一个 精神 愉快 、 有所作 为的 青年 。
# 希望能听到你的好消息。
# 希望 能 听到 你 的 好消息 。
# 真情一片为孤残
# 真情 一片 为 孤残
# 山东桓台县起凤镇穆寨村妇女穆玲英，十七年如一日精心照料一位孤残老人的故事，感动了四乡八镇的乡亲们。
# 山东 桓台县 起 凤 镇 穆 寨 村 妇女 穆 玲 英 ， 十七年 如 一日 精心 照料 一 位 孤残 老人 的 故事 ， 感动 了 四乡 八 镇 的 乡亲 们 。
# １９８０年夏天的一个下午，穆寨村年近６０岁的孤寡老人穆守家拄着拐杖挑水。
# １９８０年 夏天 的 一个 下午 ， 穆 寨 村 年 近 ６０岁 的 孤寡老人 穆 守 家 拄 着 拐杖 挑水 。
# 因以前患过青光眼病，穆守家的左眼失明，右眼勉强能看到近处的东西。
# 因 以前 患 过 青光 眼病 ， 穆 守 家 的 左 眼 失明 ， 右 眼 勉强 能 看到 近处 的 东西 。
# 年仅１６岁的穆玲英见状，二话没说，接过老人肩上的担子，替他挑回家。
# 年 仅 １６岁 的 穆 玲 英 见状 ， 二话没说 ， 接 过 老人 肩 上 的 担子 ， 替 他 挑 回家 。
# 穆守家两间低矮的小屋里，蛛丝遍布，连个下脚的地方都没有。
# 穆 守 家 两间 低矮 的 小屋 里 ， 蛛丝 遍布 ， 连 个 下脚 的 地方 都 没有 。
# 玲英又是二话没说，迅速将老人的被褥叠好，把锅、碗、瓢、盆洗了，将地面扫干净，然后又把老人的脏衣服抱回家洗晒。
# 玲 英 又是 二话没说 ， 迅速 将 老人 的 被褥 叠 好 ， 把 锅 、 碗 、 瓢 、 盆 洗 了 ， 将 地面 扫 干净 ， 然后 又 把 老人 的 脏 衣服 抱 回家 洗 晒 。
# 当时，小穆便下了决心：一定要将老人侍奉好，让他过上舒坦日子。
# 当时 ， 小 穆 便 下 了 决心 ： 一定 要 将 老人 侍奉 好 ， 让 他 过 上 舒坦 日子 。
# 以后，她每天都要到老人家里，打油、称盐、换面、挑水、做饭、洗衣……春末，她就为老人吊好蚊帐；不到冬天，她就给老人运去煤和烧土。
# 以后 ， 她 每 天都 要 到 老人 家里 ， 打 油 、 称 盐 、 换 面 、 挑水 、 做饭 、 洗衣 … … 春 末 ， 她 就 为 老人 吊 好 蚊帐 ； 不 到 冬天 ， 她 就 给 老人 运 去 煤 和 烧 土 。
# 穆守家老人喝不惯本村的浅井水，玲英就瞒着他去两公里外的起凤村挑深井水，直到本村也打了深水井。
# 穆 守 家 老人 喝 不惯 本 村 的 浅 井水 ， 玲 英 就 瞒 着 他 去 两公 里外 的 起 凤 村 挑 深 井水 ， 直到 本 村 也 打 了 深 水井 。
# 根据近两年的接触，玲英感到老人一个人在家时闷得慌，便盘算着给他买一个收音机。
# 根据 近 两年 的 接触 ， 玲 英 感到 老人 一 个人 在家 时 闷得慌 ， 便 盘算 着 给 他 买 一个 收音机 。
# 为了凑收音机的钱，她在自己住房的墙上砸个钉子，每天晚饭后就掐玉米辫。
# 为了 凑 收音机 的 钱 ， 她 在 自己 住房 的 墙 上 砸 个 钉子 ， 每天 晚 饭后 就 掐 玉米 辫 。
# 那时，一挂玉米辫能卖五角钱。
# 那时 ， 一 挂 玉米 辫 能 卖 五角钱 。
# 为了尽快凑够钱，玲英每天都忙到深夜。
# 为了 尽快 凑 够 钱 ， 玲 英 每 天都 忙 到 深夜 。
# 等攒到３０元钱时，玲英跑到县城为老人捧回一个收音机。
# 等 攒 到 ３０元钱 时 ， 玲 英 跑 到 县城 为 老人 捧 回 一个 收音机 。
# 那时，收音机在农村还不普及，穆大爷家有了收音机后，每天都有很多老人聚在一块听戏。
# 那时 ， 收音机 在 农村 还 不 普及 ， 穆 大爷 家 有 了 收音机 后 ， 每 天都 有 很多 老人 聚 在 一块 听戏 。
# 人老了格外看重自己的生日。
# 人 老 了 格外 看重 自己 的 生日 。
# 十多年来，每逢农历九月二十八老人生日这天，玲英便带上蒸好的馒头、包子、“寿桃”和酒、糖、茶，给老人祝寿。
# 十 多年来 ， 每逢 农历 九月 二十八 老人 生日 这 天 ， 玲 英 便 带 上 蒸 好 的 馒头 、 包子 、 “ 寿 桃 ” 和 酒 、 糖 、 茶 ， 给 老人 祝寿 。
# 她斟上一杯酒，给老人端起来，看着他喝下去，然后陪着老人唠嗑。
# 她 斟 上一 杯 酒 ， 给 老人 端 起来 ， 看 着 他 喝 下去 ， 然后 陪 着 老人 唠嗑 。
# 农村实行生产责任制后，穆守家老人被村里作为五保户照顾，每年供应他２５０公斤小麦，每月发７元钱的生活费。
# 农村 实行 生产责任制 后 ， 穆 守 家 老人 被 村里 作为 五保户 照顾 ， 每年 供应 他 ２ ５０公斤 小麦 ， 每月 发 ７元钱 的 生活费 。
# 虽然有这些粮食和钱，但没有人照顾，老人生活依然难以自理。
# 虽然 有 这些 粮食 和 钱 ， 但 没 有人 照顾 ， 老人 生活 依然 难以 自理 。
# 这时，玲英的哥哥为她在城里找了一份工作。
# 这时 ， 玲 英 的 哥哥 为 她 在 城里 找 了 一 份 工作 。
# 玲英思前想后，对哥哥说：“我不忍心扔下穆大爷不管啊！”
# 玲 英 思 前 想 后 ， 对 哥哥 说 ： “我 不 忍心 扔下 穆 大爷 不管 啊 ！ ”
# 春秋十七度，为了侍奉穆守家老人，穆玲英失去了许多和同伴玩耍、走亲访友、共享天伦之乐的时间。
# 春秋 十七 度 ， 为了 侍奉 穆 守 家 老人 ， 穆 玲 英 失去 了 许多 和 同伴 玩耍 、 走亲 访友 、 共享 天伦之乐 的 时间 。
# 有人说玲英是个傻姑娘，她回答说：“老人们活在世上不容易，既然我下决心要将他们侍奉好，就不计较会失去什么，也不奢望能得到什么。”
# 有人 说 玲 英 是 个 傻 姑娘 ， 她 回答 说 ： “ 老 人们 活 在 世上 不 容易 ， 既然 我 下决心 要 将 他们 侍奉 好 ， 就 不 计较 会 失去 什么 ， 也 不 奢望 能 得到 什么 。 ”
# 前不久，中共桓台县委发出通知，号召全县人民学习她助人为乐、无私奉献的优良品质和崇高精神。
# 前 不久 ， 中共 桓台 县委 发出 通知 ， 号召 全 县人民 学习 她 助人为乐 、 无私 奉献 的 优良 品质 和 崇高 精神 。
# （山东桓台县张震）
# （ 山东 桓台县 张震 ）
# 立足于正当的基础（附图片１张）
# 立足 于 正当 的 基础 （ 附 图片 １ 张 ）
# 何怀宏，哲学博士，１９５４年生，江西清江人，现为中国艺术研究院中国文化研究所研究员。
# 何 怀 宏 ， 哲学 博士 ， １９５４年 生 ， 江西 清 江人 ， 现 为 中国艺术研究院 中国文化 研究所 研究员 。
# 著作有《若有所思》、《生命的沉思》、《契约伦理与社会正义》、《良心论》、《世袭社会及其解体》、《珍重生命》、《心灵瞬间》，另有《伦理学体系》、《正义论》等译著九部，发表论文、散文数十篇。
# 著作 有 《 若 有所 思 》 、 《 生命 的 沉思 》 、 《 契约 伦理 与 社会 正义 》 、 《 良心 论 》 、 《 世袭 社会 及其 解体 》 、 《 珍重 生命 》 、 《 心灵 瞬间 》 ， 另 有 《 伦理学 体系 》 、 《 正义 论 》 等 译著 九 部 ， 发表 论文 、 散文 数十篇 。
# 鲁莹朋友：
# 鲁 莹 朋友 ：
# 你遇到的问题具有某种普遍意义，我不是法律专家，只能从伦理的角度提供一点参考意见。
# 你 遇到 的 问题 具有 某 种 普遍 意义 ， 我 不是 法律 专家 ， 只能 从 伦理 的 角度 提供 一点 参考 意见 。
# 我想这种道德上正当与否的问题要比违法与否的问题更为重要，有关违法的追究只有在造成严重后果、有人起诉的情况下才会发生，而道德的追问则在任何情况下都会发生。
# 我 想 这种 道德 上 正当 与否 的 问题 要 比 违法 与否 的 问题 更为 重要 ， 有关 违法 的 追究 只有 在 造成 严重 后果 、 有人 起诉 的 情况 下 才 会 发生 ， 而 道德 的 追问 则 在 任何 情况 下 都会 发生 。
# 你的问题可以更一般地表述为：我们是否能以某种不正当的方式反对一种在我们看来是严重的不公正，哪怕我们所采取的这种不当方式是相对轻微的、不太重要的。
# 你 的 问题 可以 更 一般 地 表述 为 ： 我们 是否 能 以 某 种 不 正当 的 方式 反对 一种 在 我们 看来 是 严重 的 不 公正 ， 哪怕 我们 所 采取 的 这种 不当 方式 是 相对 轻微 的 、 不 太 重要 的 。
# 一般而言，私下看别人的日记是不道德的行为，而利用日记材料就更不能不极其谨慎了。
# 一般而言 ， 私下 看 别人 的 日记 是 不道德 的 行为 ， 而 利用 日记 材料 就 更 不能不 极其 谨慎 了 。
# 当人们想直接依据私人日记所提供的材料来采取行动时，不能不仔细考虑这一行动所关涉的各个方面，比方说：公布这些事实将对日记主人及其他被涉及者带来何种影响？
# 当 人们 想 直接 依据 私人 日记 所 提供 的 材料 来 采取 行动 时 ， 不能不 仔细 考虑 这一 行动 所 关涉 的 各个 方面 ， 比方 说 ： 公布 这些 事实 将 对 日记 主人 及 其他 被 涉及 者 带来 何种 影响 ？
# 不同当事人在这一事件中应各负何种责任？
# 不同 当事人 在 这一 事件 中 应 各负 何种 责任 ？
# 事情的性质和程度究竟如何？
# 事情 的 性质 和 程度 究竟 如何 ？
# 这一不公正是否严重和紧迫到必须立即采取这一行动？
# 这 一不 公正 是否 严重 和 紧迫 到 必须 立即 采取 这一 行动 ？
# 还有这些材料是否完全确实？
# 还有 这些 材料 是否 完全 确实 ？
# 等等。
# 等等 。
# 就你所谈的这件事来说，你看同学日记是偶然的、无意的，而且，我赞赏你对有的人在发展党员问题上所表现出来的不公和营私行为的真诚义愤。
# 就 你 所 谈 的 这 件 事 来说 ， 你 看 同学 日记 是 偶然 的 、 无意 的 ， 而且 ， 我 赞赏 你 对 有的 人 在 发展 党员 问题 上 所 表现 出来 的 不公 和 营私 行 为的 真诚 义愤 。
# 你通过正常渠道向校领导反映情况，并没有把日记内容随意传播扩散，这种做法是可以理解的。
# 你 通过 正常 渠道 向 校 领导 反映 情况 ， 并 没有 把 日记 内容 随意 传播 扩散 ， 这种 做法 是 可以 理解 的 。
# 不过，如果在你看过日记尚未采取任何行动时，我也许会建议你直接和日记的主人谈谈，首先承认自己私下看日记的不当（哪怕对方暂时不能谅解，自己这样做也需很大的勇气），同时指出对方的错误，然后再进一步考虑是否采取其他行动。
# 不过 ， 如果 在 你 看 过 日记 尚未 采取 任何 行动 时 ， 我 也 许会 建议 你 直接 和 日记 的 主人 谈 谈 ， 首先 承认 自己 私下 看 日记 的 不当 （ 哪怕 对方 暂时 不能 谅解 ， 自己 这样 做 也 需 很 大 的 勇气 ） ， 同时 指出 对方 的 错误 ， 然后 再 进一步 考虑 是否 采取 其他 行动 。
# 近代以来，在伦理学中有两大派别。
# 近代 以来 ， 在 伦理学 中 有 两大 派别 。
# 一派叫做“道义论”，认为行为的正当与否不取决于行为的目的与效果，而是取决于这些行为本身的性质，无论什么好的出发点、为了什么好的目的，有些不正当的行为也是不应该的。
# 一派 叫做 “ 道义 论 ” ， 认为 行 为的 正当 与否 不 取决于 行 为的 目的 与 效果 ， 而是 取决于 这些 行为 本身 的 性质 ， 无论 什么 好 的 出发点 、 为了 什么 好 的 目的 ， 有些 不 正当 的 行为 也 是不 应该 的 。
# 另一派叫“目的论”，认为目的可以证明手段，极端的目的论甚至认为：为了一个好的目的可以采取一切手段。
# 另 一派 叫 “ 目的 论 ” ， 认为 目的 可以 证明 手段 ， 极 端的 目的 论 甚至 认为 ： 为了 一个 好 的 目的 可以 采取 一切 手段 。
# 在我看来，“道义论”的观点是正确的，因为人们的目的可能有误，信息可能不全或者出错，推崇“目的可以证明手段”，客观上无异于为各种不当行为打开绿灯。
# 在 我 看来 ， “ 道义 论 ” 的 观点 是 正确 的 ， 因为 人们 的 目的 可能 有 误 ， 信息 可 能不 全 或者 出错 ， 推崇 “ 目的 可以 证明 手段 ” ， 客观 上 无异 于 为 各种 不当 行为 打 开绿灯 。
# 在我们的生活中已经有过不少这样的教训。
# 在 我们 的 生活 中 已经 有 过 不少 这样 的 教训 。
# 而以自己的一个不义行为去纠正另一个人的不义行为，从严于责己的角度来说，甚至可能是一个更大的不义。
# 而 以 自己 的 一个 不义 行为 去 纠正 另一 个人 的 不义 行为 ， 从严 于 责 己 的 角度 来说 ， 甚至 可能 是 一个 更 大 的 不义 。
# 因为这是我的不义，是后发的不义，增加的不义。
# 因为 这是 我 的 不义 ， 是 后 发 的 不义 ， 增 加的 不义 。
# 比起对别人的、已经发生的行为来，我们对自己正打算去做的行为，应该要求更严格些。
# 比 起 对 别人 的 、 已经 发生 的 行为 来 ， 我们 对 自己 正 打算 去 做 的 行为 ， 应该 要求 更 严格 些 。
# 当然，上面所说的这种“道义论”观点可以是极其严格的，也可以是相对温和的，亦即容许有在某种极端情况下的例外。
# 当然 ， 上面 所 说 的 这种 “ 道义 论 ” 观点 可以 是 极其 严格 的 ， 也 可以 是 相对 温和 的 ， 亦即 容 许有 在 某 种 极端 情况 下 的 例外 。
# 例如，如果我偶然看到另一个人的日记，得知他要自杀，我就倾向于认为可以采取一切可能的手段来阻止他的自杀，因为，这时，挽救一个人生命的义务将凌驾于不侵犯别人隐私的义务。
# 例如 ， 如果 我 偶然 看到 另一 个人 的 日记 ， 得知 他 要 自杀 ， 我 就 倾向 于 认为 可以 采取 一切 可能 的 手段 来 阻止 他 的 自杀 ， 因为 ， 这时 ， 挽救 一 个人 生命 的 义务 将 凌 驾 于 不 侵犯 别人 隐私 的 义务 。
# 无论如何，虽然我主张反对不义的营私行为一定要使自己首先立足于正当的基础，采取恰当的方式，因而我们的行动就不能不审慎，但是，保留一种正义感，一种随时准备站出来维护公正、抗击不义的精神还是极其可贵、值得鼓励的。
# 无论如何 ， 虽然 我 主张 反对 不义 的 营私 行为 一定 要 使 自己 首先 立足 于 正当 的 基础 ， 采取 恰当 的 方式 ， 因而 我们 的 行动 就 不能不 审慎 ， 但是 ， 保留 一种 正义感 ， 一种 随时 准备 站 出来 维护 公正 、 抗击 不义 的 精神 还是 极其 可贵 、 值得 鼓励 的 。
# 以上的意见仅供你参考，并愿我们在今后的生活中都能互戒共勉。
# 以上 的 意见 仅 供 你 参考 ， 并 愿 我们 在 今后 的 生活 中 都 能 互 戒 共勉 。
# （何怀宏）
# （ 何 怀 宏 ）
# 说说心底的苦衷
# 说 说 心底 的 苦衷
# 我们是四个十七八岁的农村女孩，我们的父母重男轻女，只让我们马马虎虎念完小学，就再也不让上学了。
# 我们 听 了 这些 话 ， 心里 十分 难过 。
# 我们和村里不少未婚女青年谈起此事，她们也总是说，咱女儿家尽管有心外出闯荡闯荡，可往往拧不过父母，顶不住风言风语，愿望只能变成泡影。
# 我们 和 村里 不少 未婚 女 青年 谈 起 此 事 ， 她们 也 总是 说 ， 咱 女儿 家 尽管 有心 外出 闯荡 闯荡 ， 可 往往 拧 不过 父母 ， 顶 不住 风 言 风 语 ， 愿望 只能 变成 泡影 。
# 希望报纸能为我们鸣心声。
# 希望 报纸 能 为 我们 鸣 心声 。
# 山西壶关县石河沐乡四名女青年口述
# 山西 壶关县 石河 沐 乡 四名 女 青年 口述
# 山西壶关县紫团山农民通讯组秦凤鸣代笔
# 山西 壶关县 紫 团 山 农民 通讯 组 秦 凤 鸣 代笔
# ＊＊＊＊＊
# ＊ ＊ ＊ ＊ ＊
# 条条道路通向成功
# 条条 道路 通向 成功
# 人生是短促的，选择却是宽广的。
# 人生 是 短促 的 ， 选择 却 是 宽广 的 。
# 不管我们身在何处，只要自己勤勉努力，朝着既定目标奋进，就应该相信－－
# 不管 我们 身 在 何处 ， 只要 自己 勤勉 努力 ， 朝着 既定 目标 奋进 ， 就 应该 相信 － －
# 姑娘们好！
# 姑娘 们 好 ！
# 你们能猜出我读了信的感觉吗？
# 你们 能 猜 出 我 读 了 信 的 感觉 吗 ？
# 我想对你们说，理解、同情和欣慰交织在一起，于是，我想和你们聊聊。
# 我 想 对 你们 说 ， 理解 、 同情 和 欣慰 交织 在 一起 ， 于是 ， 我 想 和 你们 聊 聊 。
# 应该说，对你们的家乡壶关县我不算陌生，十多年前我去采访过。
# 应该 说 ， 对 你们 的 家乡 壶关县 我 不 算 陌生 ， 十多 年前 我 去 采访 过 。
# 记忆中，土山、土路、土屋，贫瘠的黄土加上干旱少雨，使人们的生活很苦。
# 记忆 中 ， 土 山 、 土 路 、 土屋 ， 贫瘠 的 黄土 加上 干旱 少 雨 ， 使 人们 的 生活 很 苦 。
# 如今十几年过去了，从你们的来信中知道壶关变了，孩子们有了书读，人们看上了电视，你们这群山里的女娃娃有了学本领、闯世界的志气。
# 如今 十几年 过去了 ， 从 你们 的 来信 中 知道 壶关 变 了 ， 孩子 们 有 了 书 读 ， 人们 看上 了 电视 ， 你们 这 群山 里 的 女 娃娃 有 了 学 本领 、 闯世界 的 志气 。
# 这的确令人欣慰。
# 这 的确 令人 欣慰 。
# 生活开始变好了，可与那些鱼米之乡还不能比。
# 生活 开始 变 好 了 ， 可 与 那些 鱼米之乡 还 不能 比 。
# 在我国一些先富起来的农村，不管女孩男孩，父母们都千方百计地让他们上学读书、找份好工作。
# 在 我国 一些 先 富 起来 的 农村 ， 不管 女孩 男孩 ， 父母 们 都 千方百计 地 让 他们 上学 读书 、 找 份 好 工作 。
# 生活在那里，是孩子们的福气。
# 生活 在 那里 ， 是 孩子 们 的 福气 。
# 但是，人活在世上，有些事情我们可以选择，比如诚实还是欺骗、勤劳还是懒惰；有些事情我们却不能选择，比如出生地、父母、家庭条件。
# 但是 ， 人 活 在 世上 ， 有些 事情 我们 可以 选择 ， 比如 诚实 还是 欺骗 、 勤劳 还是 懒惰 ； 有些 事情 我们 却 不能 选择 ， 比如 出生 地 、 父母 、 家庭 条件 。
# 在什么山上唱什么歌，既然生活把我们安排在这穷乡僻壤，那里还留存着浓郁的重男轻女观念，我们就应该面对现实，在力所能及的条件下自己成就自己。
# 在 什么 山 上 唱 什么 歌 ， 既然 生活 把 我们 安排 在 这 穷乡僻壤 ， 那里 还 留存 着 浓郁 的 重 男 轻 女 观念 ， 我们 就 应该 面对 现实 ， 在 力所能及 的 条件 下 自己 成就 自己 。
# 你们读完小学，就被父母中断学业，你们想出去学点本领，也遭父母的阻拦，这的确很可惜。
# 你们 读 完 小学 ， 就 被 父母 中断 学业 ， 你们 想 出去 学 点 本领 ， 也 遭 父母 的 阻拦 ， 这 的确 很 可惜 。
# 从这一点说，我理解你们的埋怨情绪。
# 从 这 一点 说 ， 我 理解 你们 的 埋怨 情绪 。
# 可我们能不能换一种思维方式，理解一下父母呢？
# 可 我们 能不能 换 一种 思维 方式 ， 理解 一下 父母 呢 ？
# 你们的父母也许从来没有读过书，或者只能写自己的名字。
# 你们 的 父母 也许 从来 没有 读 过 书 ， 或者 只能 写 自己 的 名字 。
# 他们也没有机会走出山沟，看看外边的世界。
# 他们 也 没有 机会 走出 山沟 ， 看看 外边 的 世界 。
# 在他们的眼里和记忆中，山里人的出路就是放羊、种地。
# 在 他们 的 眼 里 和 记忆 中 ， 山 里 人 的 出路 就是 放 羊 、 种地 。
# 他们的生活中也有成功和喜悦，那就是今春羊多产了一头崽，今秋地里多打了一袋粮。
# 他们 的 生活 中 也 有 成功 和 喜悦 ， 那 就是 今春 羊 多 产 了 一头 崽 ， 今秋 地里 多 打 了 一 袋 粮 。
# 他们的希望就是雨水足了，地里庄稼长好了，崖崖畔畔的草旺了，羊吃饱、养壮了。
# 他们 的 希望 就是 雨水 足 了 ， 地里 庄稼 长 好 了 ， 崖 崖 畔 畔 的 草 旺 了 ， 羊 吃 饱 、 养 壮 了 。
# 粮多了就不再饿肚子，羊多了就可以多卖钱，不知道这和上学有什么关系。
# 粮 多 了 就 不再 饿 肚子 ， 羊 多 了 就 可以 多 卖钱 ， 不 知道 这 和 上 学有 什么 关系 。
# 他们认为，女孩子早晚要嫁到别人家。
# 他们 认为 ， 女孩子 早晚 要 嫁 到 别 人家 。
# 嫁汉嫁汉，穿衣吃饭。
# 嫁 汉 嫁 汉 ， 穿衣 吃饭 。
# 父母这么想当然不对，可也不能全怪他们的愚钝和落后。
# 父母 这么 想当然 不对 ， 可 也 不能 全 怪 他们 的 愚 钝 和 落后 。
# 人们很难逾越时代的局限，也许你们的父亲当年就是这样娶了你们的母亲，你的奶奶就是这样嫁给了你们的爷爷。
# 人们 很难 逾越 时代 的 局限 ， 也许 你们 的 父亲 当年 就是 这样 娶 了 你们 的 母亲 ， 你 的 奶奶 就是 这样 嫁 给 了 你们 的 爷爷 。
# 学知识，闯世界，道理简单，可父母不懂。
# 学 知识 ， 闯世界 ， 道理 简单 ， 可 父母 不 懂 。
# 你们懂，是因为你们赶上了国家经济大发展的好年代。
# 你们 懂 ， 是 因为 你们 赶上 了 国家经济 大 发展 的 好 年代 。
# 是这个年代，让你们明白了你们的父母半辈子都没明白的道理。
# 是 这个 年代 ， 让 你们 明白 了 你们 的 父母 半辈子 都 没 明白 的 道理 。
# 想到这些，再回头看看父母，他们算不算不幸？
# 想到 这些 ， 再 回头 看看 父母 ， 他们 算不 算 不幸 ？
# 即使父母错了，我们对他们也应该有足够的理解。
# 即使 父母 错 了 ， 我们 对 他们 也 应该 有 足够 的 理解 。
# 姑娘们，说了这么多，不是怪罪你们，是想让你们换一个角度想问题，以便心境开朗，开创新生活。
# 姑娘 们 ， 说了 这么 多 ， 不是 怪 罪 你们 ， 是 想 让 你们 换 一个 角度 想 问题 ， 以便 心境 开朗 ， 开 创新 生活 。
# 在这里，我也要对你们的父母说几句：孩子们心中长出了理想的翅膀，这是我们的希望。
# 在 这里 ， 我 也 要 对 你们 的 父母 说 几句 ： 孩子 们 心 中长 出 了 理想 的 翅膀 ， 这是 我们 的 希望 。
# 中断女儿的学业已是错误，又阻止女儿外出学本领，就是一错再错。
# 中断 女儿 的 学 业已 是 错误 ， 又 阻止 女儿 外出 学 本领 ， 就是 一 错 再 错 。
# 我认识一位台湾实业家，少年丧父，母亲为了让他上学读书，去人家做保姆。
# 我 认识 一 位 台湾 实业家 ， 少年 丧父 ， 母亲 为了 让 他 上学 读书 ， 去 人家 做 保姆 。
# 一次，主人给母亲一块肉，母亲当着人面放在嘴里，扭身就吐在手帕里，带回来给他吃。
# 一次 ， 主人 给 母亲 一块 肉 ， 母亲 当着 人 面 放在 嘴 里 ， 扭 身 就 吐 在 手 帕里 ， 带 回来 给 他 吃 。
# 他说，母亲去世已经２０年了，每年的祭日，他都关起门来为母亲守祭。
# 他 说 ， 母亲 去世 已经 ２０年 了 ， 每年 的 祭 日 ， 他 都 关 起 门 来 为 母亲 守 祭 。
# 同是父母，相比之下，应该有所醒悟。
# 同 是 父母 ， 相比之下 ， 应该 有所 醒悟 。
# 如今社会男女平等，一个家要靠夫妻两人一起支撑，女人没有本事，家就塌了半边。
# 如今 社会 男女平等 ， 一个 家 要 靠 夫妻 两 人 一起 支撑 ， 女人 没有 本事 ， 家 就 塌 了 半边 。
# 即使嫁个有钱人，靠别人养着，看人家眼色行事，日子也不好过。
# 即使 嫁 个 有钱人 ， 靠 别人 养 着 ， 看 人家 眼色 行事 ， 日子 也 不 好过 。
# 姑娘们，希望这封信能对你们有所帮助。
# 姑娘 们 ， 希望 这 封 信 能 对 你们 有所 帮助 。
# 假如一切没有改变，你们也要挺身往前，自己靠自己。
# 假如 一切 没有 改变 ， 你们 也 要 挺身 往前 ， 自己 靠 自己 。
# 你们可以通过书本、电视、广播来学习掌握一些有用的知识，比如手工编织、裁剪和饲养知识。
# 你们 可以 通过 书本 、 电视 、 广播 来 学习 掌握 一些 有用 的 知识 ， 比如 手工 编织 、 裁剪 和 饲养 知识 。
# 不是说小学文化就干不成事，我知道一位四川农村妇女，在看孩子、烧饭之余写作、读书，现在已经出版了自己的诗集。
# 不是 说 小学 文化 就 干 不 成事 ， 我 知道 一 位 四川 农村 妇女 ， 在 看 孩子 、 烧饭 之余 写作 、 读书 ， 现在 已经 出版 了 自己 的 诗集 。
# 我国已故著名数学家华罗庚也没有受过正规的高等教育，而是靠一边打杂工，一边研习，终于学有所成。
# 我国 已故 著名 数学家 华罗庚 也 没有 受过 正规 的 高等教育 ， 而是 靠 一边 打 杂 工 ， 一边 研习 ， 终 于学 有所 成 。
# 相信你们能靠自己的努力和奋斗，创造出一个光明的未来。
# 相信 你们 能 靠 自己 的 努力 和 奋斗 ， 创造 出 一个 光明 的 未来 。
# （本版编辑张善菊）
# （ 本 版 编辑 张 善 菊 ）
# 信任和信用（附图片１张）
# 信任 和 信用 （ 附 图片 １ 张 ）
# 成伯清，１９９３年在南开大学社会学系获硕士学位。
# 成 伯 清 ， １９９３年 在 南开大学 社会学系 获 硕士 学位 。
# 现为南京大学社会学系讲师，在职博士生。
# 现 为 南京大学 社会学系 讲师 ， 在职 博士生 。
# 著有《科学中的理论选择》、《孔子与苏格拉底的文化差别》、《意义与对话》等论文及专著。
# 著 有 《科学 中 的 理论 选择 》 、 《 孔子 与 苏格拉底 的 文化 差别 》 、 《 意义 与 对话 》 等 论文 及 专著 。
# 李顺生朋友：
# 李 顺 生 朋友 ：
# 诚实、守信，在如今，似乎越来越被人们视为“传统”的美德，不合时宜了。
# 诚实 、 守信 ， 在 如今 ， 似乎 越来越 被 人们 视为 “ 传统 ” 的 美德 ， 不合时宜 了 。
# 仿佛只要在法律许可的范围内，就可以不择手段地随意追求自己向往的一切。
# 仿佛 只要 在 法律 许可 的 范围 内 ， 就 可以 不择手段 地 随意 追求 自己 向往 的 一切 。
# 在这样的情形下，研究信任和信用的问题，似乎有点儿不合“市场规律”了。
# 在 这样 的 情形 下 ， 研究 信任 和 信用 的 问题 ， 似乎 有点儿 不合 “ 市场 规律 ” 了 。
# 追求经济效益与恪守道德原则，在很多人看来，难以两全。
# 追求 经济效益 与 恪守 道德 原则 ， 在 很 多人 看来 ， 难以 两全 。
# 有的经济学家认为，市场与非经济的伦理行为准则是不相协调的，道德伦理不仅不会增进而且还会有损于企业的经营目标。
# 有的 经济学家 认为 ， 市场 与 非 经济 的 伦理 行为 准则 是 不相 协调 的 ， 道德 伦理 不仅 不会 增进 而且 还 会 有损于 企业 的 经营 目标 。
# 这种观点，是建立在对市场机制的乐观主义假定之上，即认为市场机制能够自动协调经济行为，维持经济运行的效率与秩序。
# 这种 观点 ， 是 建立 在 对 市场 机制 的 乐观主义 假定 之上 ， 即 认为 市场 机制 能够 自动 协调 经济 行为 ， 维持 经济 运行 的 效率 与 秩序 。
# 社会学家的观点则认为，一定程度的社会整合是一个社会得以维持秩序的必要条件。
# 社会学 家 的 观点 则 认为 ， 一定 程度 的 社会 整合 是 一个 社会 得以 维持 秩序 的 必要条件 。
# 社会整合条件下的社会个体不再是完全从个人利益出发的个体，而是社会规范和价值观念的服从者和体现者。
# 社会 整合 条件 下 的 社会 个体 不再 是 完全 从 个人利益 出发 的 个体 ， 而是 社会 规范 和 价值 观念 的 服从 者 和 体现 者 。
# 在社会大部分个体遵从社会规范的同时，个体的自身利益也得到较好实现。
# 在 社会 大部分 个体 遵从 社会 规范 的 同时 ， 个体 的 自身 利益 也 得到 较好 实现 。
# 对于共同规范的遵从，无疑提高了人们行为的可预期性，使整个社会能运行顺畅，包括经济领域。
# 对于 共同 规范 的 遵从 ， 无疑 提高 了 人们 行 为的 可 预期 性 ， 使 整个 社会 能 运行 顺畅 ， 包括 经济 领域 。
# 从这个意义上说，调节人们行为的社会规范是一种极为重要的社会公共资本，由此，经济资本方能高效地增值。
# 从 这个 意义 上 说 ， 调节 人们 行 为的 社会 规范 是 一种 极为 重要 的 社会 公共 资本 ， 由此 ， 经济 资本 方 能 高效 地 增值 。
# 社会学家一贯认为，经济只是社会生活的一个有机部分，经济领域的秩序与效率仰赖于整个社会的规范结构。
# 社会学 家 一贯 认为 ， 经济 只是 社会生活 的 一个 有机 部分 ， 经济 领域 的 秩序 与 效率 仰 赖 于 整个 社会 的 规范 结构 。
# 这里所谓的规范，不仅指明确的经济法规，还包括其他社会规范的内容，如道德与伦理。
# 这里 所谓 的 规范 ， 不仅 指 明确 的 经济 法规 ， 还 包括 其他 社会 规范 的 内容 ， 如 道德 与 伦理 。
# 前者是市场机制的组成部分，后者则涉及整个社会的公共意义资源。
# 前者 是 市场 机制 的 组成部分 ， 后者 则 涉及 整个 社会 的 公共 意义 资源 。
# 这种思想在当代经济学中亦有所体现，一些经济学家指出，信任降低了“交易成本”，而信任和社会整合的缺乏，是经济增长的障碍。
# 这种 思想 在 当代 经济学 中 亦 有所 体现 ， 一些 经济学家 指出 ， 信任 降低 了 “ 交易 成本 ” ， 而 信任 和 社会 整合 的 缺乏 ， 是 经济 增长 的 障碍 。
# 这种思想打破了传统的市场均衡的机械论模型，市场不再只是纯粹理性的经济行为主体们活动的一个独立领域，而是更大的社会有机组成部分；社会的道德伦理资源会成为市场经济的加速器，将与规范化的市场机制一起推动经济发展。
# 这种 思想 打破 了 传统 的 市场 均衡 的 机械论 模型 ， 市场 不再 只是 纯粹 理性 的 经济 行为 主体 们 活动 的 一个 独立 领域 ， 而是 更 大 的 社会 有机 组成部分 ； 社会 的 道德 伦理 资源 会 成为 市场经济 的 加速器 ， 将 与 规范化 的 市场 机制 一起 推动 经济 发展 。
# 可以毫不夸张地说，现代市场经济就是建立在信任与信用之上的，市场交换不仅仅是商品交换，更是信任与信用的交换。
# 可以 毫不 夸张 地 说 ， 现代 市场经济 就是 建立 在 信任 与 信用 之上 的 ， 市场 交换 不仅仅是 商品 交换 ， 更 是 信任 与 信用 的 交换 。
# 当前，完善和确立市场机制已经取得了全社会的共识，并且在建立和健全各种经济法规、营造经济行为主体方面已取得很大的进展。
# 当前 ， 完善 和 确立 市场 机制 已经 取 得了 全社会 的 共识 ， 并且 在 建立 和 健全 各种 经济 法规 、 营造 经济 行为 主体 方面 已 取得 很 大 的 进展 。
# 但是我们也应看到，缺乏信任和信用的现象在我们生活中并不鲜见。
# 但是 我们 也 应 看到 ， 缺乏 信任 和 信用 的 现象 在 我们 生活 中 并不 鲜见 。
# 各种假冒伪劣产品夺走了人们对厂家和商家的信任，使人们在丰富多彩而又鱼目混珠的商品面前多了犹疑和无措，甚至出现真品打不过伪品的怪现象，厂家和消费者成为直接受害者。
# 各种 假冒伪劣 产品 夺 走 了 人们 对 厂家 和 商家 的 信任 ， 使 人们 在 丰富多彩 而 又 鱼目混珠 的 商品 面前 多 了 犹 疑 和 无措 ， 甚至 出现 真品 打 不过 伪 品 的 怪 现象 ， 厂家 和 消费者 成为 直接 受害者 。
# 一些消费者利用商家“不满意就退货”的承诺，既“满意”地使用了商品又要回了货款。
# 一些 消费者 利用 商家 “ 不 满意 就 退货 ” 的 承诺 ， 既 “ 满意 ” 地 使用 了 商品 又要 回 了 货款 。
# 其他稀奇古怪的坑蒙拐骗花样，更是不胜枚举。
# 其他 稀奇 古怪 的 坑蒙拐骗 花样 ， 更 是 不胜枚举 。
# 由此不难看出，我们社会中的许多经济行为，步入所谓纯粹功利性的误区。
# 由此 不 难 看出 ， 我们 社会 中 的 许多 经济 行为 ， 步入 所谓 纯粹 功利 性 的 误区 。
# 而这些，已经超出了纯经济的范畴，仅凭经济法规是难以彻底解决的。
# 而 这些 ， 已经 超出 了 纯 经济 的 范畴 ， 仅 凭 经济 法规 是 难以 彻底 解决 的 。
# 中国有着悠久的“诚信为本”的传统。
# 中国 有着 悠久 的 “ 诚信 为 本 ” 的 传统 。
# 但我们要注意到，人与人交往中的相互信任，大都建立在家族，至少是熟人的圈子之内。
# 但 我们 要 注意 到 ， 人 与人 交往 中 的 相互 信任 ， 大都 建立 在 家族 ， 至少 是 熟人 的 圈子 之内 。
# 显然，这种信任只限于“知根知底”的狭小范围。
# 显然 ， 这种 信任 只 限于 “ 知根知底 ” 的 狭小 范围 。
# 这种信用模式，无疑束缚了大规模、远距离的交易往来。
# 这种 信用 模式 ， 无疑 束缚 了 大规模 、 远 距离 的 交易 往来 。
# 改革以前，我们社会的信任主要是建立在单位约束的基础上，这从单位开具的“介绍信”的效力中不难看出。
# 改革 以前 ， 我们 社会 的 信任 主 要是 建立 在 单位 约束 的 基础 上 ， 这 从 单位 开具 的 “ 介绍信 ” 的 效力 中 不 难 看出 。
# 出示一张介绍信，就表明你是有单位的，我们可以信任你，即便你欺骗了我们，我们可以找你的单位，要求你的单位负责。
# 出示 一 张 介绍信 ， 就 表明 你 是 有 单位 的 ， 我们 可以 信任 你 ， 即便 你 欺骗 了 我们 ， 我们 可以 找 你 的 单位 ， 要求 你 的 单位 负责 。
# 而单位确实又应为所属者的行为负责，因为所属者的一切都受控于单位。
# 而 单位 确实 又 应 为 所属 者 的 行为 负责 ， 因为 所属 者 的 一切 都 受 控 于 单位 。
# 而改革以后，不仅单位的形式多样化了，连单位同个人之间的关系的性质也变了。
# 而 改革 以后 ， 不仅 单位 的 形式 多样化 了 ， 连 单位 同 个人 之间 的 关系 的 性质 也 变 了 。
# 依靠单位的纽带来维持以往的信任模式，也就不太可靠了。
# 依靠 单位 的 纽 带来 维持 以往 的 信任 模式 ， 也就 不 太 可靠 了 。
# 由此可以看出，信任不仅仅是一种心态的问题，更重要的是需要相应的社会机制来予以维持和强化。
# 由此 可以 看出 ， 信任 不仅仅是 一种 心态 的 问题 ， 更 重要 的 是 需要 相应 的 社会 机制 来 予以 维持 和 强化 。
# 这种机制的原理应当非常简单，即守信者得到酬赏，失信者受到惩罚。
# 这种 机制 的 原理 应当 非常 简单 ， 即 守信 者 得到 酬 赏 ， 失信 者 受到 惩罚 。
# 不过，在社会经济交往日益频繁和短暂化的今天，要做到这一点并非易事。
# 不过 ， 在 社会 经济 交往 日益 频繁 和 短暂 化 的 今天 ， 要 做到 这 一点 并非 易 事 。
# 首先，我们不能通过垂直设置的行政机构来完成这种机制，因为这种设置只能收一时之效。
# 首先 ， 我们 不能 通过 垂直 设置 的 行政 机构 来 完成 这种 机制 ， 因为 这种 设置 只能 收 一时 之 效 。
# 其次，地方保护主义依然盛行，维持信任的社会机制应正面利用地方利益的驱动作用，一个地方守信则受益，反之则受到制裁。
# 其次 ， 地方 保护主义 依然 盛行 ， 维持 信任 的 社会 机制 应 正面 利用 地方 利益 的 驱动 作用 ， 一个 地方 守信 则 受益 ， 反之 则 受到 制裁 。
# 这样，地方就会增强自我约束和自我监督。
# 这样 ， 地方 就 会 增强 自我 约束 和 自我 监督 。
# 再次，政府有关部门应当着力于加强对于一些中介性和行业性机构的管理，而且这种管理应只限于保持它们的公正性和权威性。
# 再次 ， 政府 有关 部门 应当 着力 于 加强 对于 一些 中介 性 和 行业 性 机构 的 管理 ， 而且 这种 管 理应 只 限于 保持 它们 的 公正 性 和 权威性 。
# 最后，各种民间自治组织应在信任和信用的维持中起中坚作用。
# 最后 ， 各种 民间 自治 组织 应 在 信任 和 信用 的 维持 中 起 中坚 作用 。
# 市场经济需要各种致力于社会自我管理的组织的支撑。
# 市场经济 需要 各种 致力于 社会 自我 管理 的 组织 的 支撑 。
# 现在我们比任何时候都明白，解决社会问题，单是诉诸道德说教，或者仰仗公众的良心发现，不可能奏效。
# 现在 我们 比 任何 时候 都 明白 ， 解决 社会 问题 ， 单是 诉诸 道德 说教 ， 或者 仰仗 公众 的 良心 发现 ， 不可能 奏效 。
# 但是，我们也不能因此而忽视道德和良心的作用。
# 但是 ， 我们 也 不能 因此 而 忽视 道德 和 良心 的 作用 。
# 在努力完善信任和信用社会机制的同时，我们应该加快适合于新时代的道德和良心的建设，使之成为经济健康发展可以汲取动力的源泉。
# 在 努力 完善 信任 和 信用 社会 机制 的 同时 ， 我们 应该 加快 适合 于 新时代 的 道德 和 良心 的 建设 ， 使 之 成为 经济 健康 发展 可以 汲取 动力 的 源泉 。
# （成伯清）
# （ 成 伯 清 ）
# 长江三峡工程年底截流合龙设计流量为世界之最截流技术有十分把握
# 长江三峡 工程 年底 截流 合龙 设计 流量 为 世界 之最 截流 技术 有 十分 把握
# 据新华社宜昌１月２日电（记者施勇峰）长江三峡工程将在今年截流。
# 据 新华社 宜昌 １月 ２日 电 （ 记者 施 勇 峰 ） 长江三峡 工程 将 在 今年 截流 。
# 三峡工程将以长江截流成功作为一期工程结束的标志。
# 三峡 工程 将 以 长江 截流 成功 作为 一期 工程 结束 的 标志 。
# 能否高质量完成长江截流，直接关系到工程能否进入第二期施工。
# 能否 高质量 完成 长江 截流 ， 直接 关系到 工程 能否 进入 第二期 施工 。
# 现在，三峡工程建设大军正在积极准备，截流工作已进入“倒计时”。
# 现在 ， 三峡 工程 建设 大军 正在 积极 准备 ， 截流 工作 已 进入 “ 倒计时 ” 。
# 三峡截流无论是技术，还是施工规模，都是难度极高的工程。
# 三峡 截流 无论 是 技术 ， 还是 施工 规模 ， 都是 难度 极 高 的 工程 。
# 特别是它的截流设计流量，施工水深和施工强度，都属世界水电工程之最。
# 特别是 它 的 截流 设计 流量 ， 施工 水深 和 施工 强度 ， 都 属 世界 水电 工程 之最 。
# 在三峡长江截流合龙时，选定的设计流量是每秒１.４万至１.９万立方米。
# 在 三峡 长江 截流 合龙 时 ， 选定 的 设计 流量 是 每秒１ . ４万 至 １ . ９万 立方米 。
# 这个流量是目前世界上已完成的水电工程中最大的。
# 这个 流量 是 目前 世界 上 已 完成 的 水电 工程 中 最大 的 。
# 三峡长江截流施工水深一般为２６-４０米，最大水深６０米，比葛洲坝截流最大水深深４０米。
# 三峡 长江 截流 施工 水深 一般 为 ２６ - ４０米 ， 最大 水深 ６０米 ， 比 葛洲坝 截流 最 大水 深深 ４０米 。
# 由于围堰填筑８０％的工程量是水下抛投，而长江三峡水流汹涌，解决深水条件下截流的各种技术问题，是三峡截流成败的关键所在。
# 由于 围堰 填 筑 ８０％ 的 工程 量 是 水下 抛 投 ， 而 长江三峡 水流 汹涌 ， 解决 深水 条件 下 截流 的 各种 技术 问题 ， 是 三峡 截流 成败 的 关键 所在 。
# 当三峡工程还处在论证阶段的时候，三峡截流的技术问题已被国家列为科技攻关的课题。
# 当 三峡 工程 还 处在 论证 阶段 的 时候 ， 三峡 截流 的 技术 问题 已 被 国家 列为 科技攻关 的 课题 。
# 国家组织有关科研单位和大专院校对三峡工程施工水力学进行了长达４０多年的研究，攻克了截流中的各个重大技术问题。
# 国家 组织 有关 科研 单位 和 大专院 校对 三峡 工程 施工 水 力学 进行 了 长 达 ４０多年 的 研究 ， 攻克 了 截流 中 的 各个 重大 技术 问题 。
# 水利部长江水利委员会在广泛吸收国内外专家意见的基础上，参照葛洲坝大江截流和国内外大江大河截流的经验，对三峡工程大江截流的水力学、水文学等进行了充分试验研究，提出了详尽的截流设计，并通过了技术审查。
# 水利部 长江水利委员会 在 广泛 吸收 国内外 专家 意见 的 基础 上 ， 参照 葛洲坝大江 截流 和 国内外 大江 大河 截流 的 经验 ， 对 三峡 工程 大江 截流 的 水 力学 、 水文学 等 进行 了 充分 试验 研究 ， 提出 了 详尽 的 截流 设计 ， 并 通过 了 技术 审查 。
# 三峡工程业主---中国长江三峡工程开发总公司负责人表示，进行三峡截流在技术上已有十分把握。
# 三峡 工程 业主 - - - 中国 长江三峡 工程 开发 总公司 负责人 表示 ， 进行 三峡 截流 在 技术 上 已 有 十分 把握 。
# 记者在采访中了解到，三峡截流的落差和龙口流速都不大，这对截流较为有利。
# 记者 在 采访 中 了解 到 ， 三峡 截流 的 落差 和 龙口 流速 都 不大 ， 这 对 截流 较为 有利 。
# 据分析，三峡截流落差在０.７-０.８米之间，而葛洲坝截流落差为３.２３米；三峡截流的龙口流速为每秒２.８９米，大大低于葛洲坝截流每秒７米的流速。
# 据 分析 ， 三峡 截流 落差 在 ０ . ７ - ０ . ８米 之间 ， 而 葛洲坝 截流 落差 为 ３ . ２ ３米 ； 三峡 截流 的 龙口 流速 为 每秒２ . ８ ９米 ， 大大 低于 葛洲坝 截流 每秒 ７米 的 流速 。
# 这些也为三峡截流一举成功提供了有利条件。
# 这些 也 为 三峡 截流 一举 成功 提供 了 有利 条件 。
# 据悉，三峡工程长江截流的合龙时间暂定为１９９７年１１月，届时将根据工程进展和水文条件确定截流的时间。
# 据悉 ， 三峡 工程 长江 截流 的 合龙 时间 暂 定 为 １９９７年１１月 ， 届时 将 根据 工程 进展 和 水文 条件 确定 截流 的 时间 。
# 在万里长江上建起第一座大坝的葛洲坝集团公司，承担了三峡大江截流及二期围堰工程的施工。
# 在 万里 长江 上 建起 第一座 大坝 的 葛洲坝 集团公司 ， 承担 了 三峡 大江 截流 及 二期 围堰 工程 的 施工 。
# 三峡截流，举世关注。
# 三峡 截流 ， 举世 关注 。
# 这个集团公司从１９９６年１０月起，从施工队伍组织到技术、设备等方面全面进入临战状态。
# 这个 集团公司 从 １９９６年１０月 起 ， 从 施工 队伍 组织 到 技术 、 设备 等 方面 全面 进入 临战 状态 。
# 长江是我国的黄金水道。
# 长江 是 我国 的 黄金 水道 。
# 在长江上修建三峡大坝，必须确保施工期间的长江航运畅通。
# 在 长江 上 修建 三峡 大坝 ， 必须 确保 施工 期间 的 长江航运 畅通 。
# 为解决二期工程６年间的通航问题，三峡工程决定采用导流明渠结合临时船闸的通航方案。
# 为 解决 二期 工程 ６ 年间 的 通航 问题 ， 三峡 工程 决定 采用 导 流 明渠 结合 临时 船闸 的 通航 方案 。
# 大江截流截断主河床后，江水将改由在后河上开挖的导流明渠下泄，这条长１９７５米、宽３５０米的“人造长江”将在截流后的６年时间内成为江水下泄和长江航运的通道。
# 大江 截流 截断 主 河床 后 ， 江水 将 改 由 在 后河 上 开挖 的 导 流 明渠 下泄 ， 这 条 长 １９ ７５米 、 宽 ３５０米 的 “ 人造 长江 ” 将 在 截流 后 的 ６年 时间 内 成为 江水 下泄 和 长江航运 的 通道 。
# 乔石视察中国气象局时强调要重视气候资源的开发利用
# 乔石 视察 中国气象局 时 强调 要 重视 气候 资源 的 开发利用
# 本报北京１月２５日讯新华社记者王言彬、本报记者何加正报道：中共中央政治局常委、全国人大常委会委员长乔石今天视察中国气象局时强调，要使我国气象事业有一个更大的发展。
# 本报 北京 １月 ２５日 讯 新华社 记者 王言彬 、 本报 记者 何加正 报道 ： 中共 中央政治局常委 、 全国人大常委会 委员长 乔石 今天 视察 中国气象局 时 强调 ， 要 使 我国 气象 事业 有 一个 更 大 的 发展 。
# 乔石在中国气象局局长温克刚和名誉局长邹竞蒙等同志陪同下，先后视察了卫星气象中心运行控制室、国家气象中心天气预报会商室和计算机房，详细了解了有关气象装备的运转情况，听取了关于气象工作的汇报。
# 乔石 在 中国气象局 局长 温克刚 和 名誉 局长 邹 竞 蒙 等 同志 陪同 下 ， 先后 视察 了 卫星 气象 中心 运行 控制室 、 国家气象 中心 天气预报 会商 室 和 计算机房 ， 详细 了解 了 有关 气象 装备 的 运转 情况 ， 听取 了 关于 气象 工作 的 汇报 。
# 我国气象业务技术的现代化，在发展中国家已处于领先水平，相当一部分已达到发达国家８０年代中期或后期的水平，某些方面已经达到发达国家９０年代初的水平。
# 我国 气象 业务 技术 的 现代化 ， 在 发展中国家 已 处于 领先 水平 ， 相当 一部分 已 达到 发达国家 ８０年代中期 或 后期 的 水平 ， 某些 方面 已经 达到 发达国家 ９０年代初 的 水平 。
# 我国已初步建成了门类齐全、布局合理、自动化程度较高的气象综合探测系统；初步建成了以计算机通讯网络联通国家、区域气象中心和省、地气象台的信息网络系统，增强了国内外气象信息的交换和传输能力；已经建立了结构合理的气象业务技术体系和比较现代化的气象服务体系；取得了一批重要的气象科研成果；气象教育迅速发展，气象队伍素质明显提高，并广泛开展了国际气象合作与交流；气象系统精神文明建设也取得了重要成绩。
# 我国 已 初步 建成 了 门类 齐全 、 布局 合理 、 自动化 程度 较高 的 气象 综合 探测 系统 ； 初步 建成 了 以 计算机 通讯 网络 联通 国家 、 区域 气象 中心 和 省 、 地 气象台 的 信息 网络 系统 ， 增强 了 国内外 气象 信息 的 交换 和 传输 能力 ； 已经 建立 了 结构 合理 的 气象 业务 技术 体系 和 比较 现代化 的 气象 服务 体系 ； 取 得了 一批 重要 的 气象 科研成果 ； 气象 教育 迅速 发展 ， 气象 队伍 素质 明显 提高 ， 并 广泛 开展 了 国际 气象 合作 与 交流 ； 气象 系统 精神文明 建设 也 取 得了 重要 成绩 。
# 根据规划，未来１５年，我国气象事业的整体水平将达到国际先进水平。
# 根据 规划 ， 未来 １５年 ， 我国 气象 事业 的 整体 水平 将 达到 国际 先进 水平 。
# 乔石说，气象工作与国家建设和人民生活密不可分，非常重要。
# 乔石 说 ， 气象 工作 与 国家建设 和 人民 生活 密不可分 ， 非常 重要 。
# 建国以来，尤其是改革开放以来，我国的气象事业成绩显著。
# 建国 以来 ， 尤其是 改革开放 以来 ， 我国 的 气象 事业 成绩 显著 。
# 广大气象工作者克服困难，艰苦努力，为促进经济发展，为防灾减灾，为方便人民群众的工作和生活做出了重要的贡献。
# 广大 气象 工作者 克服困难 ， 艰苦 努力 ， 为 促进 经济 发展 ， 为 防灾 减灾 ， 为 方便 人民群众 的 工作 和 生活 做出 了 重要 的 贡献 。
# 他说，我国正在实施国民经济和社会发展的“九五”计划，并且制定了到２０１０年的远景目标，这对气象工作提出了更高的要求，我国气象事业面临着繁重的进一步发展的任务。
# 他 说 ， 我国 正在 实施 国民经济 和 社会发展 的 “ 九五 ” 计划 ， 并且 制定 了 到 ２０１０年 的 远景 目标 ， 这 对 气象 工作 提出 了 更 高 的 要求 ， 我国 气象 事业 面临 着 繁重 的 进一步 发展 的 任务 。
# 要更加重视气候资源的开发和利用，继续拓宽气象服务的领域，提高服务质量和效益，抓紧提高气象业务技术的现代化程度，改善工作条件，加强和完善科学管理，努力多出人才，多出成果，逐步使我国的气象工作达到国际上最先进的水平，为国家和人民做出更大贡献。
# 要 更加 重视 气候 资源 的 开发 和 利用 ， 继续 拓宽 气象 服务 的 领域 ， 提高 服务 质量 和 效益 ， 抓紧 提高 气象 业务 技术 的 现代化 程度 ， 改善 工作 条件 ， 加强 和 完善 科学管理 ， 努力 多 出 人才 ， 多 出 成果 ， 逐步 使 我国 的 气象 工作 达到 国际 上 最 先进 的 水平 ， 为 国家 和 人民 做出 更 大 贡献 。
# 他指出，在党和国家的支持下，通过广大气象工作者的共同奋斗，这是完全能够做到的。
# 他 指出 ， 在 党 和 国家 的 支持 下 ， 通过 广大 气象 工作者 的 共同 奋斗 ， 这是 完全 能够 做到 的 。
# 乔石还接见了正在举行的全国气象局长会议的代表。
# 乔石 还 接见 了 正在 举行 的 全国 气象 局长 会议 的 代表 。
# 接见时他说，在新春佳节即将来临的时候，向辛勤工作了几十年的老气象工作者，向在艰苦条件下默默奉献的同志们，向全国气象战线上的所有同志表示亲切的问候和美好的祝愿。
# 接见 时 他 说 ， 在 新春 佳节 即将 来临 的 时候 ， 向 辛勤 工作 了 几十年 的 老 气象 工作者 ， 向 在 艰苦 条件 下 默默 奉献 的 同志 们 ， 向 全国 气象 战线 上 的 所有 同志 表示 亲切 的 问候 和 美好 的 祝愿 。
# 中国记协发表公告建立新闻工作者接受社会监督制度
# 中国记协 发表 公告 建立 新闻 工作者 接受 社会监督 制度
# 新华社北京一月二十六日电为了贯彻落实党的十四届六中全会通过的《中共中央关于加强社会主义精神文明建设若干重要问题的决议》和江泽民总书记视察人民日报重要讲话精神，加强新闻职业道德建设，抵制和反对有偿新闻等不正之风，树立行业新风，中华全国新闻工作者协会（简称『中国记协』）决定建立新闻工作者接受社会监督制度，特发表公告如下：
# 新华社 北京 一月 二十六日 电 为了 贯彻 落实 党 的 十四届 六 中 全会 通过 的 《 中共中央 关于 加强 社会主义 精神文明 建设 若干 重要 问题 的 决议 》 和 江泽民 总书记 视察 人民日报 重要 讲话 精神 ， 加强 新闻 职业道德 建设 ， 抵制 和 反对 有偿 新闻 等 不正之风 ， 树立 行业 新风 ， 中华全国新闻工作者协会 （ 简称 『 中国记协 』 ） 决定 建立 新闻 工作者 接受 社会监督 制度 ， 特 发表 公告 如下 ：
# 一、我国新闻从业人员是一支有较好政治业务素质、富有奉献精神、有战斗力的新闻队伍。
# ２４分钟后，从西安卫星测控中心传来数据表明，卫星已顺利进入近地点２０９公里、远地点３６１９４公里的地球同步转移轨道。
# ２ ４分钟 后 ， 从 西安卫星测控中心 传来 数据 表明 ， 卫星 已 顺利 进入 近地点 ２０ ９公里 、 远地点 ３ ６１９ ４公里 的 地球 同步 转移 轨道 。
# 由中国空间技术研究院研制的“东方红三号”卫星，是我国新一代实用广播通信卫星。
# 由 中国空间技术研究院 研制 的 “ 东方红三号 ” 卫星 ， 是 我国 新一代 实用 广播 通信卫星 。
# 星上装有２４个ｃ波段转发器，工作寿命为８年。
# 星 上 装有 ２４个 ｃ 波段 转发器 ， 工作 寿命 为 ８年 。
# 这次发射的“东方红三号”卫星是这种型号的第二颗卫星。
# 这次 发射 的 “ 东方红三号 ” 卫星 是 这种 型号 的 第二 颗 卫星 。
# 用来发射“东方红三号”卫星的“长征三号甲”运载火箭，是我国自行研制的地球同步轨道运载能力较大的运载火箭，这种型号火箭此前已进行过两次成功发射，也是长征系列火箭第４４次发射。
# 用来 发射 “ 东方红三号 ” 卫星 的 “长征 三号甲 ” 运载火箭 ， 是 我国 自行 研制 的 地球 同步 轨道 运载 能力 较大 的 运载火箭 ， 这种 型号 火箭 此前 已 进行 过 两次 成功 发射 ， 也是 长征 系列 火箭 第４ ４次 发射 。
# “长征三号甲”运载火箭起飞质量为２４０吨，起飞推力为３００吨，可将２.６吨的有效载荷送入地球同步转移轨道。
# “长征 三号甲 ” 运载火箭 起飞 质量 为 ２ ４０吨 ， 起飞 推力 为 ３００吨 ， 可 将 ２ . ６吨 的 有效 载荷 送入 地球 同步 转移 轨道 。
# 同时，也可兼顾其它轨道卫星的发射，包括一箭双星或多星的发射。
# 同时 ， 也 可 兼顾 其它 轨道 卫星 的 发射 ， 包括 一 箭 双星 或多 星 的 发射 。
# 据有关部门介绍，“长征三号甲”火箭上新采用的大推力氢氧发动机、四框架挠性平台等多项新技术，目前世界上只有少数国家掌握。
# 据 有关 部门 介绍 ， “长征 三号甲 ” 火箭 上新 采用 的 大 推力 氢 氧 发动机 、 四 框架 挠 性 平台 等 多 项 新技术 ， 目前 世界 上 只有 少数 国家 掌握 。
# 新华社北京５月１２日电（记者奚启新）据国防科工委北京指挥所提供的信息，东方红三号通信卫星进入地球同步转移轨道后，在西安卫星测控中心地面测控网和远望号海上航天测量船的跟踪、控制下，顺利完成了太阳能帆板及通信天线展开等太空动作。
# 新华社 北京 ５月１２日 电 （ 记者 奚启新 ） 据 国防科工委 北京 指挥 所 提供 的 信息 ， 东方红三号 通信卫星 进入 地球 同步 转移 轨道 后 ， 在 西安卫星测控中心 地面 测控 网 和 远望 号 海上 航天 测量 船 的 跟踪 、 控制 下 ， 顺利 完成 了 太阳能 帆 板 及 通信 天线 展开 等 太空 动作 。
# 北京时间今天下午４时１１分，星上远地点发动机进行了第一次点火，变轨成功，使卫星近地点由２３１公里抬高到６４８８公里，倾角由２８.３度减少到１２.３度。
# 北京时间今天 下午４时 １１分 ， 星 上 远地点 发动机 进行 了 第一次 点火 ， 变 轨 成功 ， 使 卫星 近地点 由 ２ ３１公里 抬高 到 ６ ４８８公里 ， 倾角 由 ２８ . ３ 度 减少 到 １２ . ３ 度 。
# 据悉，再经过两次变轨，四天之后，卫星将进入地球准同步轨道。
# 据悉 ， 再 经过 两次 变 轨 ， 四天 之后 ， 卫星 将 进入 地球 准 同步 轨道 。
# 目前，卫星运行状况良好。
# 目前 ， 卫星 运行 状况 良好 。
# 图片：
# 图片 ：
# ５月１２日零时１７分，我国研制的新一代通信卫星“东方红三号”由新型的“长征三号甲”运载火箭在西昌卫星发射中心发射升空。
# ５月１２日 零时 １７分 ， 我国 研制 的 新一代 通信卫星 “ 东方红三号 ” 由 新型 的 “长征 三号甲 ” 运载火箭 在 西昌卫星发射中心 发射 升空 。
# （新华社记者赵健伟摄）
# （ 新华社 记者 赵 健 伟 摄 ）
# 陕西天然气九月进京陕京输气管道干线焊接接近尾声（附图片１张）
# 陕西 天然气 九月 进京 陕 京 输 气 管道 干线 焊接 接近 尾声 （ 附 图片 １ 张 ）
# 本报北京５月１７日讯记者颜世贵报道：正在建设中的陕京输气管道，已露雄姿，向着既定的投产目标，一刻不停地前进。
# 本报 北京 ５月１７日 讯 记者 颜世贵 报道 ： 正在 建设 中 的 陕 京 输 气 管道 ， 已 露 雄姿 ， 向着 既定 的 投产 目标 ， 一刻 不停 地 前进 。
# 这个投资３９亿多元人民币的国家重点工程，去年５月３日正式全面启动，万余名建设大军面对异常复杂的施工条件，不畏艰难险阻，奋力拼搏在千里施工线上。
# 这个 投资 ３９亿 多元 人民币 的 国家 重点 工程 ， 去年 ５月３日 正式 全面 启动 ， 万余名 建设 大军 面对 异常 复杂 的 施工 条件 ， 不畏 艰难险阻 ， 奋力 拼搏 在 千里 施工 线 上 。
# 截至今年５月１１日，已完成管道焊接７５０公里，占主体干线总量的８６.３％。
# 截至 今年５月１１日 ， 已 完成 管道 焊接 ７ ５０公里 ， 占 主体 干线 总量 的 ８６ . ３％ 。
# 承担此项建设任务的北京天然气集输公司立下军令状：今年５月３０日干线焊接完工；６月３０日全线贯通；９月３０日开始向北京输送天然气。
# 承担 此 项 建设 任务 的 北京 天然气 集 输 公司 立 下 军令状 ： 今年 ５月３０日 干线 焊接 完工 ； ６月３０日 全线 贯通 ； ９月 ３０日 开始 向 北京 输送 天然气 。
# 陕京工程采用了９０年代世界一流的技术和设备。
# 陕 京 工程 采用 了 ９０年代 世界 一流 的 技术 和 设备 。
# 建成后，将是我国陆上第一条大口径、长距离、全自动的输气管线。
# 建成 后 ， 将 是 我国 陆上 第一条 大 口径 、 长距离 、 全自动 的 输 气 管线 。
# 它对陕甘宁中部气田的开发利用，对京津地区城市燃料结构的调整和大气环境质量的改善，将产生巨大的作用。
# 它 对 陕甘宁 中部 气田 的 开发利用 ， 对 京 津 地区 城市 燃料 结构 的 调整 和 大气 环境 质量 的 改善 ， 将 产生 巨大 的 作用 。
# 这 当中 ， 要 经过 ３个 地震 断裂带 ， 还要 越过 无定 河 、 秃 尾 河 、 窟 野 河 、 黄河 、 永定河 ５条 大河 ， 中小型 河流 １４０ 处 ， 铁路 １ ６处 ， 大型 公路 ８ ６处 。
# 设计人员说：管线途经地带，集中国地貌之大成，是目前国内施工难度最大的管道，被外国专家称作“极具挑战性的工程”。
# 设计 人员 说 ： 管线 途经 地带 ， 集 中国 地貌 之 大 成 ， 是 目前 国内 施工 难度 最大 的 管道 ， 被 外国 专家 称作 “ 极 具 挑战 性 的 工程 ” 。
# 陕京输气管道建设得到了沿线政府和人民的大力支持。
# 陕 京 输 气 管道 建设 得到 了 沿线 政府 和 人民 的 大力 支持 。
# 工程经过的地方，绝大多数为“老少边穷”地区，他们以大局为重，表示要像当年支持八路军一样支援工程建设。
# 工程 经过 的 地方 ， 绝大多数 为 “ 老少边穷 ” 地区 ， 他们 以 大局 为重 ， 表示 要 像 当年 支持 八路军 一样 支援 工程 建设 。
# 图片：
# 图片 ：
# 陕甘宁气田至北京输气管道工程线路走向示意图（示意图：孙伟绘）
# 陕甘宁 气田 至 北京 输 气 管道 工程 线路 走向 示意图 （ 示意图 ： 孙伟 绘 ）
# 东方红三号卫星定点成功国务院中央军委致电祝贺
# 东方红三号 卫星 定点 成功 国务院 中央军委 致电 祝贺
# 新华社北京５月２０日电国务院、中央军委今天发出贺电，对成功发射“东方红三号”通信卫星表示祝贺。
# 新华社 北京 ５月２０日 电 国务院 、 中央军委 今天 发出 贺电 ， 对 成功 发射 “ 东方红三号 ” 通信卫星 表示 祝贺 。
# 贺电全文如下：
# 贺电 全文 如下 ：
# 国防科工委、航天工业总公司并转参加“东方红三号”通信卫星研制、发射工作的同志们：
# 国防科工委 、 航天 工业 总公司 并 转 参加 “ 东方红三号 ” 通信卫星 研制 、 发射 工作 的 同志 们 ：
# 欣悉你们用“长征三号甲”运载火箭，将我国“东方红三号”中容量通信卫星成功地送入预定轨道，并定点于东经１２５度赤道上空。
# 欣悉 你们 用 “长征 三号甲 ” 运载火箭 ， 将 我国 “ 东方红三号 ” 中 容量 通信卫星 成功 地 送入 预定 轨道 ， 并 定点 于 东经１ ２５度 赤道 上空 。
# 这是你们认真贯彻党中央、国务院和中央军委的各项指示，自力更生，艰苦奋斗，团结一心，刻苦攻关，保证质量的结果。
# 这是 你们 认真 贯彻 党中央 、 国务院 和 中央军委 的 各项 指示 ， 自力更生 ， 艰苦奋斗 ， 团结一心 ， 刻苦 攻关 ， 保证 质量 的 结果 。
# 国务院、中央军委特向参加研制、发射、测控及各项保障工作的全体同志表示热烈的祝贺！
# 国务院 、 中央军委 特 向 参加 研制 、 发射 、 测控 及 各项 保障 工作 的 全体 同志 表示 热烈 的 祝贺 ！
# 研制、发射“东方红三号”通信卫星，表明我国通信卫星技术又上了一个新的台阶，对于进一步振奋全国人民的精神，促进我国卫星通信事业的发展，推动我国改革开放和经济建设，提高我国在国际航天领域的威望，巩固我国在国际航天发射市场的地位，都具有重要意义。
# 研制 、 发射 “ 东方红三号 ” 通信卫星 ， 表明 我国 通信卫星 技术 又 上 了 一个 新 的 台阶 ， 对于 进一步 振奋 全国人民 的 精神 ， 促进 我国 卫星通信 事业 的 发展 ， 推动 我国 改革开放 和 经济 建设 ， 提高 我国 在 国际 航天 领域 的 威望 ， 巩固 我国 在 国际 航天 发射 市场 的 地位 ， 都 具有 重要 意义 。
# 希望你们认真总结经验，继续发扬成绩，开拓进取，再创新的业绩，为加快我国现代化建设事业的发展不断作出新的贡献！
# 希望 你们 认真 总结经验 ， 继续 发扬 成绩 ， 开拓 进取 ， 再 创新 的 业绩 ， 为 加快 我国 现代化 建设 事业 的 发展 不断 作 出 新 的 贡献 ！
# 国务院中央军委
# 国务院 中央军委
# １９９７年５月２０日
# １９９７年 ５月２０日
# 新华社北京５月２０日电（记者徐殿龙）我国新一代通信卫星“东方红三号”在西安卫星测控中心跟踪与控制下，于今天１５时０１分成功定点于东经１２５度赤道上空。
# 新华社 北京 ５月２０日 电 （ 记者 徐 殿 龙 ） 我国 新一代 通信卫星 “ 东方红三号 ” 在 西安卫星测控中心 跟踪 与 控制 下 ， 于 今天 １５时 ０ １分 成功 定点 于 东经１ ２５度 赤道 上空 。
# “东方红三号”卫星是５月１２日在西昌卫星发射中心由“长征三号甲”运载火箭发射升空的。
# “ 东方红三号 ” 卫星 是 ５月１２日 在 西昌卫星发射中心 由 “长征 三号甲 ” 运载火箭 发射 升空 的 。
# 在卫星进入地球同步转移轨道后的８天时间里，地面测控网和海上测量船对卫星进行了持续跟踪与控制，使卫星顺利地完成了太阳能帆板、通信天线展开和远地点发动机３次点火、调姿变轨等１４０多个太空动作，进入了地球准同步轨道，并建立了预定的漂移速度，为按计划对其实施定点控制创造了条件。
# 在 卫星 进入 地球 同步 转移 轨道 后 的 ８天 时间 里 ， 地面 测控 网 和 海上 测量 船 对 卫星 进行 了 持续 跟踪 与 控制 ， 使 卫星 顺利 地 完成 了 太阳能 帆 板 、 通信 天线 展开 和 远地点 发动机 ３次 点火 、 调 姿 变 轨 等 １４０多个 太空 动作 ， 进入 了 地球 准 同步 轨道 ， 并 建立 了 预定 的 漂移 速度 ， 为 按 计划 对 其 实施 定点 控制 创造 了 条件 。
# 在对“东方红三号”卫星的测控过程中，西安卫星测控中心首次采用同国际标准兼容的新型测控网，对卫星成功地实施了３次变轨和多次定点捕获进行轨道修正。
# ...
# 比赛结束后，“深蓝”小组公布了一个秘密，每场对局结束后，小组都会根据卡斯帕罗夫的情况相应地修改特定的参数，“深蓝”虽不会思考，但这些工作实际上起到了强迫它学习的“作用”，这也是卡斯帕罗夫始终无法找到一个对付“深蓝”的有效办法的主要原因。
# 比赛 结束 后 ， “ 深蓝 ” 小组 公布 了 一个 秘密 ， 每 场 对局 结束 后 ， 小组 都会 根据 卡斯帕罗夫 的 情况 相应 地 修改 特定 的 参数 ， “ 深蓝 ” 虽 不会 思考 ， 但 这些 工作 实际上 起 到 了 强迫 它 学习 的 “ 作用 ” ， 这 也是 卡斯帕罗夫 始终 无法 找到 一个 对付 “ 深蓝 ” 的 有效 办法 的 主要 原因 。
# 今日的“深蓝”，已经不是去年的“深蓝”。
# 今日 的 “ 深蓝 ” ， 已经 不是 去年 的 “ 深蓝 ” 。
# “深蓝”此次胜利，标志着电脑技术又上了一个新台阶，我们从此将不得不认真地思考人与电脑的关系。
# “ 深蓝 ” 此次 胜利 ， 标志着 电脑 技术 又 上 了 一个 新 台阶 ， 我们 从此 将 不得不 认真 地 思考 人与 电脑 的 关系 。
# 据说，卡斯帕罗夫在输掉第二局之后，曾经彻夜难眠。
# 据说 ， 卡斯帕罗夫 在 输 掉 第二局 之后 ， 曾经 彻夜 难 眠 。
# 此时，不只是卡斯帕罗夫，我们大家都要学会接受电脑在某些方面已足以与人较量的现实。
# 此时 ， 不 只是 卡斯帕罗夫 ， 我们 大家 都 要 学会 接受 电脑 在 某些 方面 已 足以 与人 较量 的 现实 。
# 国际互联网的构成和规则
# 国际互联网 的 构成 和 规则
# 风靡全球的ｉｎｔｅｒｎｅｔ就其工作原理来说，就是一个计算机网络。
# 就 其 工作 原理 来说 ， 就是 一个 计算机网络 。
# 从８０年代开始，许多企业就引进了不少的局域网，它们将企业内部的数十台乃至上百台微机用双绞线或同轴缆联通在一起，使网上的计算机可以互相通讯，资源共享。
# 从 ８０年代 开始 ， 许多 企业 就 引进 了 不少 的 局 域 网 ， 它们 将 企业 内部 的 数十台 乃至 上百 台 微机 用 双 绞 线 或 同 轴 缆 联通 在 一起 ， 使 网上 的 计算机 可以 互相 通讯 ， 资源 共享 。
# 同时，还可将一些复杂的运算交给网上功能强大的计算机运行。
# 同时 ， 还 可 将 一些 复杂 的 运算 交给 网上 功能 强大 的 计算机 运行 。
# 这样，网上用户就极大地扩充了自己微机的运算能力和信息贮存量，可以实现许多在个人单机环境下无法实现的功能。
# 这样 ， 网上 用户 就 极 大地 扩充 了 自己 微机 的 运算 能力 和 信息 贮 存量 ， 可以 实现 许多 在 个人 单机 环境 下 无法 实现 的 功能 。
# 如果说ｉｎｔｅｒｎｅｔ是“信息高速公路”，那么局域网就是“乡村小路”了。
# 是 “ 信息 高速公路 ” ， 那么 局 域 网 就是 “ 乡村 小路 ” 了 。
# 就像高速公路与乡村小路有着截然不同的要求一样，由于规模不同，其作用和配置就有了从量变到质变的一个飞跃。
# 就 像 高速公路 与 乡村 小路 有着 截然不同 的 要求 一样 ， 由于 规模 不同 ， 其 作用 和 配置 就 有 了 从 量变 到 质变 的 一个 飞跃 。
# 在局域网上，你的微机只不过和数十台计算机互相通信和资源共享。
# 在 局 域 网上 ， 你 的 微机 只不过 和 数十台 计算机 互相 通信 和 资源 共享 。
# 而当你的微机联上ｉｎｔｅｒｎｅｔ后，你就将面对不同肤色、不同语言、不同习俗、不同文化背景的８０００万ｉｎｔｅｒｎｅｔ用户，与上千万台主机共享资源。
# 用户 ， 与 上千 万台 主机 共享 资源 。
# 由于其规模较之局域网不可同日而语，故其与局域网就有着不同的“游戏规则”。
# 由于 其 规模 较之 局 域 网 不可同日而语 ， 故 其 与 局 域 网 就 有着 不同 的 “ 游戏 规则 ” 。
# 为了管理的方便，一般企业的局域网通常只选用同一类计算机联网。
# 为了 管理 的 方便 ， 一般 企业 的 局 域 网 通常 只 选用 同 一类 计算机 联网 。
# 在同种计算机之间进行通讯是一件比较容易的事情。
# 在 同种 计算机 之间 进行 通讯 是 一件 比较 容易 的 事情 。
# 而在ｉｎｔｅｒｎｅｔ上的计算机可谓五花八门，这样，在不同类型的计算机之间进行通信就成为当务之急。
# 上 的 计算机 可谓 五花八门 ， 这样 ， 在 不同 类型 的 计算机 之间 进行 通信 就 成为 当务之急 。
# 值得庆幸的是，人们已经创造了一种计算机的“世界语”---ｔｃｐ／ｉｐ协议。
# ｃ ｐ ／ ｉ ｐ 协议 。
# ｔｃｐ／ｉｐ是一种不复杂的协议。
# ｃ ｐ ／ ｉ ｐ 是 一种 不 复杂 的 协议 。
# ｉｐ协议是一个信息包结构，它要求计算机将要发的信息分解成一个个有一定长度的信息包。
# ｉ ｐ 协议 是 一个 信息 包 结构 ， 它 要求 计算机 将要 发 的 信息 分解 成 一个个 有 一定 长度 的 信息 包 。
# 其中包括一组３２位的二进制数字。
# 其中 包括 一组 ３２位 的 二进 制 数字 。
# 这组数字记录了信息包将被送往的地址，称为ｉｐ地址。
# 这 组 数字 记录 了 信息 包 将 被 送往 的 地址 ， 称为 ｉ ｐ 地址 。
# 信息包经过多台主机的传递，就可以到达目的地。
# 信息 包 经 过多 台 主机 的 传递 ， 就 可以 到达 目的地 。
# 由于较长的信息被分解成一个个的信息包，这就有可能会在传递过程中有信息包遗失。
# 由于 较 长 的 信息 被 分解 成 一个个 的 信息 包 ， 这就 有 可能 会 在 传递 过程 中 有 信息 包 遗失 。
# 而ｔｃｐ协议就是用来对信息包进行检验，看信息包是否收齐，次序是否正确，如果有错误，就会要求对方重发。
# ｃ ｐ 协议 就是 用来 对 信息 包 进行 检验 ， 看 信息 包 是否 收 齐 ， 次序 是否 正确 ， 如果 有 错误 ， 就 会 要求 对方 重 发 。
# 由于ｉｎｔｅｒｎｅｔ的用户分布在世界各地，所以用来传递信息的媒介也就不仅仅是电缆和双绞线了，还包括光纤、电话线、微波和卫星，这就要求有一些“财大气粗”的通讯公司来专门提供上网服务。
# 的 用户 分布 在 世界 各地 ， 所以 用来 传递 信息 的 媒介 也就 不仅仅是 电缆 和 双 绞 线 了 ， 还 包括 光纤 、 电话 线 、 微波 和 卫星 ， 这就 要求 有一些 “ 财大气粗 ” 的 通讯 公司 来 专门 提供 上网 服务 。
# 而一般的个人和企业则通过这些公司提供的线路上网，这些公司被称为ｉｓｐ。
# 而 一般 的 个 人和 企业 则 通过 这些 公司 提供 的 线路 上网 ， 这些 公司 被 称为 ｉ ｓ ｐ 。
# 而最为麻烦的是网上的上千万台主机的命名。
# 而 最为 麻烦 的 是 网上 的 上千 万台 主机 的 命名 。
# 幸好ｉｎｔｅｒｎｅｔ提供了“域名”服务器系统。
# 提供 了 “ 域名 ” 服务器 系统 。
# 任何一台主机入网，都要到“网络信息中心”申请一个唯一的域名。
# 任何 一 台 主机 入网 ， 都 要 到 “ 网络 信息中心 ” 申请 一个 唯一 的 域名 。
# 这样，我们就可以准确无误地找到我们想去的主机并与它通信，成为ｉｎｔｅｒｎｅｔ网上的一员。
# 网上 的 一 员 。
# （摘自《中国青年报》邓泓文）
# （ 摘 自 《 中国青年报 》 邓 泓 文 ）
# 信息技术对国民素质的挑战
# 信息技术 对 国民 素质 的 挑战
# 桑新民
# 桑 新民
# 随着２１世纪的临近，人类所面临的各种挑战也越来越严峻。
# 随着 ２１世纪 的 临近 ， 人类 所 面临 的 各种 挑战 也 越来越 严峻 。
# 其中既有高科技的挑战，又有生态危机、道德危机等一系列全球性重大问题的挑战。
# 其中 既有 高科技 的 挑战 ， 又 有 生态 危机 、 道德 危机 等 一系列 全球性 重大 问题 的 挑战 。
# 为了迎接挑战，最有效又最紧迫的对策是：尽快在教育系统中确立和传播新世纪的文化价值观念，并据此改革教育模式，在新一代人身上塑造未来社会所要求具备的品格、能力、思维与行为方式，由此完成国民素质的塑造工程。
# 为了 迎接 挑战 ， 最 有效 又 最 紧迫 的 对策 是 ： 尽快 在 教育 系统 中 确立 和 传播 新世纪 的 文化 价值 观念 ， 并 据此 改革 教育 模式 ， 在 新一代 人 身上 塑造 未来 社会 所 要求 具备 的 品格 、 能力 、 思维 与 行为 方式 ， 由此 完成 国民 素质 的 塑造 工程 。
# 本文着重谈谈当前急剧发展的信息技术对国民素质提出了哪些新的要求。
# 本文 着重 谈 谈 当前 急剧 发展 的 信息技术 对 国民 素质 提出 了 哪些 新 的 要求 。
# 在人类文明的进程中，文字的出现、印刷术的产生，不仅是文化发展中的两个重要里程碑，而且引发了教育模式的两次质变：前者使书面语言加入到以往只能借助口头语言和动作语言进行的文化交往和教育活动中，不仅扩展了教育的内容与形式，而且大大提高了学生抽象思维和自学的能力；后者使印刷物的书籍、课本成为文化的主要载体，由此推动了文化的传播和近、现代教育的普及。
# 在 人类 文明 的 进程 中 ， 文字 的 出现 、 印刷 术 的 产生 ， 不仅 是 文化 发展中 的 两个 重要 里程碑 ， 而且 引发 了 教育 模式 的 两次 质变 ： 前者 使 书面 语言 加入 到 以往 只能 借助 口头 语 言和 动作 语言 进行 的 文化 交往 和 教育 活动 中 ， 不仅 扩展 了 教育 的 内容 与 形式 ， 而且 大大 提高 了 学生 抽象 思 维和 自学 的 能力 ； 后者 使 印刷 物 的 书籍 、 课本 成为 文化 的 主要 载体 ， 由此 推动 了 文化 的 传播 和 近 、 现代 教育 的 普及 。
# 进入９０年代以来，“多媒体”和“信息高速公路”两大技术成为工业化时代向信息时代转变的两个重要杠杆，以惊人的速度改变着人们的工作方式、学习方式、思维方式、交往方式乃至生活方式。
# 进入 ９０年代 以来 ， “ 多媒体 ” 和 “ 信息 高速公路 ” 两大 技术 成为 工业化 时代 向 信息 时代 转变 的 两个 重要 杠杆 ， 以 惊人 的 速度 改 变着 人们 的 工作 方式 、 学习 方式 、 思维 方式 、 交往 方式 乃至 生活方式 。
# 在印刷时代，阅读、写作和计算被公认为文化之鼎的三足，也被视为传统教育的三大基石。
# 在 印刷 时代 ， 阅读 、 写作 和 计算 被 公 认为 文化 之 鼎 的 三足 ， 也 被 视为 传统 教育 的 三大 基石 。
# 世界各国都把这三种能力的培养列为基础教育的首要任务，教师和学生为此付出了大量心血。
# 世界 各国 都 把 这 三种 能力 的 培养 列为 基础教育 的 首要 任务 ， 教师 和 学生 为此 付出 了 大量 心血 。
# 而当代信息技术却在传统文化教育这三大基石中引发了一场巨大的裂变！
# 而 当代 信息技术 却 在 传统 文化教育 这 三大 基石 中 引发 了 一 场 巨大 的 裂变 ！
# 阅读方式的变革
# 阅读 方式 的 变革
# 自从印刷技术产生以来，人类已习惯于阅读文本和从各种图书资料中查找所需信息的工作与生活方式。
# 自从 印刷 技术 产生 以来 ， 人类 已 习 惯于 阅读 文本 和 从 各种 图书 资料 中 查找 所 需 信息 的 工作 与 生活方式 。
# 文本中知识与信息只能按线性结构来排列，因此阅读与检索的速度和效率有着不可逾越的界限。
# 文本 中 知识 与 信息 只能 按 线性 结构 来 排列 ， 因此 阅读 与 检索 的 速度 和 效率 有着 不可逾越 的 界限 。
# 电子书刊和因特网上各种巨型电子资料库的出现给人类带来了福音。
# 电子 书刊 和 因特 网上 各种 巨型 电子 资料 库 的 出现 给 人类 带来 了 福音 。
# 在电子读物中，知识间的联结不再是线性的，而是网状的，可以有多种联结组合方式与检索方式，是一种超文本阅读。
# 在 电子 读物 中 ， 知识 间 的 联结 不再 是 线性 的 ， 而是 网 状 的 ， 可以 有 多种 联结 组合 方式 与 检索 方式 ， 是 一种 超文本 阅读 。
# 同时，电子读物中的阅读对象也从文字媒体扩展为声音、图像、三维动画及影视等多种媒体，这就是信息时代的超媒体阅读。
# 同时 ， 电子 读物 中 的 阅读 对象 也 从 文字 媒体 扩展 为 声音 、 图像 、 三维 动画 及 影视 等 多种 媒体 ， 这就是 信息 时代 的 超 媒体 阅读 。
# 这种跨时空的阅读方式，大大提高了阅读的兴趣和效率。
# 这种 跨 时空 的 阅读 方式 ， 大大 提高 了 阅读 的 兴趣 和 效率 。
# 我们不妨举一个实例来帮助人们理解这场变革的意义。
# 我们 不妨 举 一个 实例 来 帮助 人们 理解 这 场 变革 的 意义 。
# 自１９８５年起，我国用７年时间将中华书局校点本《二十五史》输入电脑，建立了“二十五史全文检索系统”。
# 自 １９８５年 起 ， 我国 用 ７年 时间 将 中华书局 校 点 本 《 二十五 史 》 输入 电脑 ， 建立 了 “ 二十五 史 全文 检索 系统 ” 。
# 当你想从这部巨著中查找气象方面有关“风”的资料时，用传统阅读检索方式需要付出的时间和精力是可想而知的，如今运用超文本阅读和计算机自动检索的方式，只需键入“风”、“气象”等关键词，并加以必要的限制（排除与气象无关的“风”），短短６秒钟之后，电脑就会在通读二十五史全文的基础上为你筛选出１０９６８段相关资料和１４９１８个词目，组成一个特殊的文本供你阅读。
# 当 你 想 从 这 部 巨著 中 查找 气象 方面 有关 “风 ” 的 资料 时 ， 用 传统 阅读 检索 方式 需要 付出 的 时间 和 精力 是 可想而知 的 ， 如今 运用 超文本 阅读 和 计算机 自动 检索 的 方式 ， 只需 键 入 “风 ” 、 “ 气象 ” 等 关键 词 ， 并 加以 必要 的 限制 （ 排除 与 气象 无关 的 “风 ” ） ， 短短 ６ 秒 钟 之后 ， 电脑 就 会 在 通读 二十五 史 全文 的 基础 上 为 你 筛 选出 １０ ９６８ 段 相关 资料 和 １４９ １８个 词 目 ， 组成 一个 特殊 的 文本 供 你 阅读 。
# 你若还想简化，则可再次与计算机对话，直至获得满意的信息为止，而计算机的一大优点还在于，绝对会保证“百问不烦”。
# 你 若 还 想 简化 ， 则 可 再次 与 计算机 对话 ， 直至 获得 满意 的 信息 为止 ， 而 计算机 的 一大 优点 还 在于 ， 绝对 会 保证 “ 百 问 不 烦 ” 。
# 培养这种新的阅读能力不仅应该从儿童开始，而且迫切需要给成年人补课乃至“扫盲”。
# 培养 这种 新 的 阅读 能力 不仅 应该 从 儿童 开始 ， 而且 迫切 需要 给 成年人 补课 乃至 “ 扫盲 ” 。
# 这已成为我国跨世纪教育的一项不可忽视的重要使命。
# 这 已 成为 我国 跨世纪 教育 的 一 项 不可 忽视 的 重要 使命 。
# 当然，超文本和超媒体阅读能力还是要以传统文本阅读能力为基础的，但后者对前者的超越则具有鲜明的时代特征，体现了信息社会对个体创造性学习能力的挑战与激发。
# 当然 ， 超文本 和 超 媒体 阅读 能力 还是 要 以 传统 文本 阅读 能力 为 基础 的 ， 但 后者 对 前者 的 超越 则 具有 鲜明 的 时代 特征 ， 体现 了 信息社会 对 个体 创造性 学习 能力 的 挑战 与 激发 。
# 写作方式的变革
# 写作 方式 的 变革
# 在计算机席卷办公室乃至家庭的浪潮中，记者、作家、科学家、秘书乃至领导干部都在“换笔”，而学童们对键盘和鼠标的驾驭与偏爱，则是在电子游戏机“魔力”的引诱下自然发生的。
# 在 计算机 席卷 办公室 乃至 家庭 的 浪潮 中 ， 记者 、 作家 、 科学家 、 秘书 乃至 领导干部 都 在 “ 换 笔 ” ， 而 学童 们 对 键盘 和 鼠 标的 驾驭 与 偏爱 ， 则 是 在 电子游戏机 “ 魔力 ” 的 引诱 下 自然 发生 的 。
# 计算机文字处理系统的出现和日益完善化，不仅使文字录入的速度快，更重要的是可以随意复制、增补、删除等，这就大大节省了人类耗费在写作中的重复性劳动，极大地提高了人类写作的效率。
# 计算机 文字处理 系统 的 出现 和 日益 完善 化 ， 不仅 使 文字 录入 的 速度 快 ， 更 重要 的 是 可以 随意 复制 、 增补 、 删除 等 ， 这就 大大 节省 了 人类 耗费 在 写作 中 的 重复 性 劳动 ， 极 大地 提高 了 人类 写作 的 效率 。
# 一旦语音输入等人机接口技术以及“眼球跟踪器”等电脑视觉系统和机器翻译等技术进一步成熟之后，将会出现更加友好的人机对话界面，加快电脑写作模式的普及。
# 一旦 语音 输入 等 人机 接口 技术 以及 “ 眼球 跟踪 器 ” 等 电脑 视觉 系统 和 机器翻译 等 技术 进一步 成熟 之后 ， 将 会 出现 更加 友好 的 人机对话 界面 ， 加快 电脑 写作 模式 的 普及 。
# 印刷时代的写作是以文字为主，而在电子媒体的写作中，符号、声音、图像乃至三维动画及影视的使用则越来越频繁。
# 印刷 时代 的 写作 是 以 文字 为主 ， 而 在 电子 媒体 的 写作 中 ， 符号 、 声音 、 图像 乃至 三维 动画 及 影视 的 使用 则 越来越 频繁 。
# 这种多媒体的写作形式对于作者与读者之间的沟通、交流和相互理解在现代与未来社会中将越来越重要。
# 这种 多媒体 的 写作 形式 对于 作者 与 读者 之间 的 沟通 、 交流 和 相互 理解 在 现代 与 未来 社会 中将 越来越 重要 。
# 与此相适应，图文并茂、声形兼备的写作能力将要从小培养，多媒体与超文本结构的写作也将会越来越普及。
# 与此 相 适应 ， 图文并茂 、 声 形 兼备 的 写作 能力 将要 从小 培养 ， 多媒体 与 超文本 结构 的 写作 也 将 会 越来越 普及 。
# 计算方式的变革
# 计算 方式 的 变革
# 传统计算能力一般仅与数学和数学教育有关。
# 传统 计算 能力 一般 仅 与 数学 和 数学 教育 有关 。
# 当计算机的应用深入和扩展到社会生活各个领域之后，迫使人们去探究数字与数值计算同社会生活各方面的联系与转化，这就大大拓展了计算的概念，并使整个社会生活越来越“数字化”。
# 当 计算机 的 应用 深入 和 扩展 到 社会生活 各个 领域 之后 ， 迫使 人们 去 探究 数字 与 数值 计算 同 社会生活 各方 面的 联系 与 转化 ， 这就 大大 拓展 了 计算 的 概念 ， 并 使 整个 社会生活 越来越 “ 数字化 ” 。
# 计算机应用研究的实质，是探讨如何用计算机语言来表达各个领域所要解决的难题，并对该领域进行数字化模拟。
# 计算机应用 研究 的 实质 ， 是 探讨 如何 用 计算机 语言 来 表达 各个 领域 所 要 解决 的 难题 ， 并 对 该 领域 进行 数字化 模拟 。
# 文字的数字化可以看作计算机步入人类生活各个领域的一个重要的奠基石或里程碑。
# 文字 的 数字化 可以 看作 计算机 步入 人类 生活 各个 领域 的 一个 重要 的 奠基石 或 里程碑 。
# 此后，文字所表达和描述的世界都可以转化为二进制的计算机语言了，而计算机也开始从技术上升为文化。
# 此后 ， 文字 所 表达 和 描述 的 世界 都 可以 转 化为 二进 制 的 计算机 语言 了 ， 而 计算机 也 开始 从 技术 上升 为 文化 。
# 但计算机并没有就此止步，她又征服了比文字更加复杂的声音世界、图像世界乃至三维动画及影视世界。
# 但 计算机 并 没有 就此 止步 ， 她 又 征服 了 比 文字 更加 复杂 的 声音 世界 、 图像 世界 乃至 三维 动画 及 影视 世界 。
# 如今，记录、表达人类物质与精神世界的数字、图片、胶片、录音带、录像带等组成的巨大的资料库，都可以被数字化处理，这些数据在光、电的运载下，每时每刻都纵横驰骋于高速运行的环球“信息高速公路”网络之中，随时等待和人类的智慧实现跨时空的“联网”与“激发”。
# 如今 ， 记录 、 表达 人类 物质 与 精神 世界 的 数字 、 图片 、 胶片 、 录音带 、 录像带 等 组成 的 巨大 的 资料 库 ， 都 可以 被 数字化 处理 ， 这些 数据 在 光 、 电 的 运载 下 ， 每时每刻 都 纵横驰骋 于 高速 运行 的 环球 “ 信息 高速公路 ” 网络 之中 ， 随时 等待 和 人类 的 智慧 实现 跨 时空 的 “ 联网 ” 与 “ 激发 ” 。
# 在这样的技术背景和时代背景下，数学和数学教育正在经历着一场极其深刻的变革。
# 在 这样 的 技术 背景 和 时代 背景 下 ， 数学 和 数学 教育 正在 经历 着 一 场 极其 深刻 的 变革 。
# 传统计算能力的强化训练将会过时，枯燥乏味的“题海战术”应该抛弃，而对学生进行数学思想、数学方法、数学应用的教育和训练则应强化。
# 传统 计算 能力 的 强化 训练 将 会 过时 ， 枯燥 乏味 的 “ 题 海 战术 ” 应该 抛弃 ， 而 对 学生 进行 数学 思想 、 数学 方法 、 数学 应用 的 教育和 训练 则 应 强化 。
# 现代数学中的统计、概率、化归、建模、计算机仿真等内容必须尽快纳入基础教育的课程体系中，并通过教育心理学的研究和教育技术手段的更新，探索新的学习模式和教育模式，使不同年龄的学生易学、易懂、会用。
# 现代 数学 中 的 统计 、 概率 、 化 归 、 建 模 、 计算机 仿真 等 内容 必须 尽快 纳入 基础教育 的 课程 体系 中 ， 并 通过 教育 心理学 的 研究和 教育 技术 手段 的 更新 ， 探索 新 的 学习 模式 和 教育 模式 ， 使 不同 年龄 的 学生 易 学 、 易懂 、 会 用 。
# 数学与社会生活的联系更加密切，数学教育与其他学科以及生活教育的结合势在必行。
# 数学 与 社会生活 的 联系 更加 密切 ， 数学 教育 与 其他 学科 以及 生活 教育 的 结合 势在必行 。
# 传统教育注重文化的传承，现代与未来教育在文化传承的同时更注重培养人的创造性，由此实现对文化的不断超越。
# 传统 教育 注重 文化 的 传承 ， 现代 与 未来 教育 在 文化 传承 的 同时 更 注重 培 养人 的 创造性 ， 由此 实现 对 文化 的 不断 超越 。
# 文化的超越有量变也有质变，每当文化的根基发生实质性变化之时，文化的质变显然就不可避免了。
# 文化 的 超越 有 量变 也 有 质变 ， 每当 文化 的 根基 发生 实质性 变化 之 时 ， 文化 的 质变 显然 就 不可 避免 了 。
# 由此入手，才能更深刻地洞察信息时代教育改革发展的趋势与前景，这对于尽快培养出一大批能适应２１世纪信息化国际竞争环境的优秀人才，提高全体国民适应信息化社会的能力与素质都将产生极其深远的影响。
# 由此 入手 ， 才能 更 深刻 地 洞察 信息 时代 教育 改革 发展 的 趋势 与 前景 ， 这 对于 尽快 培养 出 一大批 能 适应 ２１世纪 信息化 国际 竞争 环境 的 优秀 人才 ， 提高 全体 国民 适应 信息化 社会 的 能力 与 素质 都 将 产生 极其 深远 的 影响 。
# （作者为北京师范大学未来教育研究中心主任、教授，教育学原理专业博士生导师）
# （ 作者 为 北京师范大学 未来 教育 研究 中心 主任 、 教授 ， 教育学 原理 专业 博士生 导师 ）
# 跨越文明的对话--浅述计算机与汉字文化的冲突与碰撞
# 跨越 文明 的 对话 - - 浅 述 计算机 与 汉字 文化 的 冲突 与 碰撞
# 本报记者杨健
# 本报 记者 杨健
# “换笔”引出的话题
# “ 换 笔 ” 引出 的 话题
# 在这个“告别铅与火，迎来光与电”的年代，文化人“换笔”似乎成了一种潮流。
# 在 这个 “ 告别 铅 与 火 ， 迎来 光 与 电 ” 的 年代 ， 文化人 “ 换 笔 ” 似乎 成 了 一种 潮流 。
# ５年前，历史学家庞朴买了一台学习机，开始了艰难的“换笔”。
# ５ 年前 ， 历 史学 家 庞朴 买 了 一 台 学习机 ， 开始 了 艰难 的 “ 换 笔 ” 。
# 捧着随机赠送的王码教程，花了两个礼拜总算写出一篇稿子，可到南方出差几天回来，发现本已倒背如流的口诀全忘到了九霄云外。
# 捧 着 随机 赠送 的 王码 教程 ， 花 了 两个 礼拜 总算 写出 一 篇 稿子 ， 可 到 南方 出差 几天 回来 ， 发现 本 已 倒背如流 的 口诀 全 忘 到 了 九 霄 云 外 。
# 夫人说别费劲了，花２００块钱进学习班吧。
# 夫人 说 别 费劲 了 ， 花 ２００ 块 钱 进 学习班 吧 。
# 庞朴不服气，订了份厚厚的《计算机世界》，又给王永民打了好多电话，几本人家推荐的教材红笔画过蓝笔画，“像学经典著作一般”，终于修成正果。
# 庞朴 不 服气 ， 订 了 份 厚 厚 的 《 计算机 世界 》 ， 又 给 王永民 打 了 好多 电话 ， 几本 人家 推荐 的 教材 红 笔画 过 蓝 笔画 ， “ 像 学 经典著作 一般 ” ， 终于 修 成 正果 。
# 如今问起他的感觉，言语中不无得意：“以前怕手跟不上脑子灵感飞了，现在发愁的是脑袋转得太慢了。
# 如今 问 起 他 的 感觉 ， 言语 中 不无 得意 ： “ 以前 怕 手 跟 不 上 脑子 灵感 飞 了 ， 现在 发愁 的 是 脑袋 转 得 太 慢 了 。
# ｀得心应手＇大概就是这个意思吧。”
# 大概 就是 这个 意思 吧 。 ”
# 其实令他得意的岂止于此。
# 其实 令 他 得意 的 岂止 于 此 。
# 熟人朋友的机器坏了，无论软件硬件，他都会“两肋插刀”，而且往往手到病除。
# 熟人 朋友 的 机器 坏 了 ， 无论 软件 硬件 ， 他 都会 “ 两肋插刀 ” ， 而且 往往 手到病除 。
# 至于自己的机器出了毛病，那就更是“敢作敢为”。
# 至于 自己 的 机器 出 了 毛病 ， 那 就 更 是 “ 敢 作 敢 为 ” 。
# 前段时间从一家公司买了台原装的“５８６”，接录音电话时出了毛病，捣鼓半天还是没辙，只好把电脑搬到公司去修。
# 前 段 时间 从 一家 公司 买 了 台 原装 的 “ ５８６ ” ， 接 录音 电话 时 出 了 毛病 ， 捣 鼓 半天 还是 没 辙 ， 只好 把 电脑 搬 到 公司 去 修 。
# 人家一看说，主板坏了，要换，收费６０００元；调制解调器坏了，要换，收费１２００元；另收４５０元修理费。
# 人家 一 看 说 ， 主板 坏 了 ， 要 换 ， 收费 ６０００元 ； 调制解调器 坏 了 ， 要 换 ， 收费 １２００元 ； 另 收 ４５０元 修理 费 。
# 庞朴一听，算了吧，回家后试着把连线从一个接口往另一个接口一换，成了！
# 庞朴 一 听 ， 算了 吧 ， 回家 后 试 着 把 连 线 从 一个 接口 往 另一个 接口 一 换 ， 成 了 ！
# 经过几年的磨练，庞朴对他的“笔”真可以说是摸透了。
# 经过 几年 的 磨练 ， 庞朴 对 他 的 “ 笔 ” 真 可以 说是 摸 透 了 。
# 和庞朴的潇洒劲儿比起来，其他一些人与电脑打交道的经历可就难受多了。
# 和 庞朴 的 潇洒 劲 儿 比 起来 ， 其他 一些 人与 电脑 打交道 的 经历 可 就 难受 多 了 。
# 去年某大报社宣布“告别纸与笔”，所有的稿件都要求作者输入电脑统一管理，不存入电脑的稿子一律免看。
# 去年 某 大 报社 宣布 “ 告别 纸 与 笔 ” ， 所 有的 稿件 都 要求 作者 输入 电脑 统一 管理 ， 不 存入 电脑 的 稿子 一律 免 看 。
# 这可急煞了一些老记者，尤其是有些年纪大一点的女同志，私下里直抱怨：这不是逼着我们早退休吗？
# 这 可 急 煞 了 一些 老 记者 ， 尤其是 有些 年纪 大 一点 的 女 同志 ， 私下里 直 抱怨 ： 这 不是 逼 着 我们 早 退休 吗 ？
# 问起他们与计算机的隔膜，笼而统之一个字：难。
# 问 起 他们 与 计算机 的 隔膜 ， 笼而统之 一个 字 ： 难 。
# 关于这个“难”字，后来有位叫康东日的计算机专家在他的著述中从理论高度进行了分析：从１８７７年世界上第一个英文打字培训班成立算起，西方人有了１００多年的英文键盘操作史，而５０年代开始的电脑字符处理技术，又是以英文键盘输入为依据发展起来的。
# 关于 这个 “ 难 ” 字 ， 后来 有 位 叫 康 东 日 的 计算机 专家 在 他 的 著述 中 从 理论 高度 进行 了 分析 ： 从 １８７７年 世界 上 第一个 英文 打字 培训班 成立 算 起 ， 西方人 有 了 １００多年 的 英文 键盘 操作 史 ， 而 ５０年代 开始 的 电脑 字符 处理 技术 ， 又是 以 英文 键盘 输入 为 依据 发展 起来 的 。
# 从根本上说，我们今天要用的这支智能化的“笔”，是迄今为止与人脑关系最密切的机器，可它在思维逻辑上就与以象形文字为代表的中国文化有着巨大的差异，运用起来当然就必须付出一定的代价了。
# 从 根本上 说 ， 我们 今天 要 用 的 这 支 智能 化 的 “ 笔 ” ， 是 迄今为止 与 人脑 关系 最 密切 的 机器 ， 可 它 在 思维 逻辑 上 就 与 以 象 形 文字 为 代表 的 中国文化 有着 巨大 的 差异 ， 运用 起来 当然 就 必须 付出 一定 的 代价 了 。
# 到底是专家，一语中的。
# 到底 是 专家 ， 一语 中 的 。
# 沉重的双重使命
# 沉重 的 双重 使命
# 其实，与中文用户相比，在中国进行计算机研究的人所付的代价还要大许多。
# 其实 ， 与 中文 用户 相比 ， 在 中国 进行 计算机研究 的 人所 付 的 代价 还要 大 许多 。
# 尽管有人自我炫耀地说，莱布尼茨是受了太极八卦图的启示才发明了二进制计算机，奠定了现代计算机的理论基础，也有人夸张地断言“中文是最适合计算机逻辑结构的语言”，可现状就如康先生所分析的，是西方人发明了计算机，而且到目前为止，西方文化仍然占据着计算机文化的主体。
# 尽管 有人 自我 炫耀 地 说 ， 莱布尼 茨 是 受 了 太极 八卦 图 的 启示 才 发 明了 二进 制 计算机 ， 奠定 了 现代 计算机 的 理论 基础 ， 也 有人 夸张 地 断言 “ 中文 是 最 适合 计算机 逻辑 结构 的 语言 ” ， 可 现状 就 如 康 先生 所 分析 的 ， 是 西方人 发 明了 计算机 ， 而且 到 目前 为止 ， 西方 文化 仍然 占据 着 计算机 文化 的 主体 。
# 对于中国计算机工作者来说，这一现状先天地决定了他们的双重使命：在历尽千辛万苦挤入计算机技术的核心层后，他们必须肩负起把母体文化引入学科前沿的重任，在使用上令中文习惯与计算机逻辑完美结合，使中文用户在计算机上如鱼得水，并且紧紧跟上技术进步的步伐。
# 对于 中国计算机 工作者 来说 ， 这一 现状 先 天地 决定 了 他们 的 双重 使命 ： 在 历尽 千辛万苦 挤 入 计算机技术 的 核心 层 后 ， 他们 必须 肩负 起 把 母体 文化 引入 学科 前沿 的 重任 ， 在 使用 上 令 中文 习惯 与 计算机 逻辑 完美 结合 ， 使 中文 用户 在 计算机 上 如鱼得水 ， 并且 紧 紧跟 上 技术 进步 的 步伐 。
# 对西文软件进行“汉化”翻译，并使汉字字符能够在计算机上处理，是发明ｃｃｅｄ的颜援朝、开发方正排版系统的王选等一代计算机元老的贡献。
# 的 颜 援 朝 、 开发 方正 排版 系统 的 王选 等 一代 计算机 元老 的 贡献 。
# 构筑外挂式中文平台，让优秀西文软件无须汉化即可在中文环境下使用，是“中文之星”的主要创意者王志东等一批后来者的功劳。
# 构筑 外挂 式 中文 平台 ， 让 优秀 西 文 软件 无 须汉 化 即可 在 中文 环境 下 使用 ， 是 “ 中文 之 星 ” 的 主要 创意 者 王志 东 等 一批 后 来者 的 功劳 。
# 实现多种中文内码自动识别和转换，使ｉｎｔｅｒｎｅｔ上世界各地不同内码的汉字均能在同一平台上显示，则是汪延等一些二十出头的小伙子的最新创造。
# 上 世界 各地 不同 内 码 的 汉字 均 能 在 同 一平 台上 显示 ， 则 是 汪 延 等 一些 二十 出头 的 小伙子 的 最新 创造 。
# 在四通利方公司的实验室里，刚从法国回来不久的汪延跟我谈起中文用户从“能用”到“同步用”再到“同步发展”的曲折历程，感慨万千。
# 在 四通利方公司 的 实验室 里 ， 刚 从 法国 回来 不久 的 汪 延 跟 我 谈 起 中文 用户 从 “ 能 用 ” 到 “ 同步 用 ” 再 到 “ 同步 发展 ” 的 曲折 历程 ， 感慨 万千 。
# 作为一门方兴未艾的新学科，计算机技术始终在飞速发展。
# 作为 一门 方兴未艾 的 新 学科 ， 计算机技术 始终 在 飞速 发展 。
# 而每往前走一步，都可能给中国的计算机专家们带来新的挑战，这场战斗旷日持久。
# 而 每 往前 走 一步 ， 都 可能 给 中国 的 计算机 专家 们 带来 新 的 挑战 ， 这 场 战斗 旷日持久 。
# 技术与文化的互动
# 技术 与 文化 的 互动
# 在与汪延的谈话中，我们说到了另一个值得注意的现象，那就是越来越多的人文学者进入了电脑行业。
# 在 与 汪 延 的 谈话 中 ， 我们 说到 了 另一个 值得 注意 的 现象 ， 那 就是 越来越 多 的 人文 学者 进入 了 电脑 行业 。
# 小汪本人原来就是学法律的，到法国后迷上了ｉｎｔｅｒｎｅｔ，干脆转行学起了计算机，而且一鸣惊人，独领潮流。
# ， 干脆 转 行 学 起 了 计算机 ， 而且 一鸣惊人 ， 独 领 潮流 。
# 像他这样的人在当今中国计算机界为数不少。
# 像 他 这样 的 人 在 当今 中国计算机 界 为数 不少 。
# 从科普的对象到技术发展的参与者，这种角色转换意味着一种技术与文化的互动。
# 从 科普 的 对象 到 技术 发展 的 参与 者 ， 这种 角色 转换 意味着 一种 技术 与 文化 的 互动 。
# “计算机发展到今天，其突破不仅要靠技术，更依赖于引进新的思想。”
# “ 计算机 发展 到 今天 ， 其 突破 不仅 要 靠 技术 ， 更 依赖 于 引进 新 的 思想 。 ”
# 据说ｗｉｎｄｏｗｓ９５推出前，考虑到低性能电脑安装它的时间很长，微软公司曾向心理学家请教，怎样在安装等待过程中设计出活动的画面才能让用户不致焦躁。
# ｏ ｗ ｓ ９５ 推出 前 ， 考虑 到 低 性能 电脑 安装 它 的 时间 很 长 ， 微软公司 曾 向 心理学 家 请教 ， 怎样 在 安装 等待 过程 中 设计 出 活动 的 画面 才能 让 用户 不致 焦躁 。
# 而许多电子出版物的策划，已经无法离开人文社科专家的支持。
# 而 许多 电子 出版物 的 策划 ， 已经 无法 离开 人文 社科 专家 的 支持 。
# 在我国，因为中西文化的差异在计算机应用上反映得格外典型，普及和发展计算机技术的人更是对“中国特色”反复揣摩，社会、文化心理方面的研究达到了相当的高度。
# 在 我国 ， 因为 中西 文化 的 差异 在 计算机应用 上 反映 得 格外 典型 ， 普及 和 发展 计算机技术 的 人 更 是 对 “中国 特色 ” 反复 揣 摩 ， 社会 、 文化 心理 方 面的 研究 达到 了 相当 的 高度 。
# 从电脑学习班的普及到教育软件的火爆，从中文打字机的风靡到中文学习机的商业奇迹，细窥其中的奥妙，有的并非靠技术取胜，而是更多地适应了中国用户的文化习惯和消费心理。
# 从 电脑 学习班 的 普及 到 教育 软件 的 火爆 ， 从 中文 打字机 的 风靡 到 中文 学习机 的 商业 奇迹 ， 细 窥 其中 的 奥妙 ， 有的 并非 靠 技术 取胜 ， 而是 更 多 地 适应 了 中国 用户 的 文化 习惯 和 消费 心理 。
# 而大量“看图学计算机”教材的出现，和蔡志忠的漫画诸子相映成趣，掀起了一股成人“看图识字”的出版潮，到后来竟说不清是谁影响了谁。
# 而 大量 “ 看 图 学 计算机 ” 教材 的 出现 ， 和 蔡 志 忠 的 漫画 诸子 相映成趣 ， 掀起 了 一股 成人 “ 看 图 识字 ” 的 出版 潮 ， 到 后来 竟 说不清 是 谁 影响 了 谁 。
# 在日常生活中，像“软件”、“硬件”、“死循环”一类的新词充实了我们的语言库。
# 在 日常生活 中 ， 像 “ 软件 ” 、 “ 硬件 ” 、 “ 死 循环 ” 一类 的 新 词 充实 了 我们 的 语言 库 。
# 而计算机造词功能的运用，形成了一种被称为“语词传染”的新现象：如果有人在电脑里造出了一个错误的词，所有使用该电脑的人都会出现同一错误，而且防不胜防。
# 而 计算机 造 词 功能 的 运用 ， 形成 了 一种 被 称为 “ 语词 传染 ” 的 新 现象 ： 如果 有人 在 电脑 里 造 出 了 一个 错误 的 词 ， 所有 使用 该 电脑 的 人 都会 出现 同一 错误 ， 而且 防不胜防 。
# 至于计算机的使用对学生书法、笔顺、发音的影响，更是教育学家关心的话题。
# 至于 计算机 的 使用 对 学生 书法 、 笔 顺 、 发音 的 影响 ， 更 是 教育学 家 关心 的 话题 。
# 再往远些看，随着汉字识别和语音识别技术的发展，中文计算机用户将跨越语言差异的鸿沟，在录入上走向中西文求同的道路。
# 再 往 远 些 看 ， 随着 汉字 识别 和 语音 识别 技术 的 发展 ， 中文 计算机 用户 将 跨越 语言 差异 的 鸿 沟 ， 在 录入 上 走向 中西 文 求同 的 道路 。
# 而计算机翻译系统与现代汉语分析相辅相成，正推动着人工智能科学的前进……
# 而 计算机 翻译 系统 与 现代汉语 分析 相辅相成 ， 正 推动 着 人工智能 科学 的 前进 … …
# 每跨过一道障碍，人们都会发现一片新的开阔地，每经过一次剧烈的碰撞，都将激起一团耀眼的火花，这就是崭新的计算机技术和古老的中华文化的对话。
# 每 跨过 一道 障碍 ， 人们 都会 发现 一片 新 的 开阔地 ， 每 经过 一次 剧烈 的 碰撞 ， 都 将 激起 一团 耀眼 的 火花 ， 这就是 崭新 的 计算机技术 和 古老 的 中华文化 的 对话 。

# %%
# 使用trie树采用最大匹配算法分词
test_data = pd.read_csv(test_path)
data_list = test_data['sentence'].tolist()


# print(data_list)
def add_spaces_to_numbers(sen):
    pattern = re.compile(r'\d+％')
    matches = pattern.findall(sen)
    for match in matches:
        sen = sen.replace(match, f' {match} ')
    return sen


# # 双向最大匹配算法
# def bi_max_match(sen):
#     sen = sen.strip()
#     sen = add_spaces_to_numbers(sen)
#     sen = sen.split()
#     result = []
#     for word in sen:
#         if trie.search(word):
#             result.append(word)
#         else:
#             left = 0
#             right = len(word)
#             while left < right:
#                 if trie.search(word[left:right]):
#                     result.append(word[left:right])
#                     left = right
#                     right = len(word)
#                 else:
#                     right -= 1
#     return result # 返回分词结果

# 正向最大匹配算法
def max_match(sen):
    sen = sen.strip()
    # sen = add_spaces_to_numbers(sen)
    sen = sen.split()
    result = []
    for word in sen:
        if trie.search(word):
            result.append(word)
        else:
            left = 0
            right = len(word)
            while left < right:
                if trie.search(word[left:right]):
                    result.append(word[left:right])
                    right = left
                    left = 0
                else:
                    left += 1

    # return result  # 返回分词结果
    return result[::-1]  # 返回分词结果


res_dict = {}

for i in range(len(data_list)):
    sen = data_list[i]
    # sen = remove_chinese_punctuation(sen)
    print(''.join(sen))
    sen = max_match(''.join(sen))
    # 将列表转换为字符串，每个元素之间用空格隔开
    sen = ' '.join(sen)
    print(sen)
    result = transfer_code.transfer(sen)
    # print(result)
    res_dict[i] = result

#将res_dict写入csv文件
import csv

with open('result1.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['id', 'expected'])
    for key, value in res_dict.items():
        writer.writerow([key + 1, value])
# Out:
# 扬帆远东做与中国合作的先行
# 扬帆 远东 做 与 中国 合作 的 先行
# 希腊的经济结构较特殊。
# 希腊 的 经济 结构 较 特殊 。
# 海运业雄踞全球之首，按吨位计占世界总数的１７％。
# 辛 志 强 朋友 ：
# 年轻人谋求自我发展，期望实现自我价值是一件好事情，但怎样才叫实现自我价值呢？
# 年轻人 谋求 自我 发展 ， 期望 实现 自我 价值 是 一件 好 事情 ， 但 怎样 才 叫 实现 自我 价值 呢 ？
# 我认为人生价值的实现应该有两方面的内容：一是个人对社会的贡献，二是社会对个人的尊重和满足。
# 我 认为 人生 价值 的 实现 应该 有 两方 面的 内容 ： 一是 个人 对 社会 的 贡献 ， 二是 社会 对 个人 的 尊重 和 满足 。
# 这两点是相辅相成的。
# 这 两点 是 相辅相成 的 。
# 青年人在确定自己的人生坐标时，一定要找到人生价值和社会价值的切合点。
# 青年人 在 确定 自己 的 人生 坐标 时 ， 一定 要 找到 人生 价值 和 社会 价值 的 切合 点 。
# 又到了毕业生找工作的时候，很多本科生、研究生都希望进国家大机关和各种大公司，这本无可厚非。
# 又 到 了 毕业生 找 工作 的 时候 ， 很多 本科生 、 研究生 都 希望 进 国家大 机关 和 各种 大 公司 ， 这 本 无可厚非 。
# 这些单位起点高，待遇好，一旦有机会可以干出一番大事业。
# 这些 单位 起点 高 ， 待遇 好 ， 一旦 有 机会 可以 干 出 一番 大 事业 。
# 但我们也必须看到，这些单位的位置基本已满，很多学生即使分配进去，也未必能发挥自己的才干，无形中形成了一种人力资源的浪费。
# 但 我们 也 必须 看到 ， 这些 单位 的 位置 基本 已 满 ， 很多 学生 即使 分配 进去 ， 也 未必 能 发挥 自己 的 才干 ， 无形中 形成 了 一种 人力资源 的 浪费 。
# 几年下来，将所学的知识忘光了，将原有的锋芒磨没了。
# 几年 下来 ， 将 所 学 的 知识 忘 光 了 ， 将 原 有的 锋芒 磨 没 了 。
# 社会对一个人自身价值的评价，并不在于他所处的职位的高低，而是看他到底为社会做了什么有价值的事情，是不是充分发挥了他的潜能，做了自己力所能及的事情。
# 社会 对 一 个人 自身 价值 的 评价 ， 并不 在于 他 所 处 的 职位 的 高低 ， 而是 看 他 到底 为 社会 做 了 什么 有 价值 的 事情 ， 是不是 充分 发挥 了 他 的 潜能 ， 做 了 自己 力所能及 的 事情 。
# 而作为个人，自己当然更清楚自我价值是否得到了实现。
# 而 作为 个人 ， 自己 当然 更 清楚 自我 价值 是否 得到 了 实现 。
# 我的一位学生毕业后没有留在北京，而是回苏州一个乡去工作，负责开发区工业园的策划规划，一年做下来，收获颇大，甚至感到所学知识已不够用，需要重回学校补充知识。
# 我 的 一 位 学生 毕业 后 没有 留 在 北京 ， 而是 回 苏州 一个 乡 去 工作 ， 负责 开发区 工业 园 的 策划 规划 ， 一年 做 下来 ， 收获 颇 大 ， 甚至 感到 所 学 知识 已 不 够用 ， 需要 重 回 学校 补充 知识 。
# 和那些分在大机关无法施展才华的同学相比，这位同学活得更充实、更有价值。
# 和 那些 分 在 大 机关 无法 施展 才华 的 同学 相比 ， 这 位 同学 活 得 更 充实 、 更有 价值 。
# 有的同学也许会将自我价值的实现和当今的社会评价体系联系起来看。
# 有的 同学 也 许会 将 自我 价值 的 实现 和 当今 的 社会 评价 体系 联系 起 来看 。
# 譬如电视上频频露面的党政要员、社会名流、企业家、总经理，极容易刺激一个人的政治抱负、财富占有欲，但这种评价体系和现实是有差距的。
# 譬如 电视 上 频频 露 面的 党政 要员 、 社会名流 、 企业家 、 总经理 ， 极 容易 刺激 一 个人 的 政治 抱负 、 财富 占有 欲 ， 但 这种 评价 体系 和 现实 是 有 差距 的 。
# 尤其是通向成功的路不是平坦的，如同一条大船为了航行，必要时要多走一些曲线，但从长远的观点看，这条线还是直的。
# 尤其是 通向 成功 的 路 不是 平坦 的 ， 如同 一条 大船 为了 航行 ， 必要 时 要 多 走 一些 曲线 ， 但 从 长远 的 观点 看 ， 这 条 线 还是 直 的 。
# 两点之间直线最短，但更多的人是走曲线的。
# 两点 之间 直线 最 短 ， 但 更 多 的 人 是 走 曲线 的 。
# 所以我经常鼓励我的学生们去艰苦的地方、去祖国最需要的地方工作。
# 所以 我 经常 鼓励 我 的 学生 们 去 艰苦 的 地方 、 去 祖国 最 需要 的 地方 工作 。
# 很多成功的人都是从最基层做起的。
# 很多 成功 的 人 都是 从 最 基层 做 起 的 。
# 从社会学的角度讲，一个人总是从自己能胜任的工作做起，一直做到自己终不能胜任的工作。
# 从 社会学 的 角度 讲 ， 一 个人 总是 从 自己 能 胜任 的 工作 做 起 ， 一直 做到 自己 终 不能 胜任 的 工作 。
# 社会所提供的机会，尤其是做大事的机会是有限的，但做一些力所能及的小事的机会却很多。
# 社会 所 提供 的 机会 ， 尤其是 做 大事 的 机会 是 有限 的 ， 但 做 一些 力所能及 的 小事 的 机会 却 很多 。
# 有些大学生眼高手低，不屑于做小事情。
# 有些 大学生 眼高手低 ， 不屑于 做 小 事情 。
# 其实小事情带给人的价值会更被人看重。
# 其实 小 事情 带 给 人 的 价值 会 更 被 人 看重 。
# 社会对个人的尊重总是体现在你所创造的价值中，而自我价值的实现本身就是社会对你的贡献的回报，同时也应该是你的满足所在。
# 社会 对 个人 的 尊重 总是 体 现在 你 所 创造 的 价值 中 ， 而 自我 价值 的 实现 本身 就是 社会 对 你 的 贡献 的 回报 ， 同时 也 应该 是 你 的 满足 所在 。
# 辛志强朋友，到边疆工作虽然苦一些，并有违父母的意愿，但如果施展才能的空间很大，而且能充分发挥所学专长，不妨一试。
# 辛 志 强 朋友 ， 到 边疆 工作 虽然 苦 一些 ， 并 有 违 父母 的 意愿 ， 但 如果 施展 才能 的 空间 很 大 ， 而且 能 充分 发挥 所 学 专长 ， 不妨 一 试 。
# （王思斌）
# ）
# 振奋精神有所作为
# 振奋 精神 有所作为
# 陈耀朋友：
# 陈耀 朋友 ：
# 看了你的信，我被你信中流露出的凄苦、迷惘以及热切求助的情绪触动了。
# 看 了 你 的 信 ， 我 被 你 信 中流 露出 的 凄 苦 、 迷惘 以及 热切 求助 的 情绪 触动 了 。
# 我在日常编辑工作中，还收到不少类似你这样的青年人的来信。
# 我 在 日常 编辑 工作 中 ， 还 收到 不少 类似 你 这样 的 青年人 的 来信 。
# 青年人自尊好胜，勇于进取，但往往受家庭、社会环境的羁绊，人生道路上遇到的挫折也多。
# 青年人 自尊 好 胜 ， 勇于 进取 ， 但 往往 受 家庭 、 社会 环境 的 羁绊 ， 人生 道 路上 遇到 的 挫折 也 多 。
# 挫折多了，不能正确对待，久而久之，便容易心灰意懒，一蹶不振。
# 不振 。
# 其实，外在的艰难困苦并不可怕，可怕的是在这一年龄段，不少青年人经受不起失败与挫折，最后自己击败了自己。
# 其实 ， 外在 的 艰难 困苦 并不 可怕 ， 可怕 的 是 在 这一 年龄 段 ， 不少 青年人 经受 不起 失败 与 挫折 ， 最后 自己 击败 了 自己 。
# 我这封信无法给你指出一条轻松顺利的人生之路，只是想对你目前的困惑心理作些分析，并与你探讨一些摆脱困境的方法。
# 我 这 封 信 无法 给 你 指出 一条 轻松 顺利 的 人生 之 路 ， 只是 想 对 你 目前 的 困惑 心理 作 些 分析 ， 并 与 你 探讨 一些 摆脱 困境 的 方法 。
# 你信中认为是家庭的厄运、周围的环境控制着你，使你不能真正地生活，难以有所作为。
# 你 信 中 认为 是 家庭 的 厄运 、 周围 的 环境 控制 着 你 ， 使 你 不能 真正 地 生活 ， 难以 有所作为 。
# 你家庭的遭遇确实令人同情，但你也要看到，这种境遇并不是你家独有的。
# 你 家庭 的 遭遇 确实 令人 同情 ， 但 你 也 要 看到 ， 这种 境遇 并不是 你 家 独 有的 。
# 我们每个人都要面临生存斗争，任何人只要活在世上，只要同其他人进行社会交往，就会遇到相似的问题。
# 我们 每个人 都 要 面临 生存 斗争 ， 任 何人 只要 活 在 世上 ， 只要 同 其 他人 进行 社会 交往 ， 就 会 遇到 相 似的 问题 。
# 天灾人祸、生老病死、贫穷富贵都是现实客观生活中存在的，意见分歧、矛盾冲突更是时常伴随在人们左右。
# 天灾人祸 、 生老病死 、 贫穷 富贵 都是 现实 客观 生活 中 存在 的 ， 意见 分歧 、 矛盾 冲突 更 是 时常 伴随 在 人们 左右 。
# 父母的年迈多病，夫妻间的龃龉，失去亲人的哀伤，每个人或多或少都有体会。
# 父母 的 年迈 多 病 ， 夫妻 间 的 龃龉 ， 失去 亲人 的 哀 伤 ， 每个人 或多或少 都 有 体会 。
# 一个人没有遇到这种不幸，也会遇到另一种变故。
# 一 个人 没有 遇到 这种 不幸 ， 也 会 遇到 另 一种 变 故 。
# 一个人在某件事上顺利一些，在另一件事上可能会碰壁。
# 一 个人 在 某 件 事 上 顺利 一些 ， 在 另 一件 事 上 可能 会 碰壁 。
# 不少人遇到打击和挫折时，怨恨生活不公平。
# 不少 人 遇到 打击 和 挫折 时 ， 怨恨 生活 不 公平 。
# 我们常常很难说清楚生活中到底是苦多还是乐多，只是可以肯定苦对人的精神打击最大。
# 我们 常常 很难说 清楚 生活 中 到底 是 苦 多 还是 乐 多 ， 只是 可以 肯定 苦 对 人 的 精神 打击 最大 。
# 意志薄弱的人最愿意诉苦，这可以赢得别人的关注与同情，从而自我怜悯，找到无所事事的借口。
# 意志 薄弱 的 人 最 愿意 诉苦 ， 这 可以 赢得 别人 的 关注 与 同情 ， 从而 自我 怜悯 ， 找到 无所事事 的 借口 。
# 你说，你的家庭的各种问题毕竟还没彻底解决，心情始终轻松不起来。
# 你 说 ， 你 的 家庭 的 各种 问题 毕竟 还 没 彻底 解决 ， 心情 始终 轻松 不 起来 。
# 等待谁来解决呢？
# 等待 谁 来 解决 呢 ？
# 如果只是把问题归咎于别人、家庭，不做努力，不冒风险，只是着急、苦恼，你家的问题可能会越搞越糟，你自己的境况也就难以改变。
# 如果 只是 把 问题 归咎 于 别人 、 家庭 ， 不 做 努力 ， 不 冒 风险 ， 只是 着急 、 苦恼 ， 你 家 的 问题 可能 会 越 搞 越 糟 ， 你 自己 的 境况 也就 难以 改变 。
# 与其怨天尤人，不如接受这种现实，正视这种现实，不使自己陷于其中，并用自己的智慧与之进行积极斗争。
# 与其 怨天尤人 ， 不如 接受 这种 现实 ， 正视 这种 现实 ， 不 使 自己 陷于 其中 ， 并用 自己 的 智慧 与 之 进行 积极 斗争 。
# 你是个有抱负的青年，好学上进，期待着为社会多做贡献，实现自己的价值。
# 你 是 个 有 抱负 的 青年 ， 好学 上进 ， 期待 着 为 社会 多 做 贡献 ， 实现 自己 的 价值 。
# 迫于家庭各种矛盾的压力，你的内心失去平衡，生活乱了章法，不但原有的才干得不到施展，潜力不能充分挖掘，而且产生了自我挫败的自卑心理，失去了各种追求的勇气。
# 迫于 家庭 各种 矛盾 的 压力 ， 你 的 内心 失去 平衡 ， 生活 乱 了 章法 ， 不但 原 有的 才干 得不 到 施展 ， 潜力 不能 充分 挖掘 ， 而且 产生 了 自我 挫败 的 自卑 心理 ， 失去 了 各种 追求 的 勇气 。
# 要改变这种局面，首先要振奋精神，不能老像心里长了草似的，焦虑，急躁，要使自己冷静下来，镇定下来，学会主宰自己，变外部控制为内部控制。
# 要 改变 这种 局面 ， 首先 要 振奋 精神 ， 不能 老 像 心里 长 了 草 似的 ， 焦虑 ， 急躁 ， 要 使 自己 冷静 下来 ， 镇定 下来 ， 学会 主宰 自己 ， 变 外部 控制 为 内部 控制 。
# 也许你一时想不出办法解决某一具体困难，但你要努力摆脱消极情绪，做好对付生活的准备。
# 也许 你 一时 想 不出 办法 解决 某 一 具体 困难 ， 但 你 要 努力 摆脱 消极 情绪 ， 做好 对付 生活 的 准备 。
# 你的当务之急，是改变家庭的经济状况。
# 你 的 当务之急 ， 是 改变 家庭 的 经济 状况 。
# 除了年迈的父亲，你似乎再没有兄弟，你就是家中的男子汉、顶梁柱，你应该意识到这一点，不要害怕，不要逃避，勇敢地承担起你的责任。
# 除了 年迈 的 父亲 ， 你 似乎 再 没有 兄弟 ， 你 就是 家 中 的 男子汉 、 顶梁柱 ， 你 应该 意识到 这 一点 ， 不要 害怕 ， 不要 逃避 ， 勇敢 地 承担 起 你 的 责任 。
# 紧紧围绕家中的严峻现实想办法，首先注意不给自己定下不现实的目标。
# 紧紧 围绕 家 中 的 严峻 现实 想 办法 ， 首先 注意 不 给 自己 定 下不 现实 的 目标 。
# 应该正确地认识自己的能力，理智地分析各种主客观因素，扎扎实实地制订循序渐进、切实可行的计划，决不好高骛远、眼高手低。
# 应该 正确 地 认识 自己 的 能力 ， 理智 地 分析 各种 主客观 因素 ， 扎扎实 实地 制订 循序渐进 、 切实可行 的 计划 ， 决 不好 高 骛 远 、 眼高手低 。
# 同时要认识到，要干成一件事，为了将来的甜，一定要吃眼前的苦，要有这个思想准备，有坚定的意志。
# 同时 要 认识 到 ， 要 干 成 一件 事 ， 为了 将来 的 甜 ， 一定 要 吃 眼前 的 苦 ， 要 有 这个 思想准备 ， 有 坚定 的 意志 。
# 无论碰到什么困难和挫折，都应提醒自己：我不能胡思乱想，事情是有希望的，出现失误是允许的，暂时心绪不宁也是正常的，一切都会过去。
# 无论 碰到 什么 困难 和 挫折 ， 都 应 提醒 自己 ： 我 不能 胡 思 乱 想 ， 事情 是 有 希望 的 ， 出现 失误 是 允许 的 ， 暂时 心绪不宁 也是 正常 的 ， 一切 都会 过去 。
# 要看到美好的前景，消极的意念只能用积极的、现实的行动来解除。
# 要 看到 美好 的 前景 ， 消极 的 意念 只能 用 积极 的 、 现实 的 行动 来 解除 。
# 你考上了乡里的临时通讯员，就应该利用这个机会好好干，多写些文章，多投些稿子，一来可以求得进一步发展，二来也可挣些稿费补贴家用。
# 你 考上 了 乡里 的 临时 通讯员 ， 就 应该 利用 这个 机会 好好 干 ， 多 写 些 文章 ， 多 投 些 稿子 ， 一来 可以 求得 进一步 发展 ， 二来 也 可 挣 些 稿费 补贴 家用 。
# 你也可以有意识地学些农业科技知识，帮助父亲种好田，这也是改善家庭状况的一条路子。
# 你 也 可以 有意识 地学 些 农业 科技 知识 ， 帮助 父亲 种 好 田 ， 这 也是 改善 家庭 状况 的 一条 路子 。
# 总之，要鼓起勇气，不怕失败，大胆尝试，相信你脚下的路会越走越宽广。
# 总之 ， 要 鼓起 勇气 ， 不怕 失败 ， 大胆 尝试 ， 相信 你 脚下 的 路 会 越 走 越 宽广 。
# 有位学者说过：“伟人之所以伟大，关键在于：当他与别人共处逆境时，别人失去理智，他则下决心实现自己的目标。”
# 有 位 学者 说 过 ： “ 伟人 之所以 伟大 ， 关键 在于 ： 当 他 与 别人 共处 逆境 时 ， 别人 失去 理智 ， 他 则 下决心 实现 自己 的 目标 。 ”
# 我们通过反复磨练自己，不断培养抵御挫折的能力，也可以成为生活中的强者。
# 我们 通过 反复 磨练 自己 ， 不断 培养 抵御 挫折 的 能力 ， 也 可以 成为 生活 中 的 强者 。
# 陈耀朋友，愿你及早征服茫然、苦恼、绝望的情绪，勇敢地接受生活的考验，做一个精神愉快、有所作为的青年。
# 陈耀 朋友 ， 愿 你 及早 征服 茫然 、 苦恼 、 绝望 的 情绪 ， 勇敢 地 接受 生活 的 考验 ， 做 一个 精神 愉快 、 有所作 为的 青年 。
# 希望能听到你的好消息。
# 希望 能 听到 你 的 好消息 。
# 真情一片为孤残
# 真情 一片 为 孤残
# 山东桓台县起凤镇穆寨村妇女穆玲英，十七年如一日精心照料一位孤残老人的故事，感动了四乡八镇的乡亲们。
# 山东 桓台县 起 凤 镇 穆 寨 村 妇女 穆 玲 英 ， 十七年 如 一日 精心 照料 一 位 孤残 老人 的 故事 ， 感动 了 四乡 八 镇 的 乡亲 们 。
# １９８０年夏天的一个下午，穆寨村年近６０岁的孤寡老人穆守家拄着拐杖挑水。
# １９８０年 夏天 的 一个 下午 ， 穆 寨 村 年 近 ６０岁 的 孤寡老人 穆 守 家 拄 着 拐杖 挑水 。
# 因以前患过青光眼病，穆守家的左眼失明，右眼勉强能看到近处的东西。
# 因 以前 患 过 青光 眼病 ， 穆 守 家 的 左 眼 失明 ， 右 眼 勉强 能 看到 近处 的 东西 。
# 年仅１６岁的穆玲英见状，二话没说，接过老人肩上的担子，替他挑回家。
# 年 仅 １６岁 的 穆 玲 英 见状 ， 二话没说 ， 接 过 老人 肩 上 的 担子 ， 替 他 挑 回家 。
# 穆守家两间低矮的小屋里，蛛丝遍布，连个下脚的地方都没有。
# 穆 守 家 两间 低矮 的 小屋 里 ， 蛛丝 遍布 ， 连 个 下脚 的 地方 都 没有 。
# 玲英又是二话没说，迅速将老人的被褥叠好，把锅、碗、瓢、盆洗了，将地面扫干净，然后又把老人的脏衣服抱回家洗晒。
# 玲 英 又是 二话没说 ， 迅速 将 老人 的 被褥 叠 好 ， 把 锅 、 碗 、 瓢 、 盆 洗 了 ， 将 地面 扫 干净 ， 然后 又 把 老人 的 脏 衣服 抱 回家 洗 晒 。
# 当时，小穆便下了决心：一定要将老人侍奉好，让他过上舒坦日子。
# 当时 ， 小 穆 便 下 了 决心 ： 一定 要 将 老人 侍奉 好 ， 让 他 过 上 舒坦 日子 。
# 以后，她每天都要到老人家里，打油、称盐、换面、挑水、做饭、洗衣……春末，她就为老人吊好蚊帐；不到冬天，她就给老人运去煤和烧土。
# 以后 ， 她 每 天都 要 到 老人 家里 ， 打 油 、 称 盐 、 换 面 、 挑水 、 做饭 、 洗衣 … … 春 末 ， 她 就 为 老人 吊 好 蚊帐 ； 不 到 冬天 ， 她 就 给 老人 运 去 煤 和 烧 土 。
# 穆守家老人喝不惯本村的浅井水，玲英就瞒着他去两公里外的起凤村挑深井水，直到本村也打了深水井。
# 穆 守 家 老人 喝 不惯 本 村 的 浅 井水 ， 玲 英 就 瞒 着 他 去 两公 里外 的 起 凤 村 挑 深 井水 ， 直到 本 村 也 打 了 深 水井 。
# 根据近两年的接触，玲英感到老人一个人在家时闷得慌，便盘算着给他买一个收音机。
# 根据 近 两年 的 接触 ， 玲 英 感到 老人 一 个人 在家 时 闷得慌 ， 便 盘算 着 给 他 买 一个 收音机 。
# 为了凑收音机的钱，她在自己住房的墙上砸个钉子，每天晚饭后就掐玉米辫。
# 为了 凑 收音机 的 钱 ， 她 在 自己 住房 的 墙 上 砸 个 钉子 ， 每天 晚 饭后 就 掐 玉米 辫 。
# 那时，一挂玉米辫能卖五角钱。
# 那时 ， 一 挂 玉米 辫 能 卖 五角钱 。
# 为了尽快凑够钱，玲英每天都忙到深夜。
# 为了 尽快 凑 够 钱 ， 玲 英 每 天都 忙 到 深夜 。
# 等攒到３０元钱时，玲英跑到县城为老人捧回一个收音机。
# 等 攒 到 ３０元钱 时 ， 玲 英 跑 到 县城 为 老人 捧 回 一个 收音机 。
# 那时，收音机在农村还不普及，穆大爷家有了收音机后，每天都有很多老人聚在一块听戏。
# 那时 ， 收音机 在 农村 还 不 普及 ， 穆 大爷 家 有 了 收音机 后 ， 每 天都 有 很多 老人 聚 在 一块 听戏 。
# 人老了格外看重自己的生日。
# 人 老 了 格外 看重 自己 的 生日 。
# 十多年来，每逢农历九月二十八老人生日这天，玲英便带上蒸好的馒头、包子、“寿桃”和酒、糖、茶，给老人祝寿。
# 十 多年来 ， 每逢 农历 九月 二十八 老人 生日 这 天 ， 玲 英 便 带 上 蒸 好 的 馒头 、 包子 、 “ 寿 桃 ” 和 酒 、 糖 、 茶 ， 给 老人 祝寿 。
# 她斟上一杯酒，给老人端起来，看着他喝下去，然后陪着老人唠嗑。
# 她 斟 上一 杯 酒 ， 给 老人 端 起来 ， 看 着 他 喝 下去 ， 然后 陪 着 老人 唠嗑 。
# 农村实行生产责任制后，穆守家老人被村里作为五保户照顾，每年供应他２５０公斤小麦，每月发７元钱的生活费。
# 农村 实行 生产责任制 后 ， 穆 守 家 老人 被 村里 作为 五保户 照顾 ， 每年 供应 他 ２ ５０公斤 小麦 ， 每月 发 ７元钱 的 生活费 。
# 虽然有这些粮食和钱，但没有人照顾，老人生活依然难以自理。
# 虽然 有 这些 粮食 和 钱 ， 但 没 有人 照顾 ， 老人 生活 依然 难以 自理 。
# 这时，玲英的哥哥为她在城里找了一份工作。
# 这时 ， 玲 英 的 哥哥 为 她 在 城里 找 了 一 份 工作 。
# 玲英思前想后，对哥哥说：“我不忍心扔下穆大爷不管啊！”
# 玲 英 思 前 想 后 ， 对 哥哥 说 ： “我 不 忍心 扔下 穆 大爷 不管 啊 ！ ”
# 玲英打消了进城工作的念头，办了个体营业证，在农村经营布匹，上午赶集卖布，下午到老人家干活。
# 玲 英 打消 了 进城 工作 的 念头 ， 办 了 个体 营业 证 ， 在 农村 经营 布 匹 ， 上午 赶集 卖 布 ， 下午 到 老人家 干活 。
# 男大当婚，女大当嫁。
# 男 大 当 婚 ， 女大 当 嫁 。
# 由于一门心思扑在照料老人上，玲英迟迟没找对象。
# 由于 一门心思 扑 在 照料 老人 上 ， 玲 英 迟迟 没 找 对象 。
# 她表示，为了婚后不影响照顾老人，她决心不嫁远村郎，而且要求未来的丈夫同她一道挑起照顾穆大爷的担子。
# 她 表示 ， 为了 婚 后不 影响 照顾 老人 ， 她 决 心不 嫁 远 村 郎 ， 而且 要求 未来 的 丈夫 同 她 一道 挑起 照顾 穆 大爷 的 担子 。
# １９８６年初，玲英结婚了。
# １９８６ 年初 ， 玲 英 结婚 了 。
# 结婚前一天，玲英全家人把穆守家老人请到家里来做客，吃完饭后，玲英把老人送回家，又一次为老人整理床铺、洗刷锅碗。
# 何怀宏，哲学博士，１９５４年生，江西清江人，现为中国艺术研究院中国文化研究所研究员。
# 何 怀 宏 ， 哲学 博士 ， １９５４年 生 ， 江西 清 江人 ， 现 为 中国艺术研究院 中国文化 研究所 研究员 。
# 著作有《若有所思》、《生命的沉思》、《契约伦理与社会正义》、《良心论》、《世袭社会及其解体》、《珍重生命》、《心灵瞬间》，另有《伦理学体系》、《正义论》等译著九部，发表论文、散文数十篇。
# 著作 有 《 若 有所 思 》 、 《 生命 的 沉思 》 、 《 契约 伦理 与 社会 正义 》 、 《 良心 论 》 、 《 世袭 社会 及其 解体 》 、 《 珍重 生命 》 、 《 心灵 瞬间 》 ， 另 有 《 伦理学 体系 》 、 《 正义 论 》 等 译著 九 部 ， 发表 论文 、 散文 数十篇 。
# 鲁莹朋友：
# 鲁 莹 朋友 ：
# 你遇到的问题具有某种普遍意义，我不是法律专家，只能从伦理的角度提供一点参考意见。
# 你 遇到 的 问题 具有 某 种 普遍 意义 ， 我 不是 法律 专家 ， 只能 从 伦理 的 角度 提供 一点 参考 意见 。
# 我想这种道德上正当与否的问题要比违法与否的问题更为重要，有关违法的追究只有在造成严重后果、有人起诉的情况下才会发生，而道德的追问则在任何情况下都会发生。
# 我 想 这种 道德 上 正当 与否 的 问题 要 比 违法 与否 的 问题 更为 重要 ， 有关 违法 的 追究 只有 在 造成 严重 后果 、 有人 起诉 的 情况 下 才 会 发生 ， 而 道德 的 追问 则 在 任何 情况 下 都会 发生 。
# 你的问题可以更一般地表述为：我们是否能以某种不正当的方式反对一种在我们看来是严重的不公正，哪怕我们所采取的这种不当方式是相对轻微的、不太重要的。
# 你 的 问题 可以 更 一般 地 表述 为 ： 我们 是否 能 以 某 种 不 正当 的 方式 反对 一种 在 我们 看来 是 严重 的 不 公正 ， 哪怕 我们 所 采取 的 这种 不当 方式 是 相对 轻微 的 、 不 太 重要 的 。
# 一般而言，私下看别人的日记是不道德的行为，而利用日记材料就更不能不极其谨慎了。
# 一般而言 ， 私下 看 别人 的 日记 是 不道德 的 行为 ， 而 利用 日记 材料 就 更 不能不 极其 谨慎 了 。
# 当人们想直接依据私人日记所提供的材料来采取行动时，不能不仔细考虑这一行动所关涉的各个方面，比方说：公布这些事实将对日记主人及其他被涉及者带来何种影响？
# 当 人们 想 直接 依据 私人 日记 所 提供 的 材料 来 采取 行动 时 ， 不能不 仔细 考虑 这一 行动 所 关涉 的 各个 方面 ， 比方 说 ： 公布 这些 事实 将 对 日记 主人 及 其他 被 涉及 者 带来 何种 影响 ？
# 不同当事人在这一事件中应各负何种责任？
# 不同 当事人 在 这一 事件 中 应 各负 何种 责任 ？
# 事情的性质和程度究竟如何？
# 事情 的 性质 和 程度 究竟 如何 ？
# 这一不公正是否严重和紧迫到必须立即采取这一行动？
# 这 一不 公正 是否 严重 和 紧迫 到 必须 立即 采取 这一 行动 ？
# 还有这些材料是否完全确实？
# 还有 这些 材料 是否 完全 确实 ？
# 等等。
# 等等 。
# 就你所谈的这件事来说，你看同学日记是偶然的、无意的，而且，我赞赏你对有的人在发展党员问题上所表现出来的不公和营私行为的真诚义愤。
# 就 你 所 谈 的 这 件 事 来说 ， 你 看 同学 日记 是 偶然 的 、 无意 的 ， 而且 ， 我 赞赏 你 对 有的 人 在 发展 党员 问题 上 所 表现 出来 的 不公 和 营私 行 为的 真诚 义愤 。
# 你通过正常渠道向校领导反映情况，并没有把日记内容随意传播扩散，这种做法是可以理解的。
# 你 通过 正常 渠道 向 校 领导 反映 情况 ， 并 没有 把 日记 内容 随意 传播 扩散 ， 这种 做法 是 可以 理解 的 。
# 不过，如果在你看过日记尚未采取任何行动时，我也许会建议你直接和日记的主人谈谈，首先承认自己私下看日记的不当（哪怕对方暂时不能谅解，自己这样做也需很大的勇气），同时指出对方的错误，然后再进一步考虑是否采取其他行动。
# 不过 ， 如果 在 你 看 过 日记 尚未 采取 任何 行动 时 ， 我 也 许会 建议 你 直接 和 日记 的 主人 谈 谈 ， 首先 承认 自己 私下 看 日记 的 不当 （ 哪怕 对方 暂时 不能 谅解 ， 自己 这样 做 也 需 很 大 的 勇气 ） ， 同时 指出 对方 的 错误 ， 然后 再 进一步 考虑 是否 采取 其他 行动 。
# 近代以来，在伦理学中有两大派别。
# 近代 以来 ， 在 伦理学 中 有 两大 派别 。
# 一派叫做“道义论”，认为行为的正当与否不取决于行为的目的与效果，而是取决于这些行为本身的性质，无论什么好的出发点、为了什么好的目的，有些不正当的行为也是不应该的。
# 一派 叫做 “ 道义 论 ” ， 认为 行 为的 正当 与否 不 取决于 行 为的 目的 与 效果 ， 而是 取决于 这些 行为 本身 的 性质 ， 无论 什么 好 的 出发点 、 为了 什么 好 的 目的 ， 有些 不 正当 的 行为 也 是不 应该 的 。
# 另一派叫“目的论”，认为目的可以证明手段，极端的目的论甚至认为：为了一个好的目的可以采取一切手段。
# 另 一派 叫 “ 目的 论 ” ， 认为 目的 可以 证明 手段 ， 极 端的 目的 论 甚至 认为 ： 为了 一个 好 的 目的 可以 采取 一切 手段 。
# 在我看来，“道义论”的观点是正确的，因为人们的目的可能有误，信息可能不全或者出错，推崇“目的可以证明手段”，客观上无异于为各种不当行为打开绿灯。
# 在 我 看来 ， “ 道义 论 ” 的 观点 是 正确 的 ， 因为 人们 的 目的 可能 有 误 ， 信息 可 能不 全 或者 出错 ， 推崇 “ 目的 可以 证明 手段 ” ， 客观 上 无异 于 为 各种 不当 行为 打 开绿灯 。
# 在我们的生活中已经有过不少这样的教训。
# 在 我们 的 生活 中 已经 有 过 不少 这样 的 教训 。
# 而以自己的一个不义行为去纠正另一个人的不义行为，从严于责己的角度来说，甚至可能是一个更大的不义。
# 而 以 自己 的 一个 不义 行为 去 纠正 另一 个人 的 不义 行为 ， 从严 于 责 己 的 角度 来说 ， 甚至 可能 是 一个 更 大 的 不义 。
# 因为这是我的不义，是后发的不义，增加的不义。
# 因为 这是 我 的 不义 ， 是 后 发 的 不义 ， 增 加的 不义 。
# 比起对别人的、已经发生的行为来，我们对自己正打算去做的行为，应该要求更严格些。
# 比 起 对 别人 的 、 已经 发生 的 行为 来 ， 我们 对 自己 正 打算 去 做 的 行为 ， 应该 要求 更 严格 些 。
# 当然，上面所说的这种“道义论”观点可以是极其严格的，也可以是相对温和的，亦即容许有在某种极端情况下的例外。
# 当然 ， 上面 所 说 的 这种 “ 道义 论 ” 观点 可以 是 极其 严格 的 ， 也 可以 是 相对 温和 的 ， 亦即 容 许有 在 某 种 极端 情况 下 的 例外 。
# 例如，如果我偶然看到另一个人的日记，得知他要自杀，我就倾向于认为可以采取一切可能的手段来阻止他的自杀，因为，这时，挽救一个人生命的义务将凌驾于不侵犯别人隐私的义务。
# 例如 ， 如果 我 偶然 看到 另一 个人 的 日记 ， 得知 他 要 自杀 ， 我 就 倾向 于 认为 可以 采取 一切 可能 的 手段 来 阻止 他 的 自杀 ， 因为 ， 这时 ， 挽救 一 个人 生命 的 义务 将 凌 驾 于 不 侵犯 别人 隐私 的 义务 。
# 无论如何，虽然我主张反对不义的营私行为一定要使自己首先立足于正当的基础，采取恰当的方式，因而我们的行动就不能不审慎，但是，保留一种正义感，一种随时准备站出来维护公正、抗击不义的精神还是极其可贵、值得鼓励的。
# 无论如何 ， 虽然 我 主张 反对 不义 的 营私 行为 一定 要 使 自己 首先 立足 于 正当 的 基础 ， 采取 恰当 的 方式 ， 因而 我们 的 行动 就 不能不 审慎 ， 但是 ， 保留 一种 正义感 ， 一种 随时 准备 站 出来 维护 公正 、 抗击 不义 的 精神 还是 极其 可贵 、 值得 鼓励 的 。
# 以上的意见仅供你参考，并愿我们在今后的生活中都能互戒共勉。
# 以上 的 意见 仅 供 你 参考 ， 并 愿 我们 在 今后 的 生活 中 都 能 互 戒 共勉 。
# （何怀宏）
# （ 何 怀 宏 ）
# 说说心底的苦衷
# 说 说 心底 的 苦衷
# 我们是四个十七八岁的农村女孩，我们的父母重男轻女，只让我们马马虎虎念完小学，就再也不让上学了。
# 我们 是 四个 十 七八岁 的 农村 女孩 ， 我们 的 父母 重 男 轻 女 ， 只 让我们 马马虎虎 念 完 小学 ， 就 再也不 让 上学 了 。
# 在父母眼里，女孩子念书不念书无所谓，只要能认得钱，别人捉弄不了就行了，就是一字不识也不愁找个婆家，何苦多念几年书，花那冤枉钱！
# 在 父母 眼 里 ， 女孩子 念书 不 念书 无所谓 ， 只要 能 认得 钱 ， 别人 捉弄 不了 就 行 了 ， 就是 一字 不 识 也 不 愁 找 个 婆家 ， 何苦 多 念 几年 书 ， 花 那 冤枉 钱 ！
# 可现在我们面临的是什么呢？
# 可 现在 我们 面临 的 是 什么 呢 ？
# 单位招工，人家起码要初中毕业，我们被拒之门外；村里推荐人才出外学技术，我们照样落了榜；跑生意、做买卖，我们睁着两眼净吃亏；亲朋好友有心帮忙找个事，我们也因无文化难以胜任。
# 单位 招工 ， 人家 起码 要 初中 毕业 ， 我们 被 拒 之 门外 ； 村里 推荐 人才 出外 学 技术 ， 我们 照样 落 了 榜 ； 跑 生意 、 做买卖 ， 我们 睁 着 两 眼 净 吃亏 ； 亲朋好友 有心 帮忙 找 个 事 ， 我们 也 因 无 文化 难以 胜任 。
# 不管 我们 身 在 何处 ， 只要 自己 勤勉 努力 ， 朝着 既定 目标 奋进 ， 就 应该 相信 － －
# 姑娘们好！
# 姑娘 们 好 ！
# 你们能猜出我读了信的感觉吗？
# 你们 能 猜 出 我 读 了 信 的 感觉 吗 ？
# 我想对你们说，理解、同情和欣慰交织在一起，于是，我想和你们聊聊。
# 我 想 对 你们 说 ， 理解 、 同情 和 欣慰 交织 在 一起 ， 于是 ， 我 想 和 你们 聊 聊 。
# 应该说，对你们的家乡壶关县我不算陌生，十多年前我去采访过。
# 应该 说 ， 对 你们 的 家乡 壶关县 我 不 算 陌生 ， 十多 年前 我 去 采访 过 。
# 记忆中，土山、土路、土屋，贫瘠的黄土加上干旱少雨，使人们的生活很苦。
# 记忆 中 ， 土 山 、 土 路 、 土屋 ， 贫瘠 的 黄土 加上 干旱 少 雨 ， 使 人们 的 生活 很 苦 。
# 如今十几年过去了，从你们的来信中知道壶关变了，孩子们有了书读，人们看上了电视，你们这群山里的女娃娃有了学本领、闯世界的志气。
# 如今 十几年 过去了 ， 从 你们 的 来信 中 知道 壶关 变 了 ， 孩子 们 有 了 书 读 ， 人们 看上 了 电视 ， 你们 这 群山 里 的 女 娃娃 有 了 学 本领 、 闯世界 的 志气 。
# 这的确令人欣慰。
# 这 的确 令人 欣慰 。
# 生活开始变好了，可与那些鱼米之乡还不能比。
# 生活 开始 变 好 了 ， 可 与 那些 鱼米之乡 还 不能 比 。
# 在我国一些先富起来的农村，不管女孩男孩，父母们都千方百计地让他们上学读书、找份好工作。
# 在 我国 一些 先 富 起来 的 农村 ， 不管 女孩 男孩 ， 父母 们 都 千方百计 地 让 他们 上学 读书 、 找 份 好 工作 。
# 生活在那里，是孩子们的福气。
# 生活 在 那里 ， 是 孩子 们 的 福气 。
# 但是，人活在世上，有些事情我们可以选择，比如诚实还是欺骗、勤劳还是懒惰；有些事情我们却不能选择，比如出生地、父母、家庭条件。
# 但是 ， 人 活 在 世上 ， 有些 事情 我们 可以 选择 ， 比如 诚实 还是 欺骗 、 勤劳 还是 懒惰 ； 有些 事情 我们 却 不能 选择 ， 比如 出生 地 、 父母 、 家庭 条件 。
# 在什么山上唱什么歌，既然生活把我们安排在这穷乡僻壤，那里还留存着浓郁的重男轻女观念，我们就应该面对现实，在力所能及的条件下自己成就自己。
# 在 什么 山 上 唱 什么 歌 ， 既然 生活 把 我们 安排 在 这 穷乡僻壤 ， 那里 还 留存 着 浓郁 的 重 男 轻 女 观念 ， 我们 就 应该 面对 现实 ， 在 力所能及 的 条件 下 自己 成就 自己 。
# 你们读完小学，就被父母中断学业，你们想出去学点本领，也遭父母的阻拦，这的确很可惜。
# 你们 读 完 小学 ， 就 被 父母 中断 学业 ， 你们 想 出去 学 点 本领 ， 也 遭 父母 的 阻拦 ， 这 的确 很 可惜 。
# 从这一点说，我理解你们的埋怨情绪。
# 从 这 一点 说 ， 我 理解 你们 的 埋怨 情绪 。
# 可我们能不能换一种思维方式，理解一下父母呢？
# 可 我们 能不能 换 一种 思维 方式 ， 理解 一下 父母 呢 ？
# 你们的父母也许从来没有读过书，或者只能写自己的名字。
# 你们 的 父母 也许 从来 没有 读 过 书 ， 或者 只能 写 自己 的 名字 。
# 他们也没有机会走出山沟，看看外边的世界。
# 他们 也 没有 机会 走出 山沟 ， 看看 外边 的 世界 。
# 在他们的眼里和记忆中，山里人的出路就是放羊、种地。
# 在 他们 的 眼 里 和 记忆 中 ， 山 里 人 的 出路 就是 放 羊 、 种地 。
# 他们的生活中也有成功和喜悦，那就是今春羊多产了一头崽，今秋地里多打了一袋粮。
# 他们 的 生活 中 也 有 成功 和 喜悦 ， 那 就是 今春 羊 多 产 了 一头 崽 ， 今秋 地里 多 打 了 一 袋 粮 。
# 他们的希望就是雨水足了，地里庄稼长好了，崖崖畔畔的草旺了，羊吃饱、养壮了。
# 他们 的 希望 就是 雨水 足 了 ， 地里 庄稼 长 好 了 ， 崖 崖 畔 畔 的 草 旺 了 ， 羊 吃 饱 、 养 壮 了 。
# 粮多了就不再饿肚子，羊多了就可以多卖钱，不知道这和上学有什么关系。
# 粮 多 了 就 不再 饿 肚子 ， 羊 多 了 就 可以 多 卖钱 ， 不 知道 这 和 上 学有 什么 关系 。
# 他们认为，女孩子早晚要嫁到别人家。
# 他们 认为 ， 女孩子 早晚 要 嫁 到 别 人家 。
# 嫁汉嫁汉，穿衣吃饭。
# 嫁 汉 嫁 汉 ， 穿衣 吃饭 。
# 父母这么想当然不对，可也不能全怪他们的愚钝和落后。
# 父母 这么 想当然 不对 ， 可 也 不能 全 怪 他们 的 愚 钝 和 落后 。
# 人们很难逾越时代的局限，也许你们的父亲当年就是这样娶了你们的母亲，你的奶奶就是这样嫁给了你们的爷爷。
# 人们 很难 逾越 时代 的 局限 ， 也许 你们 的 父亲 当年 就是 这样 娶 了 你们 的 母亲 ， 你 的 奶奶 就是 这样 嫁 给 了 你们 的 爷爷 。
# 学知识，闯世界，道理简单，可父母不懂。
# 学 知识 ， 闯世界 ， 道理 简单 ， 可 父母 不 懂 。
# 你们懂，是因为你们赶上了国家经济大发展的好年代。
# 你们 懂 ， 是 因为 你们 赶上 了 国家经济 大 发展 的 好 年代 。
# 是这个年代，让你们明白了你们的父母半辈子都没明白的道理。
# 是 这个 年代 ， 让 你们 明白 了 你们 的 父母 半辈子 都 没 明白 的 道理 。
# 想到这些，再回头看看父母，他们算不算不幸？
# 想到 这些 ， 再 回头 看看 父母 ， 他们 算不 算 不幸 ？
# 即使父母错了，我们对他们也应该有足够的理解。
# 即使 父母 错 了 ， 我们 对 他们 也 应该 有 足够 的 理解 。
# 姑娘们，说了这么多，不是怪罪你们，是想让你们换一个角度想问题，以便心境开朗，开创新生活。
# 姑娘 们 ， 说了 这么 多 ， 不是 怪 罪 你们 ， 是 想 让 你们 换 一个 角度 想 问题 ， 以便 心境 开朗 ， 开 创新 生活 。
# 在这里，我也要对你们的父母说几句：孩子们心中长出了理想的翅膀，这是我们的希望。
# 在 这里 ， 我 也 要 对 你们 的 父母 说 几句 ： 孩子 们 心 中长 出 了 理想 的 翅膀 ， 这是 我们 的 希望 。
# 著有《科学中的理论选择》、《孔子与苏格拉底的文化差别》、《意义与对话》等论文及专著。
# 著 有 《科学 中 的 理论 选择 》 、 《 孔子 与 苏格拉底 的 文化 差别 》 、 《 意义 与 对话 》 等 论文 及 专著 。
# 李顺生朋友：
# 李 顺 生 朋友 ：
# 诚实、守信，在如今，似乎越来越被人们视为“传统”的美德，不合时宜了。
# 诚实 、 守信 ， 在 如今 ， 似乎 越来越 被 人们 视为 “ 传统 ” 的 美德 ， 不合时宜 了 。
# 仿佛只要在法律许可的范围内，就可以不择手段地随意追求自己向往的一切。
# 仿佛 只要 在 法律 许可 的 范围 内 ， 就 可以 不择手段 地 随意 追求 自己 向往 的 一切 。
# 在这样的情形下，研究信任和信用的问题，似乎有点儿不合“市场规律”了。
# 在 这样 的 情形 下 ， 研究 信任 和 信用 的 问题 ， 似乎 有点儿 不合 “ 市场 规律 ” 了 。
# 追求经济效益与恪守道德原则，在很多人看来，难以两全。
# 追求 经济效益 与 恪守 道德 原则 ， 在 很 多人 看来 ， 难以 两全 。
# 有的经济学家认为，市场与非经济的伦理行为准则是不相协调的，道德伦理不仅不会增进而且还会有损于企业的经营目标。
# 有的 经济学家 认为 ， 市场 与 非 经济 的 伦理 行为 准则 是 不相 协调 的 ， 道德 伦理 不仅 不会 增进 而且 还 会 有损于 企业 的 经营 目标 。
# 这种观点，是建立在对市场机制的乐观主义假定之上，即认为市场机制能够自动协调经济行为，维持经济运行的效率与秩序。
# 这种 观点 ， 是 建立 在 对 市场 机制 的 乐观主义 假定 之上 ， 即 认为 市场 机制 能够 自动 协调 经济 行为 ， 维持 经济 运行 的 效率 与 秩序 。
# 社会学家的观点则认为，一定程度的社会整合是一个社会得以维持秩序的必要条件。
# 社会学 家 的 观点 则 认为 ， 一定 程度 的 社会 整合 是 一个 社会 得以 维持 秩序 的 必要条件 。
# 社会整合条件下的社会个体不再是完全从个人利益出发的个体，而是社会规范和价值观念的服从者和体现者。
# 社会 整合 条件 下 的 社会 个体 不再 是 完全 从 个人利益 出发 的 个体 ， 而是 社会 规范 和 价值 观念 的 服从 者 和 体现 者 。
# 在社会大部分个体遵从社会规范的同时，个体的自身利益也得到较好实现。
# 在 社会 大部分 个体 遵从 社会 规范 的 同时 ， 个体 的 自身 利益 也 得到 较好 实现 。
# 对于共同规范的遵从，无疑提高了人们行为的可预期性，使整个社会能运行顺畅，包括经济领域。
# 对于 共同 规范 的 遵从 ， 无疑 提高 了 人们 行 为的 可 预期 性 ， 使 整个 社会 能 运行 顺畅 ， 包括 经济 领域 。
# 从这个意义上说，调节人们行为的社会规范是一种极为重要的社会公共资本，由此，经济资本方能高效地增值。
# 从 这个 意义 上 说 ， 调节 人们 行 为的 社会 规范 是 一种 极为 重要 的 社会 公共 资本 ， 由此 ， 经济 资本 方 能 高效 地 增值 。
# 社会学家一贯认为，经济只是社会生活的一个有机部分，经济领域的秩序与效率仰赖于整个社会的规范结构。
# 社会学 家 一贯 认为 ， 经济 只是 社会生活 的 一个 有机 部分 ， 经济 领域 的 秩序 与 效率 仰 赖 于 整个 社会 的 规范 结构 。
# 这里所谓的规范，不仅指明确的经济法规，还包括其他社会规范的内容，如道德与伦理。
# 这里 所谓 的 规范 ， 不仅 指 明确 的 经济 法规 ， 还 包括 其他 社会 规范 的 内容 ， 如 道德 与 伦理 。
# 前者是市场机制的组成部分，后者则涉及整个社会的公共意义资源。
# 前者 是 市场 机制 的 组成部分 ， 后者 则 涉及 整个 社会 的 公共 意义 资源 。
# 这种思想在当代经济学中亦有所体现，一些经济学家指出，信任降低了“交易成本”，而信任和社会整合的缺乏，是经济增长的障碍。
# 这种 思想 在 当代 经济学 中 亦 有所 体现 ， 一些 经济学家 指出 ， 信任 降低 了 “ 交易 成本 ” ， 而 信任 和 社会 整合 的 缺乏 ， 是 经济 增长 的 障碍 。
# 这种思想打破了传统的市场均衡的机械论模型，市场不再只是纯粹理性的经济行为主体们活动的一个独立领域，而是更大的社会有机组成部分；社会的道德伦理资源会成为市场经济的加速器，将与规范化的市场机制一起推动经济发展。
# 这种 思想 打破 了 传统 的 市场 均衡 的 机械论 模型 ， 市场 不再 只是 纯粹 理性 的 经济 行为 主体 们 活动 的 一个 独立 领域 ， 而是 更 大 的 社会 有机 组成部分 ； 社会 的 道德 伦理 资源 会 成为 市场经济 的 加速器 ， 将 与 规范化 的 市场 机制 一起 推动 经济 发展 。
# 可以毫不夸张地说，现代市场经济就是建立在信任与信用之上的，市场交换不仅仅是商品交换，更是信任与信用的交换。
# 可以 毫不 夸张 地 说 ， 现代 市场经济 就是 建立 在 信任 与 信用 之上 的 ， 市场 交换 不仅仅是 商品 交换 ， 更 是 信任 与 信用 的 交换 。
# 当前，完善和确立市场机制已经取得了全社会的共识，并且在建立和健全各种经济法规、营造经济行为主体方面已取得很大的进展。
# 当前 ， 完善 和 确立 市场 机制 已经 取 得了 全社会 的 共识 ， 并且 在 建立 和 健全 各种 经济 法规 、 营造 经济 行为 主体 方面 已 取得 很 大 的 进展 。
# 但是我们也应看到，缺乏信任和信用的现象在我们生活中并不鲜见。
# 但是 我们 也 应 看到 ， 缺乏 信任 和 信用 的 现象 在 我们 生活 中 并不 鲜见 。
# 各种假冒伪劣产品夺走了人们对厂家和商家的信任，使人们在丰富多彩而又鱼目混珠的商品面前多了犹疑和无措，甚至出现真品打不过伪品的怪现象，厂家和消费者成为直接受害者。
# 各种 假冒伪劣 产品 夺 走 了 人们 对 厂家 和 商家 的 信任 ， 使 人们 在 丰富多彩 而 又 鱼目混珠 的 商品 面前 多 了 犹 疑 和 无措 ， 甚至 出现 真品 打 不过 伪 品 的 怪 现象 ， 厂家 和 消费者 成为 直接 受害者 。
# 一些消费者利用商家“不满意就退货”的承诺，既“满意”地使用了商品又要回了货款。
# 一些 消费者 利用 商家 “ 不 满意 就 退货 ” 的 承诺 ， 既 “ 满意 ” 地 使用 了 商品 又要 回 了 货款 。
# 其他稀奇古怪的坑蒙拐骗花样，更是不胜枚举。
# 其他 稀奇 古怪 的 坑蒙拐骗 花样 ， 更 是 不胜枚举 。
# 由此不难看出，我们社会中的许多经济行为，步入所谓纯粹功利性的误区。
# 由此 不 难 看出 ， 我们 社会 中 的 许多 经济 行为 ， 步入 所谓 纯粹 功利 性 的 误区 。
# 而这些，已经超出了纯经济的范畴，仅凭经济法规是难以彻底解决的。
# 而 这些 ， 已经 超出 了 纯 经济 的 范畴 ， 仅 凭 经济 法规 是 难以 彻底 解决 的 。
# 中国有着悠久的“诚信为本”的传统。
# 中国 有着 悠久 的 “ 诚信 为 本 ” 的 传统 。
# 但我们要注意到，人与人交往中的相互信任，大都建立在家族，至少是熟人的圈子之内。
# 但 我们 要 注意 到 ， 人 与人 交往 中 的 相互 信任 ， 大都 建立 在 家族 ， 至少 是 熟人 的 圈子 之内 。
# 显然，这种信任只限于“知根知底”的狭小范围。
# 显然 ， 这种 信任 只 限于 “ 知根知底 ” 的 狭小 范围 。
# 这种信用模式，无疑束缚了大规模、远距离的交易往来。
# 这种 信用 模式 ， 无疑 束缚 了 大规模 、 远 距离 的 交易 往来 。
# 改革以前，我们社会的信任主要是建立在单位约束的基础上，这从单位开具的“介绍信”的效力中不难看出。
# 改革 以前 ， 我们 社会 的 信任 主 要是 建立 在 单位 约束 的 基础 上 ， 这 从 单位 开具 的 “ 介绍信 ” 的 效力 中 不 难 看出 。
# 出示一张介绍信，就表明你是有单位的，我们可以信任你，即便你欺骗了我们，我们可以找你的单位，要求你的单位负责。
# 出示 一 张 介绍信 ， 就 表明 你 是 有 单位 的 ， 我们 可以 信任 你 ， 即便 你 欺骗 了 我们 ， 我们 可以 找 你 的 单位 ， 要求 你 的 单位 负责 。
# 而单位确实又应为所属者的行为负责，因为所属者的一切都受控于单位。
# 而 单位 确实 又 应 为 所属 者 的 行为 负责 ， 因为 所属 者 的 一切 都 受 控 于 单位 。
# 而改革以后，不仅单位的形式多样化了，连单位同个人之间的关系的性质也变了。
# 而 改革 以后 ， 不仅 单位 的 形式 多样化 了 ， 连 单位 同 个人 之间 的 关系 的 性质 也 变 了 。
# 依靠单位的纽带来维持以往的信任模式，也就不太可靠了。
# 依靠 单位 的 纽 带来 维持 以往 的 信任 模式 ， 也就 不 太 可靠 了 。
# 由此可以看出，信任不仅仅是一种心态的问题，更重要的是需要相应的社会机制来予以维持和强化。
# 由此 可以 看出 ， 信任 不仅仅是 一种 心态 的 问题 ， 更 重要 的 是 需要 相应 的 社会 机制 来 予以 维持 和 强化 。
# 这种机制的原理应当非常简单，即守信者得到酬赏，失信者受到惩罚。
# 这种 机制 的 原理 应当 非常 简单 ， 即 守信 者 得到 酬 赏 ， 失信 者 受到 惩罚 。
# 不过，在社会经济交往日益频繁和短暂化的今天，要做到这一点并非易事。
# 不过 ， 在 社会 经济 交往 日益 频繁 和 短暂 化 的 今天 ， 要 做到 这 一点 并非 易 事 。
# 首先，我们不能通过垂直设置的行政机构来完成这种机制，因为这种设置只能收一时之效。
# 首先 ， 我们 不能 通过 垂直 设置 的 行政 机构 来 完成 这种 机制 ， 因为 这种 设置 只能 收 一时 之 效 。
# 其次，地方保护主义依然盛行，维持信任的社会机制应正面利用地方利益的驱动作用，一个地方守信则受益，反之则受到制裁。
# 其次 ， 地方 保护主义 依然 盛行 ， 维持 信任 的 社会 机制 应 正面 利用 地方 利益 的 驱动 作用 ， 一个 地方 守信 则 受益 ， 反之 则 受到 制裁 。
# 这样，地方就会增强自我约束和自我监督。
# 这样 ， 地方 就 会 增强 自我 约束 和 自我 监督 。
# 再次，政府有关部门应当着力于加强对于一些中介性和行业性机构的管理，而且这种管理应只限于保持它们的公正性和权威性。
# 再次 ， 政府 有关 部门 应当 着力 于 加强 对于 一些 中介 性 和 行业 性 机构 的 管理 ， 而且 这种 管 理应 只 限于 保持 它们 的 公正 性 和 权威性 。
# 最后，各种民间自治组织应在信任和信用的维持中起中坚作用。
# 最后 ， 各种 民间 自治 组织 应 在 信任 和 信用 的 维持 中 起 中坚 作用 。
# 市场经济需要各种致力于社会自我管理的组织的支撑。
# 市场经济 需要 各种 致力于 社会 自我 管理 的 组织 的 支撑 。
# 现在我们比任何时候都明白，解决社会问题，单是诉诸道德说教，或者仰仗公众的良心发现，不可能奏效。
# 现在 我们 比 任何 时候 都 明白 ， 解决 社会 问题 ， 单是 诉诸 道德 说教 ， 或者 仰仗 公众 的 良心 发现 ， 不可能 奏效 。
# 但是，我们也不能因此而忽视道德和良心的作用。
# 但是 ， 我们 也 不能 因此 而 忽视 道德 和 良心 的 作用 。
# 在努力完善信任和信用社会机制的同时，我们应该加快适合于新时代的道德和良心的建设，使之成为经济健康发展可以汲取动力的源泉。
# 在 努力 完善 信任 和 信用 社会 机制 的 同时 ， 我们 应该 加快 适合 于 新时代 的 道德 和 良心 的 建设 ， 使 之 成为 经济 健康 发展 可以 汲取 动力 的 源泉 。
# （成伯清）
# （ 成 伯 清 ）
# 长江三峡工程年底截流合龙设计流量为世界之最截流技术有十分把握
# 长江三峡 工程 年底 截流 合龙 设计 流量 为 世界 之最 截流 技术 有 十分 把握
# 据新华社宜昌１月２日电（记者施勇峰）长江三峡工程将在今年截流。
# 据 新华社 宜昌 １月 ２日 电 （ 记者 施 勇 峰 ） 长江三峡 工程 将 在 今年 截流 。
# 三峡工程将以长江截流成功作为一期工程结束的标志。
# 三峡 工程 将 以 长江 截流 成功 作为 一期 工程 结束 的 标志 。
# 能否高质量完成长江截流，直接关系到工程能否进入第二期施工。
# 能否 高质量 完成 长江 截流 ， 直接 关系到 工程 能否 进入 第二期 施工 。
# 现在，三峡工程建设大军正在积极准备，截流工作已进入“倒计时”。
# 现在 ， 三峡 工程 建设 大军 正在 积极 准备 ， 截流 工作 已 进入 “ 倒计时 ” 。
# 三峡截流无论是技术，还是施工规模，都是难度极高的工程。
# 三峡 截流 无论 是 技术 ， 还是 施工 规模 ， 都是 难度 极 高 的 工程 。
# 特别是它的截流设计流量，施工水深和施工强度，都属世界水电工程之最。
# 特别是 它 的 截流 设计 流量 ， 施工 水深 和 施工 强度 ， 都 属 世界 水电 工程 之最 。
# 在三峡长江截流合龙时，选定的设计流量是每秒１.４万至１.９万立方米。
# 在 三峡 长江 截流 合龙 时 ， 选定 的 设计 流量 是 每秒１ . ４万 至 １ . ９万 立方米 。
# 这个流量是目前世界上已完成的水电工程中最大的。
# 这个 流量 是 目前 世界 上 已 完成 的 水电 工程 中 最大 的 。
# 三峡长江截流施工水深一般为２６-４０米，最大水深６０米，比葛洲坝截流最大水深深４０米。
# 三峡 长江 截流 施工 水深 一般 为 ２６ - ４０米 ， 最大 水深 ６０米 ， 比 葛洲坝 截流 最 大水 深深 ４０米 。
# 由于围堰填筑８０％的工程量是水下抛投，而长江三峡水流汹涌，解决深水条件下截流的各种技术问题，是三峡截流成败的关键所在。
# 由于 围堰 填 筑 ８０％ 的 工程 量 是 水下 抛 投 ， 而 长江三峡 水流 汹涌 ， 解决 深水 条件 下 截流 的 各种 技术 问题 ， 是 三峡 截流 成败 的 关键 所在 。
# 当三峡工程还处在论证阶段的时候，三峡截流的技术问题已被国家列为科技攻关的课题。
# 当 三峡 工程 还 处在 论证 阶段 的 时候 ， 三峡 截流 的 技术 问题 已 被 国家 列为 科技攻关 的 课题 。
# 国家组织有关科研单位和大专院校对三峡工程施工水力学进行了长达４０多年的研究，攻克了截流中的各个重大技术问题。
# 国家 组织 有关 科研 单位 和 大专院 校对 三峡 工程 施工 水 力学 进行 了 长 达 ４０多年 的 研究 ， 攻克 了 截流 中 的 各个 重大 技术 问题 。
# 水利部长江水利委员会在广泛吸收国内外专家意见的基础上，参照葛洲坝大江截流和国内外大江大河截流的经验，对三峡工程大江截流的水力学、水文学等进行了充分试验研究，提出了详尽的截流设计，并通过了技术审查。
# 水利部 长江水利委员会 在 广泛 吸收 国内外 专家 意见 的 基础 上 ， 参照 葛洲坝大江 截流 和 国内外 大江 大河 截流 的 经验 ， 对 三峡 工程 大江 截流 的 水 力学 、 水文学 等 进行 了 充分 试验 研究 ， 提出 了 详尽 的 截流 设计 ， 并 通过 了 技术 审查 。
# 三峡工程业主---中国长江三峡工程开发总公司负责人表示，进行三峡截流在技术上已有十分把握。
# 三峡 工程 业主 - - - 中国 长江三峡 工程 开发 总公司 负责人 表示 ， 进行 三峡 截流 在 技术 上 已 有 十分 把握 。
# 记者在采访中了解到，三峡截流的落差和龙口流速都不大，这对截流较为有利。
# 记者 在 采访 中 了解 到 ， 三峡 截流 的 落差 和 龙口 流速 都 不大 ， 这 对 截流 较为 有利 。
# 据分析，三峡截流落差在０.７-０.８米之间，而葛洲坝截流落差为３.２３米；三峡截流的龙口流速为每秒２.８９米，大大低于葛洲坝截流每秒７米的流速。
# 据 分析 ， 三峡 截流 落差 在 ０ . ７ - ０ . ８米 之间 ， 而 葛洲坝 截流 落差 为 ３ . ２ ３米 ； 三峡 截流 的 龙口 流速 为 每秒２ . ８ ９米 ， 大大 低于 葛洲坝 截流 每秒 ７米 的 流速 。
# 这些也为三峡截流一举成功提供了有利条件。
# 这些 也 为 三峡 截流 一举 成功 提供 了 有利 条件 。
# 据悉，三峡工程长江截流的合龙时间暂定为１９９７年１１月，届时将根据工程进展和水文条件确定截流的时间。
# 据悉 ， 三峡 工程 长江 截流 的 合龙 时间 暂 定 为 １９９７年１１月 ， 届时 将 根据 工程 进展 和 水文 条件 确定 截流 的 时间 。
# 在万里长江上建起第一座大坝的葛洲坝集团公司，承担了三峡大江截流及二期围堰工程的施工。
# 在 万里 长江 上 建起 第一座 大坝 的 葛洲坝 集团公司 ， 承担 了 三峡 大江 截流 及 二期 围堰 工程 的 施工 。
# 三峡截流，举世关注。
# 三峡 截流 ， 举世 关注 。
# 这个集团公司从１９９６年１０月起，从施工队伍组织到技术、设备等方面全面进入临战状态。
# 这个 集团公司 从 １９９６年１０月 起 ， 从 施工 队伍 组织 到 技术 、 设备 等 方面 全面 进入 临战 状态 。
# 长江是我国的黄金水道。
# 长江 是 我国 的 黄金 水道 。
# 在长江上修建三峡大坝，必须确保施工期间的长江航运畅通。
# 在 长江 上 修建 三峡 大坝 ， 必须 确保 施工 期间 的 长江航运 畅通 。
# 为解决二期工程６年间的通航问题，三峡工程决定采用导流明渠结合临时船闸的通航方案。
# 为 解决 二期 工程 ６ 年间 的 通航 问题 ， 三峡 工程 决定 采用 导 流 明渠 结合 临时 船闸 的 通航 方案 。
# 大江截流截断主河床后，江水将改由在后河上开挖的导流明渠下泄，这条长１９７５米、宽３５０米的“人造长江”将在截流后的６年时间内成为江水下泄和长江航运的通道。
# 大江 截流 截断 主 河床 后 ， 江水 将 改 由 在 后河 上 开挖 的 导 流 明渠 下泄 ， 这 条 长 １９ ７５米 、 宽 ３５０米 的 “ 人造 长江 ” 将 在 截流 后 的 ６年 时间 内 成为 江水 下泄 和 长江航运 的 通道 。
# 乔石视察中国气象局时强调要重视气候资源的开发利用
# 乔石 视察 中国气象局 时 强调 要 重视 气候 资源 的 开发利用
# 本报北京１月２５日讯新华社记者王言彬、本报记者何加正报道：中共中央政治局常委、全国人大常委会委员长乔石今天视察中国气象局时强调，要使我国气象事业有一个更大的发展。
# 本报 北京 １月 ２５日 讯 新华社 记者 王言彬 、 本报 记者 何加正 报道 ： 中共 中央政治局常委 、 全国人大常委会 委员长 乔石 今天 视察 中国气象局 时 强调 ， 要 使 我国 气象 事业 有 一个 更 大 的 发展 。
# 乔石在中国气象局局长温克刚和名誉局长邹竞蒙等同志陪同下，先后视察了卫星气象中心运行控制室、国家气象中心天气预报会商室和计算机房，详细了解了有关气象装备的运转情况，听取了关于气象工作的汇报。
# 乔石 在 中国气象局 局长 温克刚 和 名誉 局长 邹 竞 蒙 等 同志 陪同 下 ， 先后 视察 了 卫星 气象 中心 运行 控制室 、 国家气象 中心 天气预报 会商 室 和 计算机房 ， 详细 了解 了 有关 气象 装备 的 运转 情况 ， 听取 了 关于 气象 工作 的 汇报 。
# 我国气象业务技术的现代化，在发展中国家已处于领先水平，相当一部分已达到发达国家８０年代中期或后期的水平，某些方面已经达到发达国家９０年代初的水平。
# 我国 气象 业务 技术 的 现代化 ， 在 发展中国家 已 处于 领先 水平 ， 相当 一部分 已 达到 发达国家 ８０年代中期 或 后期 的 水平 ， 某些 方面 已经 达到 发达国家 ９０年代初 的 水平 。
# 我国已初步建成了门类齐全、布局合理、自动化程度较高的气象综合探测系统；初步建成了以计算机通讯网络联通国家、区域气象中心和省、地气象台的信息网络系统，增强了国内外气象信息的交换和传输能力；已经建立了结构合理的气象业务技术体系和比较现代化的气象服务体系；取得了一批重要的气象科研成果；气象教育迅速发展，气象队伍素质明显提高，并广泛开展了国际气象合作与交流；气象系统精神文明建设也取得了重要成绩。
# 我国 已 初步 建成 了 门类 齐全 、 布局 合理 、 自动化 程度 较高 的 气象 综合 探测 系统 ； 初步 建成 了 以 计算机 通讯 网络 联通 国家 、 区域 气象 中心 和 省 、 地 气象台 的 信息 网络 系统 ， 增强 了 国内外 气象 信息 的 交换 和 传输 能力 ； 已经 建立 了 结构 合理 的 气象 业务 技术 体系 和 比较 现代化 的 气象 服务 体系 ； 取 得了 一批 重要 的 气象 科研成果 ； 气象 教育 迅速 发展 ， 气象 队伍 素质 明显 提高 ， 并 广泛 开展 了 国际 气象 合作 与 交流 ； 气象 系统 精神文明 建设 也 取 得了 重要 成绩 。
# 根据规划，未来１５年，我国气象事业的整体水平将达到国际先进水平。
# 根据 规划 ， 未来 １５年 ， 我国 气象 事业 的 整体 水平 将 达到 国际 先进 水平 。
# 乔石说，气象工作与国家建设和人民生活密不可分，非常重要。
# 乔石 说 ， 气象 工作 与 国家建设 和 人民 生活 密不可分 ， 非常 重要 。
# 建国以来，尤其是改革开放以来，我国的气象事业成绩显著。
# 建国 以来 ， 尤其是 改革开放 以来 ， 我国 的 气象 事业 成绩 显著 。
# 广大气象工作者克服困难，艰苦努力，为促进经济发展，为防灾减灾，为方便人民群众的工作和生活做出了重要的贡献。
# 广大 气象 工作者 克服困难 ， 艰苦 努力 ， 为 促进 经济 发展 ， 为 防灾 减灾 ， 为 方便 人民群众 的 工作 和 生活 做出 了 重要 的 贡献 。
# 他说，我国正在实施国民经济和社会发展的“九五”计划，并且制定了到２０１０年的远景目标，这对气象工作提出了更高的要求，我国气象事业面临着繁重的进一步发展的任务。
# 他 说 ， 我国 正在 实施 国民经济 和 社会发展 的 “ 九五 ” 计划 ， 并且 制定 了 到 ２０１０年 的 远景 目标 ， 这 对 气象 工作 提出 了 更 高 的 要求 ， 我国 气象 事业 面临 着 繁重 的 进一步 发展 的 任务 。
# 要更加重视气候资源的开发和利用，继续拓宽气象服务的领域，提高服务质量和效益，抓紧提高气象业务技术的现代化程度，改善工作条件，加强和完善科学管理，努力多出人才，多出成果，逐步使我国的气象工作达到国际上最先进的水平，为国家和人民做出更大贡献。
# 要 更加 重视 气候 资源 的 开发 和 利用 ， 继续 拓宽 气象 服务 的 领域 ， 提高 服务 质量 和 效益 ， 抓紧 提高 气象 业务 技术 的 现代化 程度 ， 改善 工作 条件 ， 加强 和 完善 科学管理 ， 努力 多 出 人才 ， 多 出 成果 ， 逐步 使 我国 的 气象 工作 达到 国际 上 最 先进 的 水平 ， 为 国家 和 人民 做出 更 大 贡献 。
# 各地在淮河干支流出入境处还设置水质监测哨，沿淮１２个监测站，与１３条主要支流、８个城市的污染监测系统同步监测，成为淮河污染防治的好哨兵。
# 各地 在 淮河 干 支流 出入境 处 还 设置 水质 监测 哨 ， 沿 淮 １２个 监测站 ， 与 １３条 主要 支流 、 ８个 城市 的 污染 监测 系统 同步 监测 ， 成为 淮河 污染 防治 的 好 哨兵 。
# 去年４月，淮河水奇缺，各环保部门根据监测情报，对３０家企业的污染限产限排，减少污染事故损失１亿多元，今年枯水期又对４４家企业发出限产限排令，有效地控制了淮河水污染。
# 去年４月 ， 淮 河水 奇缺 ， 各 环保 部门 根据 监测 情报 ， 对 ３０家 企业 的 污染 限产 限 排 ， 减少 污染 事故 损失 １亿多元 ， 今年 枯水期 又 对 ４ ４家 企业 发出 限产 限 排 令 ， 有效 地 控制 了 淮河 水污染 。
# 东方红三号通信卫星发射升空卫星运行状况良好首次变轨成功
# 东方红三号 通信卫星 发射 升空 卫星 运行 状况 良好 首次 变 轨 成功
# （附图片１张）
# （ 附 图片 １ 张 ）
# 据新华社西昌５月１２日电（中央人民广播电台记者刘程，新华社记者徐殿龙、奚启新）今天零时１７分，我国研制的新一代通信卫星“东方红三号”，由新型的“长征三号甲”运载火箭在西昌卫星发射中心发射升空。
# 据 新华社 西昌 ５月１２日 电 （ 中央人民广播电台 记者 刘 程 ， 新华社 记者 徐 殿 龙 、 奚启新 ） 今天 零时 １７分 ， 我国 研制 的 新一代 通信卫星 “ 东方红三号 ” ， 由 新型 的 “长征 三号甲 ” 运载火箭 在 西昌卫星发射中心 发射 升空 。
# 中共中央政治局委员、国务院副总理吴邦国在现场观看了发射，并代表党中央、国务院、中央军委向参加研制、生产、发射试验的全体人员表示亲切慰问和祝贺。
# 中共中央政治局 委员 、 国务院 副总理 吴邦国 在 现场 观看 了 发射 ， 并 代表 党中央 、 国务院 、 中央军委 向 参加 研制 、 生产 、 发射 试验 的 全体 人员 表示 亲切 慰问 和 祝贺 。
# ２４分钟后，从西安卫星测控中心传来数据表明，卫星已顺利进入近地点２０９公里、远地点３６１９４公里的地球同步转移轨道。
# ２ ４分钟 后 ， 从 西安卫星测控中心 传来 数据 表明 ， 卫星 已 顺利 进入 近地点 ２０ ９公里 、 远地点 ３ ６１９ ４公里 的 地球 同步 转移 轨道 。
# 由中国空间技术研究院研制的“东方红三号”卫星，是我国新一代实用广播通信卫星。
# 由 中国空间技术研究院 研制 的 “ 东方红三号 ” 卫星 ， 是 我国 新一代 实用 广播 通信卫星 。
# 星上装有２４个ｃ波段转发器，工作寿命为８年。
# 星 上 装有 ２４个 ｃ 波段 转发器 ， 工作 寿命 为 ８年 。
# 这次发射的“东方红三号”卫星是这种型号的第二颗卫星。
# 这次 发射 的 “ 东方红三号 ” 卫星 是 这种 型号 的 第二 颗 卫星 。
# 用来发射“东方红三号”卫星的“长征三号甲”运载火箭，是我国自行研制的地球同步轨道运载能力较大的运载火箭，这种型号火箭此前已进行过两次成功发射，也是长征系列火箭第４４次发射。
# 用来 发射 “ 东方红三号 ” 卫星 的 “长征 三号甲 ” 运载火箭 ， 是 我国 自行 研制 的 地球 同步 轨道 运载 能力 较大 的 运载火箭 ， 这种 型号 火箭 此前 已 进行 过 两次 成功 发射 ， 也是 长征 系列 火箭 第４ ４次 发射 。
# “长征三号甲”运载火箭起飞质量为２４０吨，起飞推力为３００吨，可将２.６吨的有效载荷送入地球同步转移轨道。
# “长征 三号甲 ” 运载火箭 起飞 质量 为 ２ ４０吨 ， 起飞 推力 为 ３００吨 ， 可 将 ２ . ６吨 的 有效 载荷 送入 地球 同步 转移 轨道 。
# 同时，也可兼顾其它轨道卫星的发射，包括一箭双星或多星的发射。
# 同时 ， 也 可 兼顾 其它 轨道 卫星 的 发射 ， 包括 一 箭 双星 或多 星 的 发射 。
# 据有关部门介绍，“长征三号甲”火箭上新采用的大推力氢氧发动机、四框架挠性平台等多项新技术，目前世界上只有少数国家掌握。
# 据 有关 部门 介绍 ， “长征 三号甲 ” 火箭 上新 采用 的 大 推力 氢 氧 发动机 、 四 框架 挠 性 平台 等 多 项 新技术 ， 目前 世界 上 只有 少数 国家 掌握 。
# 新华社北京５月１２日电（记者奚启新）据国防科工委北京指挥所提供的信息，东方红三号通信卫星进入地球同步转移轨道后，在西安卫星测控中心地面测控网和远望号海上航天测量船的跟踪、控制下，顺利完成了太阳能帆板及通信天线展开等太空动作。
# 新华社 北京 ５月１２日 电 （ 记者 奚启新 ） 据 国防科工委 北京 指挥 所 提供 的 信息 ， 东方红三号 通信卫星 进入 地球 同步 转移 轨道 后 ， 在 西安卫星测控中心 地面 测控 网 和 远望 号 海上 航天 测量 船 的 跟踪 、 控制 下 ， 顺利 完成 了 太阳能 帆 板 及 通信 天线 展开 等 太空 动作 。
# 北京时间今天下午４时１１分，星上远地点发动机进行了第一次点火，变轨成功，使卫星近地点由２３１公里抬高到６４８８公里，倾角由２８.３度减少到１２.３度。
# 北京时间今天 下午４时 １１分 ， 星 上 远地点 发动机 进行 了 第一次 点火 ， 变 轨 成功 ， 使 卫星 近地点 由 ２ ３１公里 抬高 到 ６ ４８８公里 ， 倾角 由 ２８ . ３ 度 减少 到 １２ . ３ 度 。
# 据悉，再经过两次变轨，四天之后，卫星将进入地球准同步轨道。
# 据悉 ， 再 经过 两次 变 轨 ， 四天 之后 ， 卫星 将 进入 地球 准 同步 轨道 。
# 目前，卫星运行状况良好。
# 目前 ， 卫星 运行 状况 良好 。
# 图片：
# 图片 ：
# ５月１２日零时１７分，我国研制的新一代通信卫星“东方红三号”由新型的“长征三号甲”运载火箭在西昌卫星发射中心发射升空。
# ５月１２日 零时 １７分 ， 我国 研制 的 新一代 通信卫星 “ 东方红三号 ” 由 新型 的 “长征 三号甲 ” 运载火箭 在 西昌卫星发射中心 发射 升空 。
# （新华社记者赵健伟摄）
# （ 新华社 记者 赵 健 伟 摄 ）
# 陕西天然气九月进京陕京输气管道干线焊接接近尾声（附图片１张）
# 陕西 天然气 九月 进京 陕 京 输 气 管道 干线 焊接 接近 尾声 （ 附 图片 １ 张 ）
# 本报北京５月１７日讯记者颜世贵报道：正在建设中的陕京输气管道，已露雄姿，向着既定的投产目标，一刻不停地前进。
# 本报 北京 ５月１７日 讯 记者 颜世贵 报道 ： 正在 建设 中 的 陕 京 输 气 管道 ， 已 露 雄姿 ， 向着 既定 的 投产 目标 ， 一刻 不停 地 前进 。
# 这个投资３９亿多元人民币的国家重点工程，去年５月３日正式全面启动，万余名建设大军面对异常复杂的施工条件，不畏艰难险阻，奋力拼搏在千里施工线上。
# 这个 投资 ３９亿 多元 人民币 的 国家 重点 工程 ， 去年 ５月３日 正式 全面 启动 ， 万余名 建设 大军 面对 异常 复杂 的 施工 条件 ， 不畏 艰难险阻 ， 奋力 拼搏 在 千里 施工 线 上 。
# 截至今年５月１１日，已完成管道焊接７５０公里，占主体干线总量的８６.３％。
# 截至 今年５月１１日 ， 已 完成 管道 焊接 ７ ５０公里 ， 占 主体 干线 总量 的 ８６ . ３％ 。
# 承担此项建设任务的北京天然气集输公司立下军令状：今年５月３０日干线焊接完工；６月３０日全线贯通；９月３０日开始向北京输送天然气。
# 承担 此 项 建设 任务 的 北京 天然气 集 输 公司 立 下 军令状 ： 今年 ５月３０日 干线 焊接 完工 ； ６月３０日 全线 贯通 ； ９月 ３０日 开始 向 北京 输送 天然气 。
# 陕京工程采用了９０年代世界一流的技术和设备。
# 陕 京 工程 采用 了 ９０年代 世界 一流 的 技术 和 设备 。
# 建成后，将是我国陆上第一条大口径、长距离、全自动的输气管线。
# 建成 后 ， 将 是 我国 陆上 第一条 大 口径 、 长距离 、 全自动 的 输 气 管线 。
# 它对陕甘宁中部气田的开发利用，对京津地区城市燃料结构的调整和大气环境质量的改善，将产生巨大的作用。
# 它 对 陕甘宁 中部 气田 的 开发利用 ， 对 京 津 地区 城市 燃料 结构 的 调整 和 大气 环境 质量 的 改善 ， 将 产生 巨大 的 作用 。
# 据介绍，１９９８年至２０００年，北京市将有１００.８万户居民和一批公共服务设施用户用上天然气。
# 据 介绍 ， １９９８年 至 ２０００年 ， 北京市 将 有 １００ . ８ 万户 居 民和 一批 公共 服务 设施 用户 用 上 天然气 。
# 届时，将使城区２０万烧煤户成为历史，三环以内百分之百用上天然气。
# 届时 ， 将 使 城区 ２０万 烧 煤 户 成为 历史 ， 三环 以内 百分之百 用 上 天然气 。
# 陕京输气管道工程由输气干线和分输支线两个系统组成。
# 陕 京 输 气 管道 工程 由 输 气 干线 和 分 输 支线 两个 系统 组成 。
# 输气干线西起陕北靖边县，东至北京市石景山区衙门口，途经陕西、山西、河北、北京三省一市的２２个县、市、区，全长８６８.６公里，分输支线由北京市琉璃河分输站经永清至天津，全长１０３公里。
# 输 气 干线 西 起 陕北 靖 边 县 ， 东 至 北京市 石景山区 衙 门口 ， 途经 陕西 、 山西 、 河北 、 北京三 省 一 市 的 ２２个 县 、 市 、 区 ， 全长 ８６８ . ６公里 ， 分 输 支线 由 北京市 琉璃河 分 输 站 经 永清 至 天津 ， 全长 １０３公里 。
# 经过筛选获得参战的中国石油天然气管道局一、二、三公司的王牌军，以及来自四川油建、大庆油建、辽河油建、长庆油建、江汉油建的队伍，发扬连续作战的精神，每天天不亮就出工，差不多十几个小时奋斗在工地上，争时间，抢进度。
# 经过 筛选 获得 参战 的 中国石油天然气管道局 一、二、三 公司 的 王牌 军 ， 以及 来自 四川 油 建 、 大庆油 建 、 辽河油 建 、 长 庆 油 建 、 江汉 油 建 的 队伍 ， 发扬 连续 作战 的 精神 ， 每天 天不 亮 就 出 工 ， 差不多 十几个小时 奋斗 在 工 地上 ， 争 时间 ， 抢 进度 。
# 他们响亮地提出：“决战在陕京，奉献在陕京，建功立业在陕京！”
# 他们 响亮 地 提出 ： “ 决战 在 陕 京 ， 奉献 在 陕 京 ， 建功立业 在 陕 京 ！ ”
# 记者日前作为首都新闻采访团的一员，驱车全线采访，亲身感受到这条输气管道的铺设，不仅是设计人员智慧的结晶，同样也是施工人员汗水的结晶。
# 记者 日前 作为 首都 新闻 采访团 的 一 员 ， 驱车 全线 采访 ， 亲身 感 受到 这 条 输 气 管道 的 铺设 ， 不仅 是 设计 人员 智慧 的 结晶 ， 同样 也是 施工 人员 汗水 的 结晶 。
# 长长的管道像一条巨龙，从靖边天然气净化厂出来，穿过茫茫的毛乌素大沙漠东南边缘，来到秦晋之间的峭壁上，飞跨黄河，翻越吕梁山，向东沿大同盆地和浑源盆地延伸，翻越恒山，进入灵丘山间盆地，再穿过太行山，过遗钗岭、驿马岭、紫荆关，经河北易县进入华北平原，最后到了北京石景山区的衙门口。
# 岭 、 驿 马岭 、 紫荆 关 ， 经 河北 易县 进入 华北平原 ， 最后 到 了 北京 石景山区 的 衙 门口 。
# 这当中，要经过３个地震断裂带，还要越过无定河、秃尾河、窟野河、黄河、永定河５条大河，中小型河流１４０处，铁路１６处，大型公路８６处。
# 这 当中 ， 要 经过 ３个 地震 断裂带 ， 还要 越过 无定 河 、 秃 尾 河 、 窟 野 河 、 黄河 、 永定河 ５条 大河 ， 中小型 河流 １４０ 处 ， 铁路 １ ６处 ， 大型 公路 ８ ６处 。
# 设计人员说：管线途经地带，集中国地貌之大成，是目前国内施工难度最大的管道，被外国专家称作“极具挑战性的工程”。
# 设计 人员 说 ： 管线 途经 地带 ， 集 中国 地貌 之 大 成 ， 是 目前 国内 施工 难度 最大 的 管道 ， 被 外国 专家 称作 “ 极 具 挑战 性 的 工程 ” 。
# 陕京输气管道建设得到了沿线政府和人民的大力支持。
# 陕 京 输 气 管道 建设 得到 了 沿线 政府 和 人民 的 大力 支持 。
# 工程经过的地方，绝大多数为“老少边穷”地区，他们以大局为重，表示要像当年支持八路军一样支援工程建设。
# 工程 经过 的 地方 ， 绝大多数 为 “ 老少边穷 ” 地区 ， 他们 以 大局 为重 ， 表示 要 像 当年 支持 八路军 一样 支援 工程 建设 。
# 图片：
# 图片 ：
# 陕甘宁气田至北京输气管道工程线路走向示意图（示意图：孙伟绘）
# 陕甘宁 气田 至 北京 输 气 管道 工程 线路 走向 示意图 （ 示意图 ： 孙伟 绘 ）
# 东方红三号卫星定点成功国务院中央军委致电祝贺
# 东方红三号 卫星 定点 成功 国务院 中央军委 致电 祝贺
# 新华社北京５月２０日电国务院、中央军委今天发出贺电，对成功发射“东方红三号”通信卫星表示祝贺。
# 新华社 北京 ５月２０日 电 国务院 、 中央军委 今天 发出 贺电 ， 对 成功 发射 “ 东方红三号 ” 通信卫星 表示 祝贺 。
# 贺电全文如下：
# 贺电 全文 如下 ：
# 国防科工委、航天工业总公司并转参加“东方红三号”通信卫星研制、发射工作的同志们：
# 国防科工委 、 航天 工业 总公司 并 转 参加 “ 东方红三号 ” 通信卫星 研制 、 发射 工作 的 同志 们 ：
# 欣悉你们用“长征三号甲”运载火箭，将我国“东方红三号”中容量通信卫星成功地送入预定轨道，并定点于东经１２５度赤道上空。
# 欣悉 你们 用 “长征 三号甲 ” 运载火箭 ， 将 我国 “ 东方红三号 ” 中 容量 通信卫星 成功 地 送入 预定 轨道 ， 并 定点 于 东经１ ２５度 赤道 上空 。
# 这是你们认真贯彻党中央、国务院和中央军委的各项指示，自力更生，艰苦奋斗，团结一心，刻苦攻关，保证质量的结果。
# 这是 你们 认真 贯彻 党中央 、 国务院 和 中央军委 的 各项 指示 ， 自力更生 ， 艰苦奋斗 ， 团结一心 ， 刻苦 攻关 ， 保证 质量 的 结果 。
# 国务院、中央军委特向参加研制、发射、测控及各项保障工作的全体同志表示热烈的祝贺！
# 国务院 、 中央军委 特 向 参加 研制 、 发射 、 测控 及 各项 保障 工作 的 全体 同志 表示 热烈 的 祝贺 ！
# 研制、发射“东方红三号”通信卫星，表明我国通信卫星技术又上了一个新的台阶，对于进一步振奋全国人民的精神，促进我国卫星通信事业的发展，推动我国改革开放和经济建设，提高我国在国际航天领域的威望，巩固我国在国际航天发射市场的地位，都具有重要意义。
# 研制 、 发射 “ 东方红三号 ” 通信卫星 ， 表明 我国 通信卫星 技术 又 上 了 一个 新 的 台阶 ， 对于 进一步 振奋 全国人民 的 精神 ， 促进 我国 卫星通信 事业 的 发展 ， 推动 我国 改革开放 和 经济 建设 ， 提高 我国 在 国际 航天 领域 的 威望 ， 巩固 我国 在 国际 航天 发射 市场 的 地位 ， 都 具有 重要 意义 。
# 希望你们认真总结经验，继续发扬成绩，开拓进取，再创新的业绩，为加快我国现代化建设事业的发展不断作出新的贡献！
# 希望 你们 认真 总结经验 ， 继续 发扬 成绩 ， 开拓 进取 ， 再 创新 的 业绩 ， 为 加快 我国 现代化 建设 事业 的 发展 不断 作 出 新 的 贡献 ！
# 国务院中央军委
# 国务院 中央军委
# １９９７年５月２０日
# １９９７年 ５月２０日
# 新华社北京５月２０日电（记者徐殿龙）我国新一代通信卫星“东方红三号”在西安卫星测控中心跟踪与控制下，于今天１５时０１分成功定点于东经１２５度赤道上空。
# 新华社 北京 ５月２０日 电 （ 记者 徐 殿 龙 ） 我国 新一代 通信卫星 “ 东方红三号 ” 在 西安卫星测控中心 跟踪 与 控制 下 ， 于 今天 １５时 ０ １分 成功 定点 于 东经１ ２５度 赤道 上空 。
# “东方红三号”卫星是５月１２日在西昌卫星发射中心由“长征三号甲”运载火箭发射升空的。
# “ 东方红三号 ” 卫星 是 ５月１２日 在 西昌卫星发射中心 由 “长征 三号甲 ” 运载火箭 发射 升空 的 。
# 在卫星进入地球同步转移轨道后的８天时间里，地面测控网和海上测量船对卫星进行了持续跟踪与控制，使卫星顺利地完成了太阳能帆板、通信天线展开和远地点发动机３次点火、调姿变轨等１４０多个太空动作，进入了地球准同步轨道，并建立了预定的漂移速度，为按计划对其实施定点控制创造了条件。
# 在 卫星 进入 地球 同步 转移 轨道 后 的 ８天 时间 里 ， 地面 测控 网 和 海上 测量 船 对 卫星 进行 了 持续 跟踪 与 控制 ， 使 卫星 顺利 地 完成 了 太阳能 帆 板 、 通信 天线 展开 和 远地点 发动机 ３次 点火 、 调 姿 变 轨 等 １４０多个 太空 动作 ， 进入 了 地球 准 同步 轨道 ， 并 建立 了 预定 的 漂移 速度 ， 为 按 计划 对 其 实施 定点 控制 创造 了 条件 。
# 在对“东方红三号”卫星的测控过程中，西安卫星测控中心首次采用同国际标准兼容的新型测控网，对卫星成功地实施了３次变轨和多次定点捕获进行轨道修正。
# ...
# 比赛结束后，“深蓝”小组公布了一个秘密，每场对局结束后，小组都会根据卡斯帕罗夫的情况相应地修改特定的参数，“深蓝”虽不会思考，但这些工作实际上起到了强迫它学习的“作用”，这也是卡斯帕罗夫始终无法找到一个对付“深蓝”的有效办法的主要原因。
# 比赛 结束 后 ， “ 深蓝 ” 小组 公布 了 一个 秘密 ， 每 场 对局 结束 后 ， 小组 都会 根据 卡斯帕罗夫 的 情况 相应 地 修改 特定 的 参数 ， “ 深蓝 ” 虽 不会 思考 ， 但 这些 工作 实际上 起 到 了 强迫 它 学习 的 “ 作用 ” ， 这 也是 卡斯帕罗夫 始终 无法 找到 一个 对付 “ 深蓝 ” 的 有效 办法 的 主要 原因 。
# 今日的“深蓝”，已经不是去年的“深蓝”。
# 今日 的 “ 深蓝 ” ， 已经 不是 去年 的 “ 深蓝 ” 。
# “深蓝”此次胜利，标志着电脑技术又上了一个新台阶，我们从此将不得不认真地思考人与电脑的关系。
# “ 深蓝 ” 此次 胜利 ， 标志着 电脑 技术 又 上 了 一个 新 台阶 ， 我们 从此 将 不得不 认真 地 思考 人与 电脑 的 关系 。
# 据说，卡斯帕罗夫在输掉第二局之后，曾经彻夜难眠。
# 据说 ， 卡斯帕罗夫 在 输 掉 第二局 之后 ， 曾经 彻夜 难 眠 。
# 此时，不只是卡斯帕罗夫，我们大家都要学会接受电脑在某些方面已足以与人较量的现实。
# 此时 ， 不 只是 卡斯帕罗夫 ， 我们 大家 都 要 学会 接受 电脑 在 某些 方面 已 足以 与人 较量 的 现实 。
# 国际互联网的构成和规则
# 国际互联网 的 构成 和 规则
# 风靡全球的ｉｎｔｅｒｎｅｔ就其工作原理来说，就是一个计算机网络。
# 就 其 工作 原理 来说 ， 就是 一个 计算机网络 。
# 从８０年代开始，许多企业就引进了不少的局域网，它们将企业内部的数十台乃至上百台微机用双绞线或同轴缆联通在一起，使网上的计算机可以互相通讯，资源共享。
# 从 ８０年代 开始 ， 许多 企业 就 引进 了 不少 的 局 域 网 ， 它们 将 企业 内部 的 数十台 乃至 上百 台 微机 用 双 绞 线 或 同 轴 缆 联通 在 一起 ， 使 网上 的 计算机 可以 互相 通讯 ， 资源 共享 。
# 同时，还可将一些复杂的运算交给网上功能强大的计算机运行。
# 同时 ， 还 可 将 一些 复杂 的 运算 交给 网上 功能 强大 的 计算机 运行 。
# 这样，网上用户就极大地扩充了自己微机的运算能力和信息贮存量，可以实现许多在个人单机环境下无法实现的功能。
# 这样 ， 网上 用户 就 极 大地 扩充 了 自己 微机 的 运算 能力 和 信息 贮 存量 ， 可以 实现 许多 在 个人 单机 环境 下 无法 实现 的 功能 。
# 如果说ｉｎｔｅｒｎｅｔ是“信息高速公路”，那么局域网就是“乡村小路”了。
# 是 “ 信息 高速公路 ” ， 那么 局 域 网 就是 “ 乡村 小路 ” 了 。
# 就像高速公路与乡村小路有着截然不同的要求一样，由于规模不同，其作用和配置就有了从量变到质变的一个飞跃。
# 就 像 高速公路 与 乡村 小路 有着 截然不同 的 要求 一样 ， 由于 规模 不同 ， 其 作用 和 配置 就 有 了 从 量变 到 质变 的 一个 飞跃 。
# 在局域网上，你的微机只不过和数十台计算机互相通信和资源共享。
# 在 局 域 网上 ， 你 的 微机 只不过 和 数十台 计算机 互相 通信 和 资源 共享 。
# 而当你的微机联上ｉｎｔｅｒｎｅｔ后，你就将面对不同肤色、不同语言、不同习俗、不同文化背景的８０００万ｉｎｔｅｒｎｅｔ用户，与上千万台主机共享资源。
# 用户 ， 与 上千 万台 主机 共享 资源 。
# 由于其规模较之局域网不可同日而语，故其与局域网就有着不同的“游戏规则”。
# 由于 其 规模 较之 局 域 网 不可同日而语 ， 故 其 与 局 域 网 就 有着 不同 的 “ 游戏 规则 ” 。
# 为了管理的方便，一般企业的局域网通常只选用同一类计算机联网。
# 为了 管理 的 方便 ， 一般 企业 的 局 域 网 通常 只 选用 同 一类 计算机 联网 。
# 在同种计算机之间进行通讯是一件比较容易的事情。
# 在 同种 计算机 之间 进行 通讯 是 一件 比较 容易 的 事情 。
# 而在ｉｎｔｅｒｎｅｔ上的计算机可谓五花八门，这样，在不同类型的计算机之间进行通信就成为当务之急。
# 上 的 计算机 可谓 五花八门 ， 这样 ， 在 不同 类型 的 计算机 之间 进行 通信 就 成为 当务之急 。
# 值得庆幸的是，人们已经创造了一种计算机的“世界语”---ｔｃｐ／ｉｐ协议。
# ｃ ｐ ／ ｉ ｐ 协议 。
# ｔｃｐ／ｉｐ是一种不复杂的协议。
# ｃ ｐ ／ ｉ ｐ 是 一种 不 复杂 的 协议 。
# ｉｐ协议是一个信息包结构，它要求计算机将要发的信息分解成一个个有一定长度的信息包。
# ｉ ｐ 协议 是 一个 信息 包 结构 ， 它 要求 计算机 将要 发 的 信息 分解 成 一个个 有 一定 长度 的 信息 包 。
# 其中包括一组３２位的二进制数字。
# 其中 包括 一组 ３２位 的 二进 制 数字 。
# 这组数字记录了信息包将被送往的地址，称为ｉｐ地址。
# 这 组 数字 记录 了 信息 包 将 被 送往 的 地址 ， 称为 ｉ ｐ 地址 。
# 信息包经过多台主机的传递，就可以到达目的地。
# 信息 包 经 过多 台 主机 的 传递 ， 就 可以 到达 目的地 。
# 由于较长的信息被分解成一个个的信息包，这就有可能会在传递过程中有信息包遗失。
# 由于 较 长 的 信息 被 分解 成 一个个 的 信息 包 ， 这就 有 可能 会 在 传递 过程 中 有 信息 包 遗失 。
# 而ｔｃｐ协议就是用来对信息包进行检验，看信息包是否收齐，次序是否正确，如果有错误，就会要求对方重发。
# ｃ ｐ 协议 就是 用来 对 信息 包 进行 检验 ， 看 信息 包 是否 收 齐 ， 次序 是否 正确 ， 如果 有 错误 ， 就 会 要求 对方 重 发 。
# 由于ｉｎｔｅｒｎｅｔ的用户分布在世界各地，所以用来传递信息的媒介也就不仅仅是电缆和双绞线了，还包括光纤、电话线、微波和卫星，这就要求有一些“财大气粗”的通讯公司来专门提供上网服务。
# 的 用户 分布 在 世界 各地 ， 所以 用来 传递 信息 的 媒介 也就 不仅仅是 电缆 和 双 绞 线 了 ， 还 包括 光纤 、 电话 线 、 微波 和 卫星 ， 这就 要求 有一些 “ 财大气粗 ” 的 通讯 公司 来 专门 提供 上网 服务 。
# 而一般的个人和企业则通过这些公司提供的线路上网，这些公司被称为ｉｓｐ。
# 而 一般 的 个 人和 企业 则 通过 这些 公司 提供 的 线路 上网 ， 这些 公司 被 称为 ｉ ｓ ｐ 。
# 而最为麻烦的是网上的上千万台主机的命名。
# 而 最为 麻烦 的 是 网上 的 上千 万台 主机 的 命名 。
# 幸好ｉｎｔｅｒｎｅｔ提供了“域名”服务器系统。
# 提供 了 “ 域名 ” 服务器 系统 。
# 任何一台主机入网，都要到“网络信息中心”申请一个唯一的域名。
# 任何 一 台 主机 入网 ， 都 要 到 “ 网络 信息中心 ” 申请 一个 唯一 的 域名 。
# 这样，我们就可以准确无误地找到我们想去的主机并与它通信，成为ｉｎｔｅｒｎｅｔ网上的一员。
# 网上 的 一 员 。
# （摘自《中国青年报》邓泓文）
# （ 摘 自 《 中国青年报 》 邓 泓 文 ）
# 信息技术对国民素质的挑战
# 信息技术 对 国民 素质 的 挑战
# 桑新民
# 桑 新民
# 随着２１世纪的临近，人类所面临的各种挑战也越来越严峻。
# 随着 ２１世纪 的 临近 ， 人类 所 面临 的 各种 挑战 也 越来越 严峻 。
# 其中既有高科技的挑战，又有生态危机、道德危机等一系列全球性重大问题的挑战。
# 其中 既有 高科技 的 挑战 ， 又 有 生态 危机 、 道德 危机 等 一系列 全球性 重大 问题 的 挑战 。
# 为了迎接挑战，最有效又最紧迫的对策是：尽快在教育系统中确立和传播新世纪的文化价值观念，并据此改革教育模式，在新一代人身上塑造未来社会所要求具备的品格、能力、思维与行为方式，由此完成国民素质的塑造工程。
# 为了 迎接 挑战 ， 最 有效 又 最 紧迫 的 对策 是 ： 尽快 在 教育 系统 中 确立 和 传播 新世纪 的 文化 价值 观念 ， 并 据此 改革 教育 模式 ， 在 新一代 人 身上 塑造 未来 社会 所 要求 具备 的 品格 、 能力 、 思维 与 行为 方式 ， 由此 完成 国民 素质 的 塑造 工程 。
# 本文着重谈谈当前急剧发展的信息技术对国民素质提出了哪些新的要求。
# 本文 着重 谈 谈 当前 急剧 发展 的 信息技术 对 国民 素质 提出 了 哪些 新 的 要求 。
# 在人类文明的进程中，文字的出现、印刷术的产生，不仅是文化发展中的两个重要里程碑，而且引发了教育模式的两次质变：前者使书面语言加入到以往只能借助口头语言和动作语言进行的文化交往和教育活动中，不仅扩展了教育的内容与形式，而且大大提高了学生抽象思维和自学的能力；后者使印刷物的书籍、课本成为文化的主要载体，由此推动了文化的传播和近、现代教育的普及。
# 在 人类 文明 的 进程 中 ， 文字 的 出现 、 印刷 术 的 产生 ， 不仅 是 文化 发展中 的 两个 重要 里程碑 ， 而且 引发 了 教育 模式 的 两次 质变 ： 前者 使 书面 语言 加入 到 以往 只能 借助 口头 语 言和 动作 语言 进行 的 文化 交往 和 教育 活动 中 ， 不仅 扩展 了 教育 的 内容 与 形式 ， 而且 大大 提高 了 学生 抽象 思 维和 自学 的 能力 ； 后者 使 印刷 物 的 书籍 、 课本 成为 文化 的 主要 载体 ， 由此 推动 了 文化 的 传播 和 近 、 现代 教育 的 普及 。
# 进入９０年代以来，“多媒体”和“信息高速公路”两大技术成为工业化时代向信息时代转变的两个重要杠杆，以惊人的速度改变着人们的工作方式、学习方式、思维方式、交往方式乃至生活方式。
# 进入 ９０年代 以来 ， “ 多媒体 ” 和 “ 信息 高速公路 ” 两大 技术 成为 工业化 时代 向 信息 时代 转变 的 两个 重要 杠杆 ， 以 惊人 的 速度 改 变着 人们 的 工作 方式 、 学习 方式 、 思维 方式 、 交往 方式 乃至 生活方式 。
# 在印刷时代，阅读、写作和计算被公认为文化之鼎的三足，也被视为传统教育的三大基石。
# 在 印刷 时代 ， 阅读 、 写作 和 计算 被 公 认为 文化 之 鼎 的 三足 ， 也 被 视为 传统 教育 的 三大 基石 。
# 世界各国都把这三种能力的培养列为基础教育的首要任务，教师和学生为此付出了大量心血。
# 世界 各国 都 把 这 三种 能力 的 培养 列为 基础教育 的 首要 任务 ， 教师 和 学生 为此 付出 了 大量 心血 。
# 而当代信息技术却在传统文化教育这三大基石中引发了一场巨大的裂变！
# 而 当代 信息技术 却 在 传统 文化教育 这 三大 基石 中 引发 了 一 场 巨大 的 裂变 ！
# 阅读方式的变革
# 阅读 方式 的 变革
# 自从印刷技术产生以来，人类已习惯于阅读文本和从各种图书资料中查找所需信息的工作与生活方式。
# 自从 印刷 技术 产生 以来 ， 人类 已 习 惯于 阅读 文本 和 从 各种 图书 资料 中 查找 所 需 信息 的 工作 与 生活方式 。
# 文本中知识与信息只能按线性结构来排列，因此阅读与检索的速度和效率有着不可逾越的界限。
# 文本 中 知识 与 信息 只能 按 线性 结构 来 排列 ， 因此 阅读 与 检索 的 速度 和 效率 有着 不可逾越 的 界限 。
# 电子书刊和因特网上各种巨型电子资料库的出现给人类带来了福音。
# 电子 书刊 和 因特 网上 各种 巨型 电子 资料 库 的 出现 给 人类 带来 了 福音 。
# 在电子读物中，知识间的联结不再是线性的，而是网状的，可以有多种联结组合方式与检索方式，是一种超文本阅读。
# 在 电子 读物 中 ， 知识 间 的 联结 不再 是 线性 的 ， 而是 网 状 的 ， 可以 有 多种 联结 组合 方式 与 检索 方式 ， 是 一种 超文本 阅读 。
# 同时，电子读物中的阅读对象也从文字媒体扩展为声音、图像、三维动画及影视等多种媒体，这就是信息时代的超媒体阅读。
# 同时 ， 电子 读物 中 的 阅读 对象 也 从 文字 媒体 扩展 为 声音 、 图像 、 三维 动画 及 影视 等 多种 媒体 ， 这就是 信息 时代 的 超 媒体 阅读 。
# 这种跨时空的阅读方式，大大提高了阅读的兴趣和效率。
# 这种 跨 时空 的 阅读 方式 ， 大大 提高 了 阅读 的 兴趣 和 效率 。
# 我们不妨举一个实例来帮助人们理解这场变革的意义。
# 我们 不妨 举 一个 实例 来 帮助 人们 理解 这 场 变革 的 意义 。
# 自１９８５年起，我国用７年时间将中华书局校点本《二十五史》输入电脑，建立了“二十五史全文检索系统”。
# 自 １９８５年 起 ， 我国 用 ７年 时间 将 中华书局 校 点 本 《 二十五 史 》 输入 电脑 ， 建立 了 “ 二十五 史 全文 检索 系统 ” 。
# 当你想从这部巨著中查找气象方面有关“风”的资料时，用传统阅读检索方式需要付出的时间和精力是可想而知的，如今运用超文本阅读和计算机自动检索的方式，只需键入“风”、“气象”等关键词，并加以必要的限制（排除与气象无关的“风”），短短６秒钟之后，电脑就会在通读二十五史全文的基础上为你筛选出１０９６８段相关资料和１４９１８个词目，组成一个特殊的文本供你阅读。
# 当 你 想 从 这 部 巨著 中 查找 气象 方面 有关 “风 ” 的 资料 时 ， 用 传统 阅读 检索 方式 需要 付出 的 时间 和 精力 是 可想而知 的 ， 如今 运用 超文本 阅读 和 计算机 自动 检索 的 方式 ， 只需 键 入 “风 ” 、 “ 气象 ” 等 关键 词 ， 并 加以 必要 的 限制 （ 排除 与 气象 无关 的 “风 ” ） ， 短短 ６ 秒 钟 之后 ， 电脑 就 会 在 通读 二十五 史 全文 的 基础 上 为 你 筛 选出 １０ ９６８ 段 相关 资料 和 １４９ １８个 词 目 ， 组成 一个 特殊 的 文本 供 你 阅读 。
# 你若还想简化，则可再次与计算机对话，直至获得满意的信息为止，而计算机的一大优点还在于，绝对会保证“百问不烦”。
# 你 若 还 想 简化 ， 则 可 再次 与 计算机 对话 ， 直至 获得 满意 的 信息 为止 ， 而 计算机 的 一大 优点 还 在于 ， 绝对 会 保证 “ 百 问 不 烦 ” 。
# 培养这种新的阅读能力不仅应该从儿童开始，而且迫切需要给成年人补课乃至“扫盲”。
# 培养 这种 新 的 阅读 能力 不仅 应该 从 儿童 开始 ， 而且 迫切 需要 给 成年人 补课 乃至 “ 扫盲 ” 。
# 这已成为我国跨世纪教育的一项不可忽视的重要使命。
# 这 已 成为 我国 跨世纪 教育 的 一 项 不可 忽视 的 重要 使命 。
# 当然，超文本和超媒体阅读能力还是要以传统文本阅读能力为基础的，但后者对前者的超越则具有鲜明的时代特征，体现了信息社会对个体创造性学习能力的挑战与激发。
# 当然 ， 超文本 和 超 媒体 阅读 能力 还是 要 以 传统 文本 阅读 能力 为 基础 的 ， 但 后者 对 前者 的 超越 则 具有 鲜明 的 时代 特征 ， 体现 了 信息社会 对 个体 创造性 学习 能力 的 挑战 与 激发 。
# 写作方式的变革
# 写作 方式 的 变革
# 在计算机席卷办公室乃至家庭的浪潮中，记者、作家、科学家、秘书乃至领导干部都在“换笔”，而学童们对键盘和鼠标的驾驭与偏爱，则是在电子游戏机“魔力”的引诱下自然发生的。
# 在 计算机 席卷 办公室 乃至 家庭 的 浪潮 中 ， 记者 、 作家 、 科学家 、 秘书 乃至 领导干部 都 在 “ 换 笔 ” ， 而 学童 们 对 键盘 和 鼠 标的 驾驭 与 偏爱 ， 则 是 在 电子游戏机 “ 魔力 ” 的 引诱 下 自然 发生 的 。
# 计算机文字处理系统的出现和日益完善化，不仅使文字录入的速度快，更重要的是可以随意复制、增补、删除等，这就大大节省了人类耗费在写作中的重复性劳动，极大地提高了人类写作的效率。
# 计算机 文字处理 系统 的 出现 和 日益 完善 化 ， 不仅 使 文字 录入 的 速度 快 ， 更 重要 的 是 可以 随意 复制 、 增补 、 删除 等 ， 这就 大大 节省 了 人类 耗费 在 写作 中 的 重复 性 劳动 ， 极 大地 提高 了 人类 写作 的 效率 。
# 一旦语音输入等人机接口技术以及“眼球跟踪器”等电脑视觉系统和机器翻译等技术进一步成熟之后，将会出现更加友好的人机对话界面，加快电脑写作模式的普及。
# 一旦 语音 输入 等 人机 接口 技术 以及 “ 眼球 跟踪 器 ” 等 电脑 视觉 系统 和 机器翻译 等 技术 进一步 成熟 之后 ， 将 会 出现 更加 友好 的 人机对话 界面 ， 加快 电脑 写作 模式 的 普及 。
# 印刷时代的写作是以文字为主，而在电子媒体的写作中，符号、声音、图像乃至三维动画及影视的使用则越来越频繁。
# 印刷 时代 的 写作 是 以 文字 为主 ， 而 在 电子 媒体 的 写作 中 ， 符号 、 声音 、 图像 乃至 三维 动画 及 影视 的 使用 则 越来越 频繁 。
# 这种多媒体的写作形式对于作者与读者之间的沟通、交流和相互理解在现代与未来社会中将越来越重要。
# 这种 多媒体 的 写作 形式 对于 作者 与 读者 之间 的 沟通 、 交流 和 相互 理解 在 现代 与 未来 社会 中将 越来越 重要 。
# 与此相适应，图文并茂、声形兼备的写作能力将要从小培养，多媒体与超文本结构的写作也将会越来越普及。
# 与此 相 适应 ， 图文并茂 、 声 形 兼备 的 写作 能力 将要 从小 培养 ， 多媒体 与 超文本 结构 的 写作 也 将 会 越来越 普及 。
# 计算方式的变革
# 计算 方式 的 变革
# 传统计算能力一般仅与数学和数学教育有关。
# 传统 计算 能力 一般 仅 与 数学 和 数学 教育 有关 。
# 当计算机的应用深入和扩展到社会生活各个领域之后，迫使人们去探究数字与数值计算同社会生活各方面的联系与转化，这就大大拓展了计算的概念，并使整个社会生活越来越“数字化”。
# 当 计算机 的 应用 深入 和 扩展 到 社会生活 各个 领域 之后 ， 迫使 人们 去 探究 数字 与 数值 计算 同 社会生活 各方 面的 联系 与 转化 ， 这就 大大 拓展 了 计算 的 概念 ， 并 使 整个 社会生活 越来越 “ 数字化 ” 。
# 计算机应用研究的实质，是探讨如何用计算机语言来表达各个领域所要解决的难题，并对该领域进行数字化模拟。
# 计算机应用 研究 的 实质 ， 是 探讨 如何 用 计算机 语言 来 表达 各个 领域 所 要 解决 的 难题 ， 并 对 该 领域 进行 数字化 模拟 。
# 文字的数字化可以看作计算机步入人类生活各个领域的一个重要的奠基石或里程碑。
# 文字 的 数字化 可以 看作 计算机 步入 人类 生活 各个 领域 的 一个 重要 的 奠基石 或 里程碑 。
# 此后，文字所表达和描述的世界都可以转化为二进制的计算机语言了，而计算机也开始从技术上升为文化。
# 此后 ， 文字 所 表达 和 描述 的 世界 都 可以 转 化为 二进 制 的 计算机 语言 了 ， 而 计算机 也 开始 从 技术 上升 为 文化 。
# 但计算机并没有就此止步，她又征服了比文字更加复杂的声音世界、图像世界乃至三维动画及影视世界。
# 但 计算机 并 没有 就此 止步 ， 她 又 征服 了 比 文字 更加 复杂 的 声音 世界 、 图像 世界 乃至 三维 动画 及 影视 世界 。
# 如今，记录、表达人类物质与精神世界的数字、图片、胶片、录音带、录像带等组成的巨大的资料库，都可以被数字化处理，这些数据在光、电的运载下，每时每刻都纵横驰骋于高速运行的环球“信息高速公路”网络之中，随时等待和人类的智慧实现跨时空的“联网”与“激发”。
# 如今 ， 记录 、 表达 人类 物质 与 精神 世界 的 数字 、 图片 、 胶片 、 录音带 、 录像带 等 组成 的 巨大 的 资料 库 ， 都 可以 被 数字化 处理 ， 这些 数据 在 光 、 电 的 运载 下 ， 每时每刻 都 纵横驰骋 于 高速 运行 的 环球 “ 信息 高速公路 ” 网络 之中 ， 随时 等待 和 人类 的 智慧 实现 跨 时空 的 “ 联网 ” 与 “ 激发 ” 。
# 在这样的技术背景和时代背景下，数学和数学教育正在经历着一场极其深刻的变革。
# 在 这样 的 技术 背景 和 时代 背景 下 ， 数学 和 数学 教育 正在 经历 着 一 场 极其 深刻 的 变革 。
# 传统计算能力的强化训练将会过时，枯燥乏味的“题海战术”应该抛弃，而对学生进行数学思想、数学方法、数学应用的教育和训练则应强化。
# 传统 计算 能力 的 强化 训练 将 会 过时 ， 枯燥 乏味 的 “ 题 海 战术 ” 应该 抛弃 ， 而 对 学生 进行 数学 思想 、 数学 方法 、 数学 应用 的 教育和 训练 则 应 强化 。
# 现代数学中的统计、概率、化归、建模、计算机仿真等内容必须尽快纳入基础教育的课程体系中，并通过教育心理学的研究和教育技术手段的更新，探索新的学习模式和教育模式，使不同年龄的学生易学、易懂、会用。
# 现代 数学 中 的 统计 、 概率 、 化 归 、 建 模 、 计算机 仿真 等 内容 必须 尽快 纳入 基础教育 的 课程 体系 中 ， 并 通过 教育 心理学 的 研究和 教育 技术 手段 的 更新 ， 探索 新 的 学习 模式 和 教育 模式 ， 使 不同 年龄 的 学生 易 学 、 易懂 、 会 用 。
# 数学与社会生活的联系更加密切，数学教育与其他学科以及生活教育的结合势在必行。
# 数学 与 社会生活 的 联系 更加 密切 ， 数学 教育 与 其他 学科 以及 生活 教育 的 结合 势在必行 。
# 传统教育注重文化的传承，现代与未来教育在文化传承的同时更注重培养人的创造性，由此实现对文化的不断超越。
# 传统 教育 注重 文化 的 传承 ， 现代 与 未来 教育 在 文化 传承 的 同时 更 注重 培 养人 的 创造性 ， 由此 实现 对 文化 的 不断 超越 。
# 文化的超越有量变也有质变，每当文化的根基发生实质性变化之时，文化的质变显然就不可避免了。
# 文化 的 超越 有 量变 也 有 质变 ， 每当 文化 的 根基 发生 实质性 变化 之 时 ， 文化 的 质变 显然 就 不可 避免 了 。
# 由此入手，才能更深刻地洞察信息时代教育改革发展的趋势与前景，这对于尽快培养出一大批能适应２１世纪信息化国际竞争环境的优秀人才，提高全体国民适应信息化社会的能力与素质都将产生极其深远的影响。
# 由此 入手 ， 才能 更 深刻 地 洞察 信息 时代 教育 改革 发展 的 趋势 与 前景 ， 这 对于 尽快 培养 出 一大批 能 适应 ２１世纪 信息化 国际 竞争 环境 的 优秀 人才 ， 提高 全体 国民 适应 信息化 社会 的 能力 与 素质 都 将 产生 极其 深远 的 影响 。
# （作者为北京师范大学未来教育研究中心主任、教授，教育学原理专业博士生导师）
# （ 作者 为 北京师范大学 未来 教育 研究 中心 主任 、 教授 ， 教育学 原理 专业 博士生 导师 ）
# 跨越文明的对话--浅述计算机与汉字文化的冲突与碰撞
# 跨越 文明 的 对话 - - 浅 述 计算机 与 汉字 文化 的 冲突 与 碰撞
# 本报记者杨健
# 本报 记者 杨健
# “换笔”引出的话题
# “ 换 笔 ” 引出 的 话题
# 在这个“告别铅与火，迎来光与电”的年代，文化人“换笔”似乎成了一种潮流。
# 在 这个 “ 告别 铅 与 火 ， 迎来 光 与 电 ” 的 年代 ， 文化人 “ 换 笔 ” 似乎 成 了 一种 潮流 。
# ５年前，历史学家庞朴买了一台学习机，开始了艰难的“换笔”。
# ５ 年前 ， 历 史学 家 庞朴 买 了 一 台 学习机 ， 开始 了 艰难 的 “ 换 笔 ” 。
# 捧着随机赠送的王码教程，花了两个礼拜总算写出一篇稿子，可到南方出差几天回来，发现本已倒背如流的口诀全忘到了九霄云外。
# 捧 着 随机 赠送 的 王码 教程 ， 花 了 两个 礼拜 总算 写出 一 篇 稿子 ， 可 到 南方 出差 几天 回来 ， 发现 本 已 倒背如流 的 口诀 全 忘 到 了 九 霄 云 外 。
# 夫人说别费劲了，花２００块钱进学习班吧。
# 夫人 说 别 费劲 了 ， 花 ２００ 块 钱 进 学习班 吧 。
# 庞朴不服气，订了份厚厚的《计算机世界》，又给王永民打了好多电话，几本人家推荐的教材红笔画过蓝笔画，“像学经典著作一般”，终于修成正果。
# 庞朴 不 服气 ， 订 了 份 厚 厚 的 《 计算机 世界 》 ， 又 给 王永民 打 了 好多 电话 ， 几本 人家 推荐 的 教材 红 笔画 过 蓝 笔画 ， “ 像 学 经典著作 一般 ” ， 终于 修 成 正果 。
# 如今问起他的感觉，言语中不无得意：“以前怕手跟不上脑子灵感飞了，现在发愁的是脑袋转得太慢了。
# 如今 问 起 他 的 感觉 ， 言语 中 不无 得意 ： “ 以前 怕 手 跟 不 上 脑子 灵感 飞 了 ， 现在 发愁 的 是 脑袋 转 得 太 慢 了 。
# ｀得心应手＇大概就是这个意思吧。”
# 大概 就是 这个 意思 吧 。 ”
# 其实令他得意的岂止于此。
# 其实 令 他 得意 的 岂止 于 此 。
# 熟人朋友的机器坏了，无论软件硬件，他都会“两肋插刀”，而且往往手到病除。
# 熟人 朋友 的 机器 坏 了 ， 无论 软件 硬件 ， 他 都会 “ 两肋插刀 ” ， 而且 往往 手到病除 。
# 至于自己的机器出了毛病，那就更是“敢作敢为”。
# 至于 自己 的 机器 出 了 毛病 ， 那 就 更 是 “ 敢 作 敢 为 ” 。
# 前段时间从一家公司买了台原装的“５８６”，接录音电话时出了毛病，捣鼓半天还是没辙，只好把电脑搬到公司去修。
# 前 段 时间 从 一家 公司 买 了 台 原装 的 “ ５８６ ” ， 接 录音 电话 时 出 了 毛病 ， 捣 鼓 半天 还是 没 辙 ， 只好 把 电脑 搬 到 公司 去 修 。
# 人家一看说，主板坏了，要换，收费６０００元；调制解调器坏了，要换，收费１２００元；另收４５０元修理费。
# 人家 一 看 说 ， 主板 坏 了 ， 要 换 ， 收费 ６０００元 ； 调制解调器 坏 了 ， 要 换 ， 收费 １２００元 ； 另 收 ４５０元 修理 费 。
# 庞朴一听，算了吧，回家后试着把连线从一个接口往另一个接口一换，成了！
# 庞朴 一 听 ， 算了 吧 ， 回家 后 试 着 把 连 线 从 一个 接口 往 另一个 接口 一 换 ， 成 了 ！
# 经过几年的磨练，庞朴对他的“笔”真可以说是摸透了。
# 经过 几年 的 磨练 ， 庞朴 对 他 的 “ 笔 ” 真 可以 说是 摸 透 了 。
# 和庞朴的潇洒劲儿比起来，其他一些人与电脑打交道的经历可就难受多了。
# 和 庞朴 的 潇洒 劲 儿 比 起来 ， 其他 一些 人与 电脑 打交道 的 经历 可 就 难受 多 了 。
# 去年某大报社宣布“告别纸与笔”，所有的稿件都要求作者输入电脑统一管理，不存入电脑的稿子一律免看。
# 去年 某 大 报社 宣布 “ 告别 纸 与 笔 ” ， 所 有的 稿件 都 要求 作者 输入 电脑 统一 管理 ， 不 存入 电脑 的 稿子 一律 免 看 。
# 这可急煞了一些老记者，尤其是有些年纪大一点的女同志，私下里直抱怨：这不是逼着我们早退休吗？
# 这 可 急 煞 了 一些 老 记者 ， 尤其是 有些 年纪 大 一点 的 女 同志 ， 私下里 直 抱怨 ： 这 不是 逼 着 我们 早 退休 吗 ？
# 问起他们与计算机的隔膜，笼而统之一个字：难。
# 问 起 他们 与 计算机 的 隔膜 ， 笼而统之 一个 字 ： 难 。
# 关于这个“难”字，后来有位叫康东日的计算机专家在他的著述中从理论高度进行了分析：从１８７７年世界上第一个英文打字培训班成立算起，西方人有了１００多年的英文键盘操作史，而５０年代开始的电脑字符处理技术，又是以英文键盘输入为依据发展起来的。
# 关于 这个 “ 难 ” 字 ， 后来 有 位 叫 康 东 日 的 计算机 专家 在 他 的 著述 中 从 理论 高度 进行 了 分析 ： 从 １８７７年 世界 上 第一个 英文 打字 培训班 成立 算 起 ， 西方人 有 了 １００多年 的 英文 键盘 操作 史 ， 而 ５０年代 开始 的 电脑 字符 处理 技术 ， 又是 以 英文 键盘 输入 为 依据 发展 起来 的 。
# 从根本上说，我们今天要用的这支智能化的“笔”，是迄今为止与人脑关系最密切的机器，可它在思维逻辑上就与以象形文字为代表的中国文化有着巨大的差异，运用起来当然就必须付出一定的代价了。
# 从 根本上 说 ， 我们 今天 要 用 的 这 支 智能 化 的 “ 笔 ” ， 是 迄今为止 与 人脑 关系 最 密切 的 机器 ， 可 它 在 思维 逻辑 上 就 与 以 象 形 文字 为 代表 的 中国文化 有着 巨大 的 差异 ， 运用 起来 当然 就 必须 付出 一定 的 代价 了 。
# 到底是专家，一语中的。
# 到底 是 专家 ， 一语 中 的 。
# 沉重的双重使命
# 沉重 的 双重 使命
# 其实，与中文用户相比，在中国进行计算机研究的人所付的代价还要大许多。
# 其实 ， 与 中文 用户 相比 ， 在 中国 进行 计算机研究 的 人所 付 的 代价 还要 大 许多 。
# 尽管有人自我炫耀地说，莱布尼茨是受了太极八卦图的启示才发明了二进制计算机，奠定了现代计算机的理论基础，也有人夸张地断言“中文是最适合计算机逻辑结构的语言”，可现状就如康先生所分析的，是西方人发明了计算机，而且到目前为止，西方文化仍然占据着计算机文化的主体。
# 尽管 有人 自我 炫耀 地 说 ， 莱布尼 茨 是 受 了 太极 八卦 图 的 启示 才 发 明了 二进 制 计算机 ， 奠定 了 现代 计算机 的 理论 基础 ， 也 有人 夸张 地 断言 “ 中文 是 最 适合 计算机 逻辑 结构 的 语言 ” ， 可 现状 就 如 康 先生 所 分析 的 ， 是 西方人 发 明了 计算机 ， 而且 到 目前 为止 ， 西方 文化 仍然 占据 着 计算机 文化 的 主体 。
# 对于中国计算机工作者来说，这一现状先天地决定了他们的双重使命：在历尽千辛万苦挤入计算机技术的核心层后，他们必须肩负起把母体文化引入学科前沿的重任，在使用上令中文习惯与计算机逻辑完美结合，使中文用户在计算机上如鱼得水，并且紧紧跟上技术进步的步伐。
# 对于 中国计算机 工作者 来说 ， 这一 现状 先 天地 决定 了 他们 的 双重 使命 ： 在 历尽 千辛万苦 挤 入 计算机技术 的 核心 层 后 ， 他们 必须 肩负 起 把 母体 文化 引入 学科 前沿 的 重任 ， 在 使用 上 令 中文 习惯 与 计算机 逻辑 完美 结合 ， 使 中文 用户 在 计算机 上 如鱼得水 ， 并且 紧 紧跟 上 技术 进步 的 步伐 。
# 对西文软件进行“汉化”翻译，并使汉字字符能够在计算机上处理，是发明ｃｃｅｄ的颜援朝、开发方正排版系统的王选等一代计算机元老的贡献。
# 的 颜 援 朝 、 开发 方正 排版 系统 的 王选 等 一代 计算机 元老 的 贡献 。
# 构筑外挂式中文平台，让优秀西文软件无须汉化即可在中文环境下使用，是“中文之星”的主要创意者王志东等一批后来者的功劳。
# 构筑 外挂 式 中文 平台 ， 让 优秀 西 文 软件 无 须汉 化 即可 在 中文 环境 下 使用 ， 是 “ 中文 之 星 ” 的 主要 创意 者 王志 东 等 一批 后 来者 的 功劳 。
# 实现多种中文内码自动识别和转换，使ｉｎｔｅｒｎｅｔ上世界各地不同内码的汉字均能在同一平台上显示，则是汪延等一些二十出头的小伙子的最新创造。
# 上 世界 各地 不同 内 码 的 汉字 均 能 在 同 一平 台上 显示 ， 则 是 汪 延 等 一些 二十 出头 的 小伙子 的 最新 创造 。
# 在四通利方公司的实验室里，刚从法国回来不久的汪延跟我谈起中文用户从“能用”到“同步用”再到“同步发展”的曲折历程，感慨万千。
# 在 四通利方公司 的 实验室 里 ， 刚 从 法国 回来 不久 的 汪 延 跟 我 谈 起 中文 用户 从 “ 能 用 ” 到 “ 同步 用 ” 再 到 “ 同步 发展 ” 的 曲折 历程 ， 感慨 万千 。
# 作为一门方兴未艾的新学科，计算机技术始终在飞速发展。
# 作为 一门 方兴未艾 的 新 学科 ， 计算机技术 始终 在 飞速 发展 。
# 而每往前走一步，都可能给中国的计算机专家们带来新的挑战，这场战斗旷日持久。
# 而 每 往前 走 一步 ， 都 可能 给 中国 的 计算机 专家 们 带来 新 的 挑战 ， 这 场 战斗 旷日持久 。
# 技术与文化的互动
# 技术 与 文化 的 互动
# 在与汪延的谈话中，我们说到了另一个值得注意的现象，那就是越来越多的人文学者进入了电脑行业。
# 在 与 汪 延 的 谈话 中 ， 我们 说到 了 另一个 值得 注意 的 现象 ， 那 就是 越来越 多 的 人文 学者 进入 了 电脑 行业 。
# 小汪本人原来就是学法律的，到法国后迷上了ｉｎｔｅｒｎｅｔ，干脆转行学起了计算机，而且一鸣惊人，独领潮流。
# ， 干脆 转 行 学 起 了 计算机 ， 而且 一鸣惊人 ， 独 领 潮流 。
# 像他这样的人在当今中国计算机界为数不少。
# 像 他 这样 的 人 在 当今 中国计算机 界 为数 不少 。
# 从科普的对象到技术发展的参与者，这种角色转换意味着一种技术与文化的互动。
# 从 科普 的 对象 到 技术 发展 的 参与 者 ， 这种 角色 转换 意味着 一种 技术 与 文化 的 互动 。
# “计算机发展到今天，其突破不仅要靠技术，更依赖于引进新的思想。”
# “ 计算机 发展 到 今天 ， 其 突破 不仅 要 靠 技术 ， 更 依赖 于 引进 新 的 思想 。 ”
# 据说ｗｉｎｄｏｗｓ９５推出前，考虑到低性能电脑安装它的时间很长，微软公司曾向心理学家请教，怎样在安装等待过程中设计出活动的画面才能让用户不致焦躁。
# ｏ ｗ ｓ ９５ 推出 前 ， 考虑 到 低 性能 电脑 安装 它 的 时间 很 长 ， 微软公司 曾 向 心理学 家 请教 ， 怎样 在 安装 等待 过程 中 设计 出 活动 的 画面 才能 让 用户 不致 焦躁 。
# 而许多电子出版物的策划，已经无法离开人文社科专家的支持。
# 而 许多 电子 出版物 的 策划 ， 已经 无法 离开 人文 社科 专家 的 支持 。
# 在我国，因为中西文化的差异在计算机应用上反映得格外典型，普及和发展计算机技术的人更是对“中国特色”反复揣摩，社会、文化心理方面的研究达到了相当的高度。
# 在 我国 ， 因为 中西 文化 的 差异 在 计算机应用 上 反映 得 格外 典型 ， 普及 和 发展 计算机技术 的 人 更 是 对 “中国 特色 ” 反复 揣 摩 ， 社会 、 文化 心理 方 面的 研究 达到 了 相当 的 高度 。
# 从电脑学习班的普及到教育软件的火爆，从中文打字机的风靡到中文学习机的商业奇迹，细窥其中的奥妙，有的并非靠技术取胜，而是更多地适应了中国用户的文化习惯和消费心理。
# 从 电脑 学习班 的 普及 到 教育 软件 的 火爆 ， 从 中文 打字机 的 风靡 到 中文 学习机 的 商业 奇迹 ， 细 窥 其中 的 奥妙 ， 有的 并非 靠 技术 取胜 ， 而是 更 多 地 适应 了 中国 用户 的 文化 习惯 和 消费 心理 。
# 而大量“看图学计算机”教材的出现，和蔡志忠的漫画诸子相映成趣，掀起了一股成人“看图识字”的出版潮，到后来竟说不清是谁影响了谁。
# 而 大量 “ 看 图 学 计算机 ” 教材 的 出现 ， 和 蔡 志 忠 的 漫画 诸子 相映成趣 ， 掀起 了 一股 成人 “ 看 图 识字 ” 的 出版 潮 ， 到 后来 竟 说不清 是 谁 影响 了 谁 。
# 在日常生活中，像“软件”、“硬件”、“死循环”一类的新词充实了我们的语言库。
# 在 日常生活 中 ， 像 “ 软件 ” 、 “ 硬件 ” 、 “ 死 循环 ” 一类 的 新 词 充实 了 我们 的 语言 库 。
# 而计算机造词功能的运用，形成了一种被称为“语词传染”的新现象：如果有人在电脑里造出了一个错误的词，所有使用该电脑的人都会出现同一错误，而且防不胜防。
# 而 计算机 造 词 功能 的 运用 ， 形成 了 一种 被 称为 “ 语词 传染 ” 的 新 现象 ： 如果 有人 在 电脑 里 造 出 了 一个 错误 的 词 ， 所有 使用 该 电脑 的 人 都会 出现 同一 错误 ， 而且 防不胜防 。
# 至于计算机的使用对学生书法、笔顺、发音的影响，更是教育学家关心的话题。
# 至于 计算机 的 使用 对 学生 书法 、 笔 顺 、 发音 的 影响 ， 更 是 教育学 家 关心 的 话题 。
# 再往远些看，随着汉字识别和语音识别技术的发展，中文计算机用户将跨越语言差异的鸿沟，在录入上走向中西文求同的道路。
# 再 往 远 些 看 ， 随着 汉字 识别 和 语音 识别 技术 的 发展 ， 中文 计算机 用户 将 跨越 语言 差异 的 鸿 沟 ， 在 录入 上 走向 中西 文 求同 的 道路 。
# 而计算机翻译系统与现代汉语分析相辅相成，正推动着人工智能科学的前进……
# 而 计算机 翻译 系统 与 现代汉语 分析 相辅相成 ， 正 推动 着 人工智能 科学 的 前进 … …
# 每跨过一道障碍，人们都会发现一片新的开阔地，每经过一次剧烈的碰撞，都将激起一团耀眼的火花，这就是崭新的计算机技术和古老的中华文化的对话。
# 每 跨过 一道 障碍 ， 人们 都会 发现 一片 新 的 开阔地 ， 每 经过 一次 剧烈 的 碰撞 ， 都 将 激起 一团 耀眼 的 火花 ， 这就是 崭新 的 计算机技术 和 古老 的 中华文化 的 对话 。
